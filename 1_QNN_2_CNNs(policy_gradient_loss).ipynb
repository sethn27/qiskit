# %% [markdown]
# #### Importing Librarires

# %%
import gym
import sys
import sys
import random

import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn 
import torch.nn.functional as F 
from torch.distributions.categorical import Categorical
from sklearn.preprocessing import normalize

import math as mt
import numpy as np
import matplotlib.pyplot as plt
import qiskit
from qiskit import transpile, assemble
from qiskit.visualization import *
import qiskit_machine_learning
from qiskit_machine_learning.neural_networks import SamplerQNN, CircuitQNN
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class HybridActorNetwork(nn.Module):
    def __init__(self, 
                 state_space, 
                 action_space,
                 number_of_qubits = 1,
                 number_of_shots = 1024):
        super(HybridActorNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.number_of_qubits = number_of_qubits
        self.number_of_shots = number_of_shots

        self.qubits = [i for i in range(0, self.number_of_qubits)]
        self.quantum_circuit = qiskit.QuantumCircuit(self.number_of_qubits)
        self.theta = qiskit.circuit.Parameter('theta')
        self.beta = qiskit.circuit.ParameterVector('beta', self.state_space)

        self.input_layer()
        self.parameterized_quantum_circuit()
        quantum_neural_network = EstimatorQNN(circuit = self.quantum_circuit, 
                                              input_params = self.beta.params, 
                                              weight_params = [self.theta], 
                                              input_gradients = True)
        self.quantum_layer = TorchConnector(quantum_neural_network)

        self.classical_layer_1 = nn.Linear(64, 128)
        self.classical_layer_2 = nn.Linear(128, self.action_space)

    def input_layer(self):
        self.quantum_circuit.h(self.qubits)
        self.quantum_circuit.barrier()

        self.quantum_circuit.rz(self.beta[0], self.qubits)
        self.quantum_circuit.ry(self.beta[1], self.qubits)
        self.quantum_circuit.rz(self.beta[2], self.qubits)
        self.quantum_circuit.barrier()

    def parameterized_quantum_circuit(self):
        self.quantum_circuit.rx(self.theta, self.qubits)
        self.quantum_circuit.barrier()

    def forward(self, current_state):
        output_layer_1 = self.quantum_layer(current_state)
        output_layer_1 = output_layer_1.repeat(64)
        output_layer_2 = F.relu(self.classical_layer_1(output_layer_1))
        output_layer_3 = self.classical_layer_2(output_layer_2)
        
        policy = Categorical(F.softmax(output_layer_3, dim=-1))
        return policy

# %%
class HybridCriticNetwork(nn.Module):
    def __init__(self, 
                 state_space, 
                 action_space,
                 number_of_qubits = 1,
                 number_of_shots = 1024):
        super(HybridCriticNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.number_of_qubits = number_of_qubits
        self.number_of_shots = number_of_shots

        self.qubits = [i for i in range(0, self.number_of_qubits)]
        self.quantum_circuit = qiskit.QuantumCircuit(self.number_of_qubits)
        self.theta = qiskit.circuit.Parameter('theta')
        self.beta = qiskit.circuit.ParameterVector('beta', self.state_space)

        self.input_layer()
        self.parameterized_quantum_circuit()
        quantum_neural_network = EstimatorQNN(circuit = self.quantum_circuit, 
                                              input_params = self.beta.params, 
                                              weight_params = [self.theta], 
                                              input_gradients = True)
        self.quantum_layer = TorchConnector(quantum_neural_network)

        self.classical_layer_1 = nn.Linear(64, 128)
        self.classical_layer_2 = nn.Linear(128, 1)

    def input_layer(self):
        self.quantum_circuit.h(self.qubits)
        self.quantum_circuit.barrier()

        self.quantum_circuit.rz(self.beta[0], self.qubits)
        self.quantum_circuit.ry(self.beta[1], self.qubits)
        self.quantum_circuit.rz(self.beta[2], self.qubits)
        self.quantum_circuit.barrier()

    def parameterized_quantum_circuit(self):
        self.quantum_circuit.rx(self.theta, self.qubits)
        self.quantum_circuit.barrier()

    def forward(self, current_state):
        output_layer_1 = self.quantum_layer(current_state)
        output_layer_1 = output_layer_1.repeat(64)
        output_layer_2 = F.relu(self.classical_layer_1(output_layer_1))
        state_value = self.classical_layer_2(output_layer_2)
    
        return state_value

# %%
class QERL_Agent():
    def __init__(self, 
                 Actor,
                 Critic,
                 max_time_steps,
                 actor_learning_rate,
                 critic_learning_rate,
                 discount_factor,
                 number_of_epochs):
        
        self.max_time_steps = max_time_steps
        self.actor_learning_rate = actor_learning_rate
        self.critic_learning_rate = critic_learning_rate
        self.discount_factor = discount_factor
        self.number_of_epochs = number_of_epochs

        self.Actor = Actor
        self.Critic = Critic

        self.actor_optimizer = optim.Adam(self.Actor.parameters(), self.actor_learning_rate)
        self.critic_optimizer = optim.Adam(self.Critic.parameters(), self.critic_learning_rate)

    def clear_memory(self):
        self.rewards = []
        self.state_values = []
        self.log_policies = []
        self.done = []

    def replay_memory(self, 
                      state_value,
                      reward,
                      policy,
                      done):
        
        self.log_policies.append(policy)
        self.state_values.append(state_value)
        self.rewards.append(torch.tensor([reward],
                                         dtype = torch.float,
                                         device = device))
        self.done.append(torch.tensor([1-done],
                                      dtype = torch.float,
                                      device = device))
        
    def action_selection(self, 
                         current_state):
        current_state = torch.FloatTensor(current_state).to(device)
        policy = self.Actor(current_state)
        action = policy.sample()
        policy = policy.log_prob(action).unsqueeze(0)

        return action.cpu().numpy(), policy
    
    def compute_discounted_rewards(self, 
                                   next_state_value):
        R = next_state_value
        discounted_rewards = []
        for step in reversed(range(len(self.rewards))):
            R = self.rewards[step] + self.discount_factor * R * self.done[step]
            discounted_rewards.insert(0, R)
        return discounted_rewards
    
    def loss_function(self,
                      discounted_rewards):
        
        self.log_policies = torch.cat(self.log_policies)
        discounted_rewards = torch.cat(discounted_rewards).detach()
        self.state_values = torch.cat(self.state_values)

        advantage = discounted_rewards - self.state_values
        actor_loss = -(self.log_policies * advantage.detach()).mean()
        critic_loss = F.huber_loss(discounted_rewards, self.state_values)

        return actor_loss, critic_loss
    
    def training(self, next_state_value):
        discounted_rewards = self.compute_discounted_rewards(next_state_value)
        actor_loss, critic_loss = self.loss_function(discounted_rewards)

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        return actor_loss.item(), critic_loss.item()

# %%
def data_transformation(state):
        return [mt.atan(i) for i in state]

# %%
enviroment = gym.make("CartPole-v0").unwrapped

state_space = enviroment.observation_space.shape[0]-1
action_space = enviroment.action_space.n

actor_learning_rate = 0.001
critic_learning_rate = 0.01

max_time_steps = 500
number_of_epochs = 1
number_of_episodes = 500
discount_factor = 0.99
constant_for_average = 10

Actor = HybridActorNetwork(state_space = state_space,
                     action_space = action_space).to(device)
Critic = HybridCriticNetwork(state_space = state_space,
                       action_space = action_space).to(device)
Agent = QERL_Agent(Actor = Actor,
                        Critic = Critic,
                        max_time_steps = max_time_steps,
                        discount_factor = discount_factor,
                        actor_learning_rate = actor_learning_rate,
                        critic_learning_rate = critic_learning_rate,
                        number_of_epochs = number_of_epochs)

score = []
actor_loss = []
critic_loss = []

average_score = []
average_actor_loss = []
average_critic_loss = []

for current_episode in range(0, number_of_episodes):
    Agent.clear_memory()
    (current_state, _ ) = enviroment.reset()
    episodic_score  = 0

    for time_step in range(0, max_time_steps):
        enviroment.render()
        current_state = data_transformation(state = current_state[1:4])
        action, policy = Agent.action_selection(current_state)
        current_state = torch.FloatTensor(current_state).to(device)
        state_value = Critic(current_state)

        next_state, reward, done, info, _ = enviroment.step(action)
        episodic_score += reward

        Agent.replay_memory(reward = reward,
                            policy = policy,
                            state_value = state_value,
                            done = done)
        
        current_state = next_state
        if done == True:
            break

    next_state = data_transformation(state = next_state[1:4])
    next_state = torch.FloatTensor(next_state).to(device)
    next_state_value = Critic(next_state)
    episodic_actor_loss, episodic_critic_loss = Agent.training(next_state_value = next_state_value)

    score.append(episodic_score)
    actor_loss.append(episodic_actor_loss)
    critic_loss.append(episodic_critic_loss)
    print('Episode:{} Score:{} Actor_Loss:{} Critic_Loss:{}'.format(current_episode, 
                                                                    episodic_score, 
                                                                    episodic_actor_loss, 
                                                                    episodic_critic_loss))
    
for i in range(0,int(len(score)/constant_for_average)):
    temp_score = sum(score[i * constant_for_average : (i+1) * constant_for_average])
    temp_actor_loss = sum(actor_loss[i * constant_for_average : (i+1) * constant_for_average])
    temp_critic_loss = sum(critic_loss[i * constant_for_average : (i+1) * constant_for_average])

    average_score.append(temp_score/10)
    average_actor_loss.append(temp_actor_loss/10)
    average_critic_loss.append(temp_critic_loss/10)
# Out:
# Episode:0 Score:14.0 Actor_Loss:4.717113494873047 Critic_Loss:6.675096035003662
# Episode:1 Score:19.0 Actor_Loss:6.641137599945068 Critic_Loss:8.938326835632324
# Episode:2 Score:14.0 Actor_Loss:4.480010986328125 Critic_Loss:6.338454246520996
# Episode:3 Score:17.0 Actor_Loss:5.881042957305908 Critic_Loss:7.743668556213379
# Episode:4 Score:13.0 Actor_Loss:3.956125020980835 Critic_Loss:5.60426664352417
# Episode:5 Score:12.0 Actor_Loss:4.393077850341797 Critic_Loss:5.314713001251221
# Episode:6 Score:14.0 Actor_Loss:4.674781799316406 Critic_Loss:5.99718713760376
# Episode:7 Score:10.0 Actor_Loss:3.3644893169403076 Critic_Loss:3.9894137382507324
# Episode:8 Score:23.0 Actor_Loss:7.0864033699035645 Critic_Loss:9.57313060760498
# Episode:9 Score:41.0 Actor_Loss:11.999899864196777 Critic_Loss:16.615209579467773
# Episode:10 Score:36.0 Actor_Loss:10.636981964111328 Critic_Loss:14.596479415893555
# Episode:11 Score:19.0 Actor_Loss:5.147160530090332 Critic_Loss:7.174704074859619
# Episode:12 Score:12.0 Actor_Loss:2.6077206134796143 Critic_Loss:3.76358962059021
# Episode:13 Score:19.0 Actor_Loss:5.007238388061523 Critic_Loss:7.026806354522705
# Episode:14 Score:10.0 Actor_Loss:1.5459821224212646 Critic_Loss:2.573798179626465
# Episode:15 Score:24.0 Actor_Loss:5.342045307159424 Critic_Loss:8.33017349243164
# Episode:16 Score:55.0 Actor_Loss:14.123820304870605 Critic_Loss:19.846893310546875
# Episode:17 Score:17.0 Actor_Loss:2.8599562644958496 Critic_Loss:4.782747268676758
# Episode:18 Score:18.0 Actor_Loss:3.1475515365600586 Critic_Loss:5.089212417602539
# Episode:19 Score:26.0 Actor_Loss:5.339743614196777 Critic_Loss:7.88922119140625
# Episode:20 Score:18.0 Actor_Loss:2.827834129333496 Critic_Loss:4.913651466369629
# Episode:21 Score:27.0 Actor_Loss:5.330965042114258 Critic_Loss:7.866368770599365
# Episode:22 Score:21.0 Actor_Loss:2.4939889907836914 Critic_Loss:4.659440517425537
# Episode:23 Score:12.0 Actor_Loss:-2.1626226902008057 Critic_Loss:4.3820719718933105
# Episode:24 Score:18.0 Actor_Loss:0.3915569484233856 Critic_Loss:5.215426445007324
# Episode:25 Score:14.0 Actor_Loss:-3.5245249271392822 Critic_Loss:7.1458048820495605
# Episode:26 Score:15.0 Actor_Loss:-3.817789316177368 Critic_Loss:6.436929225921631
# Episode:27 Score:17.0 Actor_Loss:-1.6531132459640503 Critic_Loss:6.358448028564453
# Episode:28 Score:14.0 Actor_Loss:-0.06128043681383133 Critic_Loss:3.9922080039978027
# Episode:29 Score:24.0 Actor_Loss:2.671727418899536 Critic_Loss:7.774011611938477
# Episode:30 Score:13.0 Actor_Loss:-0.9705015420913696 Critic_Loss:4.88252067565918
# Episode:31 Score:11.0 Actor_Loss:-3.248974084854126 Critic_Loss:5.513524055480957
# Episode:32 Score:17.0 Actor_Loss:-1.7863960266113281 Critic_Loss:4.697987079620361
# Episode:33 Score:42.0 Actor_Loss:8.383345603942871 Critic_Loss:13.009088516235352
# Episode:34 Score:12.0 Actor_Loss:-0.4819387197494507 Critic_Loss:2.420905351638794
# Episode:35 Score:29.0 Actor_Loss:2.5492470264434814 Critic_Loss:9.1968994140625
# Episode:36 Score:16.0 Actor_Loss:0.6872214078903198 Critic_Loss:3.0801820755004883
# Episode:37 Score:25.0 Actor_Loss:4.585194110870361 Critic_Loss:6.935327053070068
# Episode:38 Score:13.0 Actor_Loss:-0.08108304440975189 Critic_Loss:3.5046005249023438
# Episode:39 Score:13.0 Actor_Loss:1.1887407302856445 Critic_Loss:2.5879602432250977
# Episode:40 Score:37.0 Actor_Loss:7.999494552612305 Critic_Loss:11.555871963500977
# Episode:41 Score:32.0 Actor_Loss:2.931304454803467 Critic_Loss:10.39437484741211
# Episode:42 Score:11.0 Actor_Loss:0.6602216362953186 Critic_Loss:2.1909279823303223
# Episode:43 Score:27.0 Actor_Loss:5.10825777053833 Critic_Loss:8.212122917175293
# Episode:44 Score:45.0 Actor_Loss:9.697408676147461 Critic_Loss:14.340023040771484
# Episode:45 Score:40.0 Actor_Loss:8.266864776611328 Critic_Loss:12.648017883300781
# Episode:46 Score:26.0 Actor_Loss:2.014064311981201 Critic_Loss:7.052920818328857
# Episode:47 Score:39.0 Actor_Loss:8.018173217773438 Critic_Loss:13.39908218383789
# Episode:48 Score:10.0 Actor_Loss:0.23611155152320862 Critic_Loss:1.551129698753357
# Episode:49 Score:12.0 Actor_Loss:-2.344214677810669 Critic_Loss:3.754774808883667
# Episode:50 Score:11.0 Actor_Loss:0.40077173709869385 Critic_Loss:1.9332367181777954
# Episode:51 Score:44.0 Actor_Loss:8.716859817504883 Critic_Loss:12.941170692443848
# Episode:52 Score:34.0 Actor_Loss:6.511920928955078 Critic_Loss:9.785345077514648
# Episode:53 Score:29.0 Actor_Loss:3.968804359436035 Critic_Loss:8.184072494506836
# Episode:54 Score:31.0 Actor_Loss:5.409654140472412 Critic_Loss:8.47911548614502
# Episode:55 Score:13.0 Actor_Loss:-2.114922523498535 Critic_Loss:3.8437018394470215
# Episode:56 Score:18.0 Actor_Loss:1.4905515909194946 Critic_Loss:3.89864444732666
# Episode:57 Score:25.0 Actor_Loss:1.6635037660598755 Critic_Loss:5.2732110023498535
# Episode:58 Score:20.0 Actor_Loss:1.7332534790039062 Critic_Loss:4.442458152770996
# Episode:59 Score:13.0 Actor_Loss:-0.8012598752975464 Critic_Loss:2.3013899326324463
# Episode:60 Score:20.0 Actor_Loss:0.4439926743507385 Critic_Loss:3.9115614891052246
# Episode:61 Score:18.0 Actor_Loss:0.2207142412662506 Critic_Loss:3.1677823066711426
# Episode:62 Score:15.0 Actor_Loss:-0.4046310484409332 Critic_Loss:2.6260292530059814
# Episode:63 Score:9.0 Actor_Loss:-2.8716015815734863 Critic_Loss:3.9747259616851807
# Episode:64 Score:36.0 Actor_Loss:4.995785713195801 Critic_Loss:9.122304916381836
# Episode:65 Score:17.0 Actor_Loss:-1.2096645832061768 Critic_Loss:4.8453593254089355
# Episode:66 Score:39.0 Actor_Loss:4.907532691955566 Critic_Loss:10.027671813964844
# Episode:67 Score:12.0 Actor_Loss:-2.3012449741363525 Critic_Loss:3.2865171432495117
# Episode:68 Score:13.0 Actor_Loss:-2.3182356357574463 Critic_Loss:3.357926845550537
# Episode:69 Score:46.0 Actor_Loss:7.446498870849609 Critic_Loss:12.240091323852539
# Episode:70 Score:11.0 Actor_Loss:-1.8387738466262817 Critic_Loss:2.6893553733825684
# Episode:71 Score:22.0 Actor_Loss:0.5827127695083618 Critic_Loss:5.333481311798096
# Episode:72 Score:39.0 Actor_Loss:6.215816020965576 Critic_Loss:10.310392379760742
# Episode:73 Score:32.0 Actor_Loss:2.7126083374023438 Critic_Loss:8.410859107971191
# Episode:74 Score:21.0 Actor_Loss:0.6671719551086426 Critic_Loss:4.109987735748291
# Episode:75 Score:27.0 Actor_Loss:3.107564926147461 Critic_Loss:6.105923175811768
# Episode:76 Score:24.0 Actor_Loss:1.5737766027450562 Critic_Loss:5.034316539764404
# Episode:77 Score:10.0 Actor_Loss:-3.4749197959899902 Critic_Loss:3.643437623977661
# Episode:78 Score:72.0 Actor_Loss:12.559677124023438 Critic_Loss:20.19203758239746
# Episode:79 Score:45.0 Actor_Loss:5.438643932342529 Critic_Loss:12.155649185180664
# Episode:80 Score:85.0 Actor_Loss:15.550350189208984 Critic_Loss:23.92081069946289
# Episode:81 Score:87.0 Actor_Loss:14.981398582458496 Critic_Loss:23.604015350341797
# Episode:82 Score:50.0 Actor_Loss:6.756840705871582 Critic_Loss:12.552966117858887
# Episode:83 Score:28.0 Actor_Loss:2.0132312774658203 Critic_Loss:5.8374199867248535
# Episode:84 Score:15.0 Actor_Loss:-3.2241790294647217 Critic_Loss:3.7488229274749756
# Episode:85 Score:84.0 Actor_Loss:11.952119827270508 Critic_Loss:21.742013931274414
# Episode:86 Score:53.0 Actor_Loss:7.622836589813232 Critic_Loss:13.473884582519531
# Episode:87 Score:21.0 Actor_Loss:-0.0042876629158854485 Critic_Loss:4.41439962387085
# Episode:88 Score:83.0 Actor_Loss:12.457934379577637 Critic_Loss:21.474544525146484
# Episode:89 Score:15.0 Actor_Loss:-2.4020285606384277 Critic_Loss:3.7475998401641846
# Episode:90 Score:102.0 Actor_Loss:14.167222023010254 Critic_Loss:24.868492126464844
# Episode:91 Score:20.0 Actor_Loss:-0.42165476083755493 Critic_Loss:4.13315486907959
# Episode:92 Score:25.0 Actor_Loss:-1.9468176364898682 Critic_Loss:6.73452615737915
# Episode:93 Score:49.0 Actor_Loss:5.755926132202148 Critic_Loss:11.4243803024292
# Episode:94 Score:46.0 Actor_Loss:5.180370330810547 Critic_Loss:10.546266555786133
# Episode:95 Score:42.0 Actor_Loss:3.1727137565612793 Critic_Loss:9.020054817199707
# Episode:96 Score:20.0 Actor_Loss:-3.0260796546936035 Critic_Loss:5.365662574768066
# Episode:97 Score:11.0 Actor_Loss:-7.930718898773193 Critic_Loss:8.592758178710938
# Episode:98 Score:46.0 Actor_Loss:2.612891912460327 Critic_Loss:9.566797256469727
# Episode:99 Score:46.0 Actor_Loss:4.065528392791748 Critic_Loss:10.067863464355469
# Episode:100 Score:79.0 Actor_Loss:10.063216209411621 Critic_Loss:18.20412254333496
# Episode:101 Score:60.0 Actor_Loss:7.246057987213135 Critic_Loss:14.166244506835938
# Episode:102 Score:74.0 Actor_Loss:9.139848709106445 Critic_Loss:17.50762939453125
# Episode:103 Score:79.0 Actor_Loss:8.531000137329102 Critic_Loss:18.1049747467041
# Episode:104 Score:39.0 Actor_Loss:1.3241033554077148 Critic_Loss:7.286664962768555
# Episode:105 Score:71.0 Actor_Loss:7.9149651527404785 Critic_Loss:15.5233736038208
# Episode:106 Score:66.0 Actor_Loss:3.9386720657348633 Critic_Loss:19.659915924072266
# Episode:107 Score:88.0 Actor_Loss:9.141472816467285 Critic_Loss:19.587635040283203
# Episode:108 Score:34.0 Actor_Loss:0.32428938150405884 Critic_Loss:7.354129791259766
# Episode:109 Score:73.0 Actor_Loss:5.338489055633545 Critic_Loss:17.099592208862305
# Episode:110 Score:31.0 Actor_Loss:-2.081542730331421 Critic_Loss:7.345243453979492
# Episode:111 Score:27.0 Actor_Loss:-2.269615411758423 Critic_Loss:6.873256683349609
# Episode:112 Score:54.0 Actor_Loss:2.3450143337249756 Critic_Loss:10.274055480957031
# Episode:113 Score:21.0 Actor_Loss:-8.157621383666992 Critic_Loss:7.899501323699951
# Episode:114 Score:53.0 Actor_Loss:1.3571193218231201 Critic_Loss:12.57396411895752
# Episode:115 Score:32.0 Actor_Loss:-2.802051067352295 Critic_Loss:6.209589958190918
# Episode:116 Score:117.0 Actor_Loss:8.699170112609863 Critic_Loss:20.734893798828125
# Episode:117 Score:77.0 Actor_Loss:5.4203619956970215 Critic_Loss:14.559292793273926
# Episode:118 Score:94.0 Actor_Loss:8.210103988647461 Critic_Loss:19.89155387878418
# Episode:119 Score:28.0 Actor_Loss:-3.890972852706909 Critic_Loss:5.436856746673584
# Episode:120 Score:88.0 Actor_Loss:8.591562271118164 Critic_Loss:18.976037979125977
# Episode:121 Score:76.0 Actor_Loss:7.022169589996338 Critic_Loss:16.134319305419922
# Episode:122 Score:64.0 Actor_Loss:3.6839420795440674 Critic_Loss:11.896211624145508
# Episode:123 Score:39.0 Actor_Loss:0.7563824653625488 Critic_Loss:9.5010986328125
# Episode:124 Score:96.0 Actor_Loss:6.278797626495361 Critic_Loss:20.26420783996582
# Episode:125 Score:29.0 Actor_Loss:-3.0229599475860596 Critic_Loss:6.455366611480713
# Episode:126 Score:27.0 Actor_Loss:-3.0592544078826904 Critic_Loss:6.324009418487549
# Episode:127 Score:96.0 Actor_Loss:9.89533519744873 Critic_Loss:20.63568687438965
# Episode:128 Score:21.0 Actor_Loss:-5.662090301513672 Critic_Loss:9.846832275390625
# Episode:129 Score:23.0 Actor_Loss:-5.173985481262207 Critic_Loss:6.659912109375
# Episode:130 Score:50.0 Actor_Loss:2.4688024520874023 Critic_Loss:11.085296630859375
# Episode:131 Score:157.0 Actor_Loss:16.75288200378418 Critic_Loss:31.60655975341797
# Episode:132 Score:97.0 Actor_Loss:10.480355262756348 Critic_Loss:20.609621047973633
# Episode:133 Score:68.0 Actor_Loss:5.124055862426758 Critic_Loss:14.307195663452148
# Episode:134 Score:178.0 Actor_Loss:18.371416091918945 Critic_Loss:36.77010726928711
# Episode:135 Score:116.0 Actor_Loss:12.84427261352539 Critic_Loss:24.8509521484375
# Episode:136 Score:67.0 Actor_Loss:5.308628559112549 Critic_Loss:14.168889045715332
# Episode:137 Score:42.0 Actor_Loss:0.1255546510219574 Critic_Loss:7.873943328857422
# Episode:138 Score:72.0 Actor_Loss:5.283842086791992 Critic_Loss:14.747597694396973
# Episode:139 Score:60.0 Actor_Loss:2.0559566020965576 Critic_Loss:12.406828880310059
# Episode:140 Score:52.0 Actor_Loss:2.4388933181762695 Critic_Loss:12.441336631774902
# Episode:141 Score:106.0 Actor_Loss:8.569337844848633 Critic_Loss:21.393600463867188
# Episode:142 Score:53.0 Actor_Loss:-0.813686728477478 Critic_Loss:10.650247573852539
# Episode:143 Score:78.0 Actor_Loss:5.997421741485596 Critic_Loss:14.516437530517578
# Episode:144 Score:105.0 Actor_Loss:9.47012996673584 Critic_Loss:19.863847732543945
# Episode:145 Score:94.0 Actor_Loss:7.4547834396362305 Critic_Loss:18.499496459960938
# Episode:146 Score:79.0 Actor_Loss:4.521524906158447 Critic_Loss:15.296040534973145
# Episode:147 Score:20.0 Actor_Loss:-6.704507350921631 Critic_Loss:13.372164726257324
# Episode:148 Score:76.0 Actor_Loss:4.78920316696167 Critic_Loss:14.408693313598633
# Episode:149 Score:64.0 Actor_Loss:0.9859977960586548 Critic_Loss:10.591123580932617
# Episode:150 Score:260.0 Actor_Loss:21.49492645263672 Critic_Loss:40.490230560302734
# Episode:151 Score:36.0 Actor_Loss:-3.51937198638916 Critic_Loss:9.23321533203125
# Episode:152 Score:33.0 Actor_Loss:-5.485751152038574 Critic_Loss:10.0263032913208
# Episode:153 Score:58.0 Actor_Loss:-1.7865312099456787 Critic_Loss:10.792627334594727
# Episode:154 Score:105.0 Actor_Loss:8.75131893157959 Critic_Loss:18.98255729675293
# Episode:155 Score:147.0 Actor_Loss:12.385567665100098 Critic_Loss:27.00133514404297
# Episode:156 Score:108.0 Actor_Loss:8.48131275177002 Critic_Loss:20.01108169555664
# Episode:157 Score:61.0 Actor_Loss:0.05927154794335365 Critic_Loss:11.454438209533691
# Episode:158 Score:45.0 Actor_Loss:-1.7201550006866455 Critic_Loss:10.529291152954102
# Episode:159 Score:40.0 Actor_Loss:-4.426547050476074 Critic_Loss:10.174198150634766
# Episode:160 Score:74.0 Actor_Loss:2.5456933975219727 Critic_Loss:12.310315132141113
# Episode:161 Score:51.0 Actor_Loss:-1.1778030395507812 Critic_Loss:9.748205184936523
# Episode:162 Score:34.0 Actor_Loss:-3.21894907951355 Critic_Loss:11.52849006652832
# Episode:163 Score:233.0 Actor_Loss:18.875659942626953 Critic_Loss:37.46653366088867
# Episode:164 Score:104.0 Actor_Loss:6.9830827713012695 Critic_Loss:18.797462463378906
# Episode:165 Score:92.0 Actor_Loss:4.746272087097168 Critic_Loss:17.438295364379883
# Episode:166 Score:123.0 Actor_Loss:8.94201946258545 Critic_Loss:22.100709915161133
# Episode:167 Score:64.0 Actor_Loss:-0.06194888800382614 Critic_Loss:10.326677322387695
# Episode:168 Score:98.0 Actor_Loss:5.426013946533203 Critic_Loss:17.08133316040039
# Episode:169 Score:27.0 Actor_Loss:-5.70886754989624 Critic_Loss:14.85224723815918
# Episode:170 Score:50.0 Actor_Loss:-4.271907329559326 Critic_Loss:10.681718826293945
# Episode:171 Score:69.0 Actor_Loss:2.16373872756958 Critic_Loss:12.419960021972656
# Episode:172 Score:73.0 Actor_Loss:1.1811026334762573 Critic_Loss:12.510470390319824
# Episode:173 Score:188.0 Actor_Loss:15.14148998260498 Critic_Loss:31.36993980407715
# Episode:174 Score:352.0 Actor_Loss:20.583961486816406 Critic_Loss:45.414371490478516
# Episode:175 Score:144.0 Actor_Loss:11.104125022888184 Critic_Loss:24.712717056274414
# Episode:176 Score:123.0 Actor_Loss:7.125446319580078 Critic_Loss:21.178937911987305
# Episode:177 Score:47.0 Actor_Loss:-3.0953593254089355 Critic_Loss:10.467549324035645
# Episode:178 Score:91.0 Actor_Loss:3.9252543449401855 Critic_Loss:15.851030349731445
# Episode:179 Score:66.0 Actor_Loss:-0.0010310086654499173 Critic_Loss:12.706314086914062
# Episode:180 Score:49.0 Actor_Loss:-0.7650889754295349 Critic_Loss:11.540046691894531
# Episode:181 Score:86.0 Actor_Loss:3.522883176803589 Critic_Loss:14.400494575500488
# Episode:182 Score:117.0 Actor_Loss:4.491926193237305 Critic_Loss:18.678895950317383
# Episode:183 Score:29.0 Actor_Loss:-8.196434020996094 Critic_Loss:16.615615844726562
# Episode:184 Score:63.0 Actor_Loss:-1.2337696552276611 Critic_Loss:12.142477989196777
# Episode:185 Score:241.0 Actor_Loss:15.32650375366211 Critic_Loss:34.81968307495117
# Episode:186 Score:225.0 Actor_Loss:15.270705223083496 Critic_Loss:34.06299591064453
# Episode:187 Score:83.0 Actor_Loss:0.31299668550491333 Critic_Loss:13.167635917663574
# Episode:188 Score:140.0 Actor_Loss:7.308521270751953 Critic_Loss:23.090621948242188
# Episode:189 Score:116.0 Actor_Loss:6.163772106170654 Critic_Loss:18.523685455322266
# Episode:190 Score:128.0 Actor_Loss:6.84197473526001 Critic_Loss:20.06388282775879
# Episode:191 Score:150.0 Actor_Loss:9.06213665008545 Critic_Loss:23.464265823364258
# Episode:192 Score:271.0 Actor_Loss:15.388789176940918 Critic_Loss:36.38115692138672
# Episode:193 Score:57.0 Actor_Loss:-5.529257774353027 Critic_Loss:12.049607276916504
# Episode:194 Score:226.0 Actor_Loss:12.839876174926758 Critic_Loss:31.07280158996582
# Episode:195 Score:342.0 Actor_Loss:16.92228889465332 Critic_Loss:39.83133316040039
# Episode:196 Score:29.0 Actor_Loss:-13.480181694030762 Critic_Loss:22.18574333190918
# Episode:197 Score:111.0 Actor_Loss:2.6870057582855225 Critic_Loss:17.109033584594727
# Episode:198 Score:181.0 Actor_Loss:9.5610933303833 Critic_Loss:25.230987548828125
# Episode:199 Score:88.0 Actor_Loss:-1.9034839868545532 Critic_Loss:14.360797882080078
# Episode:200 Score:449.0 Actor_Loss:22.240812301635742 Critic_Loss:43.210121154785156
# Episode:201 Score:32.0 Actor_Loss:-15.965995788574219 Critic_Loss:23.197223663330078
# Episode:202 Score:447.0 Actor_Loss:20.440793991088867 Critic_Loss:42.26936340332031
# Episode:203 Score:140.0 Actor_Loss:4.397514820098877 Critic_Loss:19.330318450927734
# Episode:204 Score:210.0 Actor_Loss:9.314579010009766 Critic_Loss:26.40089988708496
# Episode:205 Score:55.0 Actor_Loss:-7.540408611297607 Critic_Loss:17.606035232543945
# Episode:206 Score:500.0 Actor_Loss:23.156652450561523 Critic_Loss:46.4278564453125
# Episode:207 Score:252.0 Actor_Loss:11.283522605895996 Critic_Loss:29.342927932739258
# Episode:208 Score:274.0 Actor_Loss:12.377436637878418 Critic_Loss:30.513490676879883
# Episode:209 Score:213.0 Actor_Loss:7.72960901260376 Critic_Loss:24.920068740844727
# Episode:210 Score:500.0 Actor_Loss:20.394926071166992 Critic_Loss:43.11591720581055
# Episode:211 Score:407.0 Actor_Loss:15.75514030456543 Critic_Loss:36.42120361328125
# Episode:212 Score:192.0 Actor_Loss:5.3110432624816895 Critic_Loss:21.910667419433594
# Episode:213 Score:478.0 Actor_Loss:16.304508209228516 Critic_Loss:36.568695068359375
# Episode:214 Score:146.0 Actor_Loss:-0.08628291636705399 Critic_Loss:17.857709884643555
# Episode:215 Score:242.0 Actor_Loss:7.9665846824646 Critic_Loss:24.652267456054688
# Episode:216 Score:146.0 Actor_Loss:-0.7311875820159912 Critic_Loss:18.861541748046875
# Episode:217 Score:106.0 Actor_Loss:-4.662154197692871 Critic_Loss:21.654943466186523
# Episode:218 Score:500.0 Actor_Loss:16.820472717285156 Critic_Loss:34.30679702758789
# Episode:219 Score:500.0 Actor_Loss:16.47280502319336 Critic_Loss:33.69505310058594
# Episode:220 Score:500.0 Actor_Loss:13.916749000549316 Critic_Loss:30.34583854675293
# Episode:221 Score:123.0 Actor_Loss:-9.090312004089355 Critic_Loss:20.624042510986328
# Episode:222 Score:465.0 Actor_Loss:8.435837745666504 Critic_Loss:26.957033157348633
# Episode:223 Score:500.0 Actor_Loss:14.303518295288086 Critic_Loss:27.944114685058594
# Episode:224 Score:500.0 Actor_Loss:13.617936134338379 Critic_Loss:26.21200180053711
# Episode:225 Score:500.0 Actor_Loss:14.531771659851074 Critic_Loss:28.171842575073242
# Episode:226 Score:500.0 Actor_Loss:11.470954895019531 Critic_Loss:22.986127853393555
# Episode:227 Score:500.0 Actor_Loss:10.206859588623047 Critic_Loss:20.645463943481445
# Episode:228 Score:500.0 Actor_Loss:10.229187965393066 Critic_Loss:21.082237243652344
# Episode:229 Score:500.0 Actor_Loss:6.412489414215088 Critic_Loss:14.921185493469238
# Episode:230 Score:500.0 Actor_Loss:4.755056858062744 Critic_Loss:13.512056350708008
# Episode:231 Score:500.0 Actor_Loss:4.1401567459106445 Critic_Loss:11.296379089355469
# Episode:232 Score:485.0 Actor_Loss:-5.744963645935059 Critic_Loss:19.487794876098633
# Episode:233 Score:500.0 Actor_Loss:2.3152198791503906 Critic_Loss:8.387948036193848
# Episode:234 Score:500.0 Actor_Loss:0.17692513763904572 Critic_Loss:9.542007446289062
# Episode:235 Score:500.0 Actor_Loss:0.5062663555145264 Critic_Loss:9.551575660705566
# Episode:236 Score:447.0 Actor_Loss:-9.639841079711914 Critic_Loss:28.41611671447754
# Episode:237 Score:222.0 Actor_Loss:-19.7158203125 Critic_Loss:41.25737762451172
# Episode:238 Score:68.0 Actor_Loss:-30.2325439453125 Critic_Loss:77.32921600341797
# Episode:239 Score:500.0 Actor_Loss:-0.24243763089179993 Critic_Loss:6.823801040649414
# Episode:240 Score:500.0 Actor_Loss:-0.9214441776275635 Critic_Loss:8.319037437438965
# Episode:241 Score:500.0 Actor_Loss:-0.9854711294174194 Critic_Loss:5.033458709716797
# Episode:242 Score:363.0 Actor_Loss:-15.199383735656738 Critic_Loss:29.45328712463379
# Episode:243 Score:500.0 Actor_Loss:1.1327811479568481 Critic_Loss:7.246332168579102
# Episode:244 Score:500.0 Actor_Loss:-0.770272970199585 Critic_Loss:3.754041910171509
# Episode:245 Score:500.0 Actor_Loss:-1.0276163816452026 Critic_Loss:4.253898620605469
# Episode:246 Score:500.0 Actor_Loss:-0.13258008658885956 Critic_Loss:2.9494009017944336
# Episode:247 Score:500.0 Actor_Loss:-0.5010960102081299 Critic_Loss:2.7090706825256348
# Episode:248 Score:500.0 Actor_Loss:0.14915938675403595 Critic_Loss:2.344390630722046
# Episode:249 Score:500.0 Actor_Loss:-0.4611406624317169 Critic_Loss:2.195826768875122
# Episode:250 Score:500.0 Actor_Loss:-0.19728033244609833 Critic_Loss:1.529871940612793
# Episode:251 Score:500.0 Actor_Loss:0.29176461696624756 Critic_Loss:1.760614037513733
# Episode:252 Score:500.0 Actor_Loss:-0.7338359355926514 Critic_Loss:1.8136829137802124
# Episode:253 Score:500.0 Actor_Loss:-0.3278968632221222 Critic_Loss:0.8762043118476868
# Episode:254 Score:500.0 Actor_Loss:-0.6017205715179443 Critic_Loss:1.2425366640090942
# Episode:255 Score:500.0 Actor_Loss:-0.6842359900474548 Critic_Loss:0.9634802937507629
# Episode:256 Score:500.0 Actor_Loss:-0.21564486622810364 Critic_Loss:0.5391399264335632
# Episode:257 Score:500.0 Actor_Loss:0.05192374810576439 Critic_Loss:0.5342844128608704
# Episode:258 Score:500.0 Actor_Loss:0.3140775263309479 Critic_Loss:0.5788151621818542
# Episode:259 Score:500.0 Actor_Loss:-0.013524286448955536 Critic_Loss:0.8188689351081848
# Episode:260 Score:500.0 Actor_Loss:0.07975709438323975 Critic_Loss:0.5906306505203247
# Episode:261 Score:500.0 Actor_Loss:0.1957121342420578 Critic_Loss:0.17543138563632965
# Episode:262 Score:500.0 Actor_Loss:-0.07410577684640884 Critic_Loss:0.10060123354196548
# Episode:263 Score:500.0 Actor_Loss:-0.2619432508945465 Critic_Loss:0.23003576695919037
# Episode:264 Score:500.0 Actor_Loss:-0.2369072437286377 Critic_Loss:0.19504010677337646
# Episode:265 Score:500.0 Actor_Loss:-0.18035773932933807 Critic_Loss:0.14837689697742462
# Episode:266 Score:500.0 Actor_Loss:-0.038357917219400406 Critic_Loss:0.09872625768184662
# Episode:267 Score:500.0 Actor_Loss:0.1301642507314682 Critic_Loss:0.15216238796710968
# Episode:268 Score:500.0 Actor_Loss:0.22344443202018738 Critic_Loss:0.17156094312667847
# Episode:269 Score:500.0 Actor_Loss:0.23579667508602142 Critic_Loss:0.14693115651607513
# Episode:270 Score:500.0 Actor_Loss:0.0627041682600975 Critic_Loss:0.03340718895196915
# Episode:271 Score:500.0 Actor_Loss:-0.09818893671035767 Critic_Loss:0.05369959771633148
# Episode:272 Score:500.0 Actor_Loss:-0.19523881375789642 Critic_Loss:0.10269419103860855
# Episode:273 Score:500.0 Actor_Loss:-0.17184945940971375 Critic_Loss:0.08499551564455032
# Episode:274 Score:500.0 Actor_Loss:-0.10518069565296173 Critic_Loss:0.03873187303543091
# Episode:275 Score:500.0 Actor_Loss:0.05221810191869736 Critic_Loss:0.016748622059822083
# Episode:276 Score:500.0 Actor_Loss:0.144242063164711 Critic_Loss:0.05979100242257118
# Episode:277 Score:500.0 Actor_Loss:0.12312095612287521 Critic_Loss:0.10009202361106873
# Episode:278 Score:500.0 Actor_Loss:0.1617199331521988 Critic_Loss:0.07779181748628616
# Episode:279 Score:500.0 Actor_Loss:0.02422522008419037 Critic_Loss:0.016162525862455368
# Episode:280 Score:500.0 Actor_Loss:-0.13525348901748657 Critic_Loss:0.05931403487920761
# Episode:281 Score:500.0 Actor_Loss:-0.17555081844329834 Critic_Loss:0.08126004040241241
# Episode:282 Score:500.0 Actor_Loss:-0.16300749778747559 Critic_Loss:0.11770984530448914
# Episode:283 Score:208.0 Actor_Loss:-20.512451171875 Critic_Loss:41.161434173583984
# Episode:284 Score:500.0 Actor_Loss:0.4331858456134796 Critic_Loss:0.48323482275009155
# Episode:285 Score:392.0 Actor_Loss:-10.8477783203125 Critic_Loss:22.91904067993164
# Episode:286 Score:419.0 Actor_Loss:-11.928685188293457 Critic_Loss:20.567501068115234
# Episode:287 Score:500.0 Actor_Loss:1.2748996019363403 Critic_Loss:2.262608289718628
# Episode:288 Score:500.0 Actor_Loss:1.77474045753479 Critic_Loss:3.1181106567382812
# Episode:289 Score:500.0 Actor_Loss:1.802053689956665 Critic_Loss:3.129075288772583
# Episode:290 Score:500.0 Actor_Loss:1.2886877059936523 Critic_Loss:2.4008123874664307
# Episode:291 Score:500.0 Actor_Loss:1.1055183410644531 Critic_Loss:1.7193186283111572
# Episode:292 Score:500.0 Actor_Loss:0.46514925360679626 Critic_Loss:0.8506582975387573
# Episode:293 Score:500.0 Actor_Loss:-0.0805293470621109 Critic_Loss:0.7780864238739014
# Episode:294 Score:500.0 Actor_Loss:-0.5470909476280212 Critic_Loss:0.6494112610816956
# Episode:295 Score:500.0 Actor_Loss:-0.6276038289070129 Critic_Loss:1.0986425876617432
# Episode:296 Score:500.0 Actor_Loss:-0.6863272190093994 Critic_Loss:1.5426040887832642
# Episode:297 Score:500.0 Actor_Loss:-0.6467126607894897 Critic_Loss:1.576363444328308
# Episode:298 Score:500.0 Actor_Loss:-0.8203274607658386 Critic_Loss:1.3848083019256592
# Episode:299 Score:500.0 Actor_Loss:-0.5284351110458374 Critic_Loss:0.6201667189598083
# Episode:300 Score:373.0 Actor_Loss:-9.653965950012207 Critic_Loss:25.710847854614258
# Episode:301 Score:500.0 Actor_Loss:0.1391105204820633 Critic_Loss:0.5646406412124634
# Episode:302 Score:500.0 Actor_Loss:0.7933999300003052 Critic_Loss:1.3233612775802612
# Episode:303 Score:500.0 Actor_Loss:0.9858140349388123 Critic_Loss:1.7240889072418213
# Episode:304 Score:500.0 Actor_Loss:1.1747088432312012 Critic_Loss:2.024386405944824
# Episode:305 Score:500.0 Actor_Loss:1.0423566102981567 Critic_Loss:1.7019888162612915
# Episode:306 Score:500.0 Actor_Loss:0.7705750465393066 Critic_Loss:1.1288363933563232
# Episode:307 Score:500.0 Actor_Loss:0.053907547146081924 Critic_Loss:0.5352869629859924
# Episode:308 Score:500.0 Actor_Loss:-0.1523190587759018 Critic_Loss:0.22278277575969696
# Episode:309 Score:500.0 Actor_Loss:-0.3374379277229309 Critic_Loss:0.36880016326904297
# Episode:310 Score:500.0 Actor_Loss:-0.2945461869239807 Critic_Loss:0.7994307279586792
# Episode:311 Score:500.0 Actor_Loss:-0.7246835827827454 Critic_Loss:1.205003261566162
# Episode:312 Score:500.0 Actor_Loss:-0.34838151931762695 Critic_Loss:0.6432476043701172
# Episode:313 Score:500.0 Actor_Loss:-0.37551748752593994 Critic_Loss:0.32818904519081116
# Episode:314 Score:500.0 Actor_Loss:-0.021229110658168793 Critic_Loss:0.24061517417430878
# Episode:315 Score:500.0 Actor_Loss:0.0827491283416748 Critic_Loss:0.15066896378993988
# Episode:316 Score:500.0 Actor_Loss:0.37431514263153076 Critic_Loss:0.35035672783851624
# Episode:317 Score:500.0 Actor_Loss:0.4695167541503906 Critic_Loss:0.4790765643119812
# Episode:318 Score:500.0 Actor_Loss:0.28073495626449585 Critic_Loss:0.29818567633628845
# Episode:319 Score:500.0 Actor_Loss:0.10281996428966522 Critic_Loss:0.031624216586351395
# Episode:320 Score:500.0 Actor_Loss:-0.1906173676252365 Critic_Loss:0.11821487545967102
# Episode:321 Score:500.0 Actor_Loss:-0.2769883871078491 Critic_Loss:0.21217018365859985
# Episode:322 Score:500.0 Actor_Loss:-0.2701929807662964 Critic_Loss:0.1937502920627594
# Episode:323 Score:500.0 Actor_Loss:-0.11149167269468307 Critic_Loss:0.14444485306739807
# Episode:324 Score:500.0 Actor_Loss:-0.0043691303580999374 Critic_Loss:0.039965856820344925
# Episode:325 Score:500.0 Actor_Loss:0.019221242517232895 Critic_Loss:0.02337694726884365
# Episode:326 Score:500.0 Actor_Loss:0.06882137805223465 Critic_Loss:0.1110406443476677
# Episode:327 Score:500.0 Actor_Loss:0.23031124472618103 Critic_Loss:0.17973195016384125
# Episode:328 Score:500.0 Actor_Loss:0.18520203232765198 Critic_Loss:0.0933922752737999
# Episode:329 Score:500.0 Actor_Loss:0.11247576773166656 Critic_Loss:0.07344630360603333
# Episode:330 Score:500.0 Actor_Loss:-0.006128363311290741 Critic_Loss:0.02786950021982193
# Episode:331 Score:500.0 Actor_Loss:-0.174460768699646 Critic_Loss:0.07588593661785126
# Episode:332 Score:500.0 Actor_Loss:-0.23323513567447662 Critic_Loss:0.16321250796318054
# Episode:333 Score:500.0 Actor_Loss:-0.1463935673236847 Critic_Loss:0.05451013147830963
# Episode:334 Score:500.0 Actor_Loss:-0.02928205579519272 Critic_Loss:0.024028027430176735
# Episode:335 Score:500.0 Actor_Loss:0.15710462629795074 Critic_Loss:0.10091033577919006
# Episode:336 Score:500.0 Actor_Loss:0.1091371402144432 Critic_Loss:0.03342742100358009
# Episode:337 Score:500.0 Actor_Loss:0.07659830152988434 Critic_Loss:0.06024077907204628
# Episode:338 Score:500.0 Actor_Loss:0.027981912717223167 Critic_Loss:0.09910164773464203
# Episode:339 Score:500.0 Actor_Loss:0.016874870285391808 Critic_Loss:0.002881482010707259
# Episode:340 Score:500.0 Actor_Loss:-0.013711749576032162 Critic_Loss:0.06166861578822136
# Episode:341 Score:500.0 Actor_Loss:-0.05015163868665695 Critic_Loss:0.051445409655570984
# Episode:342 Score:500.0 Actor_Loss:-0.09032376855611801 Critic_Loss:0.023136857897043228
# Episode:343 Score:500.0 Actor_Loss:-0.14351479709148407 Critic_Loss:0.07332128286361694
# Episode:344 Score:500.0 Actor_Loss:0.014649680815637112 Critic_Loss:0.017661385238170624
# Episode:345 Score:500.0 Actor_Loss:0.05516323819756508 Critic_Loss:0.0133425397798419
# Episode:346 Score:500.0 Actor_Loss:0.13021141290664673 Critic_Loss:0.05092276260256767
# Episode:347 Score:500.0 Actor_Loss:0.07303230464458466 Critic_Loss:0.01467891875654459
# Episode:348 Score:500.0 Actor_Loss:0.013337933458387852 Critic_Loss:0.015241156332194805
# Episode:349 Score:500.0 Actor_Loss:-0.046918656677007675 Critic_Loss:0.028731243684887886
# Episode:350 Score:500.0 Actor_Loss:-0.055792223662137985 Critic_Loss:0.008086252957582474
# Episode:351 Score:500.0 Actor_Loss:-0.0505184680223465 Critic_Loss:0.027586771175265312
# Episode:352 Score:500.0 Actor_Loss:-0.02399803139269352 Critic_Loss:0.0240824855864048
# Episode:353 Score:500.0 Actor_Loss:-0.03288193419575691 Critic_Loss:0.0033860737457871437
# Episode:354 Score:500.0 Actor_Loss:-0.010723692364990711 Critic_Loss:0.04327414929866791
# Episode:355 Score:500.0 Actor_Loss:0.035805489867925644 Critic_Loss:0.004321213345974684
# Episode:356 Score:500.0 Actor_Loss:0.03320418298244476 Critic_Loss:0.015063234604895115
# Episode:357 Score:500.0 Actor_Loss:0.031368788331747055 Critic_Loss:0.014551617205142975
# Episode:358 Score:500.0 Actor_Loss:0.03338965028524399 Critic_Loss:0.0037067346274852753
# Episode:359 Score:500.0 Actor_Loss:0.0009134648134931922 Critic_Loss:0.008277900516986847
# Episode:360 Score:500.0 Actor_Loss:-0.04666891694068909 Critic_Loss:0.024034496396780014
# Episode:361 Score:500.0 Actor_Loss:-0.02452670969069004 Critic_Loss:0.004775316454470158
# Episode:362 Score:500.0 Actor_Loss:-0.002853211248293519 Critic_Loss:0.0247108805924654
# Episode:363 Score:500.0 Actor_Loss:-0.010007376782596111 Critic_Loss:0.005082441959530115
# Episode:364 Score:500.0 Actor_Loss:-0.008072065189480782 Critic_Loss:0.005310731008648872
# Episode:365 Score:500.0 Actor_Loss:-0.015299557708203793 Critic_Loss:0.014814983122050762
# Episode:366 Score:500.0 Actor_Loss:0.00895704049617052 Critic_Loss:0.004820976406335831
# Episode:367 Score:500.0 Actor_Loss:0.03864360973238945 Critic_Loss:0.007352224551141262
# Episode:368 Score:500.0 Actor_Loss:0.05160049721598625 Critic_Loss:0.016871115192770958
# Episode:369 Score:500.0 Actor_Loss:0.0036359152290970087 Critic_Loss:0.0013240057742223144
# Episode:370 Score:500.0 Actor_Loss:-0.03665103390812874 Critic_Loss:0.009052467532455921
# Episode:371 Score:500.0 Actor_Loss:-0.04301485791802406 Critic_Loss:0.009862519800662994
# Episode:372 Score:500.0 Actor_Loss:-0.029275154694914818 Critic_Loss:0.0034927644301205873
# Episode:373 Score:500.0 Actor_Loss:-0.003991702105849981 Critic_Loss:0.010017810389399529
# Episode:374 Score:500.0 Actor_Loss:0.016979750245809555 Critic_Loss:0.005329398438334465
# Episode:375 Score:500.0 Actor_Loss:0.020867103710770607 Critic_Loss:0.002618558704853058
# Episode:376 Score:500.0 Actor_Loss:0.013174793682992458 Critic_Loss:0.007343826815485954
# Episode:377 Score:500.0 Actor_Loss:0.019280126318335533 Critic_Loss:0.005982216447591782
# Episode:378 Score:500.0 Actor_Loss:0.012259378097951412 Critic_Loss:0.0012794840149581432
# Episode:379 Score:500.0 Actor_Loss:-0.017586950212717056 Critic_Loss:0.00583173893392086
# Episode:380 Score:500.0 Actor_Loss:-0.014186090789735317 Critic_Loss:0.003966555465012789
# Episode:381 Score:500.0 Actor_Loss:-0.013523653149604797 Critic_Loss:0.0011898329248651862
# Episode:382 Score:500.0 Actor_Loss:-0.011928417719900608 Critic_Loss:0.004866940435022116
# Episode:383 Score:500.0 Actor_Loss:-0.00931501667946577 Critic_Loss:0.002239494351670146
# Episode:384 Score:500.0 Actor_Loss:0.010524691082537174 Critic_Loss:0.0023121831472963095
# Episode:385 Score:500.0 Actor_Loss:0.027696335688233376 Critic_Loss:0.0047061387449502945
# Episode:386 Score:500.0 Actor_Loss:0.012941422872245312 Critic_Loss:0.0012728989822790027
# Episode:387 Score:500.0 Actor_Loss:0.0006980229518376291 Critic_Loss:0.002206666162237525
# Episode:388 Score:500.0 Actor_Loss:-0.008432228118181229 Critic_Loss:0.0033016277011483908
# Episode:389 Score:500.0 Actor_Loss:-0.020848847925662994 Critic_Loss:0.001501765800639987
# Episode:390 Score:500.0 Actor_Loss:-0.01434345357120037 Critic_Loss:0.0022760399151593447
# Episode:391 Score:500.0 Actor_Loss:0.007709663826972246 Critic_Loss:0.0026340861804783344
# Episode:392 Score:500.0 Actor_Loss:0.007272767834365368 Critic_Loss:0.0007787040085531771
# Episode:393 Score:500.0 Actor_Loss:-0.0014260985190048814 Critic_Loss:0.0027541208546608686
# Episode:394 Score:500.0 Actor_Loss:0.01115850917994976 Critic_Loss:0.002254053018987179
# Episode:395 Score:500.0 Actor_Loss:0.012537436559796333 Critic_Loss:0.001031851745210588
# Episode:396 Score:500.0 Actor_Loss:0.00862728338688612 Critic_Loss:0.001903077820315957
# Episode:397 Score:500.0 Actor_Loss:-0.003774168435484171 Critic_Loss:0.0012505404883995652
# Episode:398 Score:500.0 Actor_Loss:-0.016494903713464737 Critic_Loss:0.0020177788101136684
# Episode:399 Score:500.0 Actor_Loss:-0.019083172082901 Critic_Loss:0.0018557794392108917
# Episode:400 Score:500.0 Actor_Loss:-0.009065668098628521 Critic_Loss:0.0010290188947692513
# Episode:401 Score:500.0 Actor_Loss:0.005109231919050217 Critic_Loss:0.0015967529034242034
# Episode:402 Score:500.0 Actor_Loss:0.007905001752078533 Critic_Loss:0.0012329773744568229
# Episode:403 Score:500.0 Actor_Loss:0.005328753497451544 Critic_Loss:0.0008521764539182186
# Episode:404 Score:500.0 Actor_Loss:0.009136827662587166 Critic_Loss:0.001053761225193739
# Episode:405 Score:500.0 Actor_Loss:-0.005437891930341721 Critic_Loss:0.0017412673914805055
# Episode:406 Score:500.0 Actor_Loss:0.002812362741678953 Critic_Loss:0.0007045776583254337
# Episode:407 Score:500.0 Actor_Loss:-0.003216262673959136 Critic_Loss:0.0013014376163482666
# Episode:408 Score:500.0 Actor_Loss:-0.012707087211310863 Critic_Loss:0.005176241975277662
# Episode:409 Score:500.0 Actor_Loss:0.005900333635509014 Critic_Loss:0.0027795443311333656
# Episode:410 Score:500.0 Actor_Loss:0.003461277112364769 Critic_Loss:0.0013581541134044528
# Episode:411 Score:500.0 Actor_Loss:-0.018252447247505188 Critic_Loss:0.002386766253039241
# Episode:412 Score:500.0 Actor_Loss:0.0003317489172331989 Critic_Loss:0.0009363559656776488
# Episode:413 Score:500.0 Actor_Loss:0.006755287759006023 Critic_Loss:0.0007816180004738271
# Episode:414 Score:500.0 Actor_Loss:0.008241012692451477 Critic_Loss:0.000927587563637644
# Episode:415 Score:500.0 Actor_Loss:0.004771018400788307 Critic_Loss:0.0008214444969780743
# Episode:416 Score:500.0 Actor_Loss:-0.0010849934769794345 Critic_Loss:0.0006887679919600487
# Episode:417 Score:500.0 Actor_Loss:-0.011912593618035316 Critic_Loss:0.0022655329667031765
# Episode:418 Score:500.0 Actor_Loss:-0.004028819967061281 Critic_Loss:0.0007646980811841786
# Episode:419 Score:500.0 Actor_Loss:0.009459913708269596 Critic_Loss:0.0016842606710270047
# Episode:420 Score:500.0 Actor_Loss:0.0011474458733573556 Critic_Loss:0.0016793274553492665
# Episode:421 Score:500.0 Actor_Loss:-0.001550709130242467 Critic_Loss:0.0007713388768024743
# Episode:422 Score:500.0 Actor_Loss:-0.0034791098441928625 Critic_Loss:0.0012143439380452037
# Episode:423 Score:500.0 Actor_Loss:-0.0007677850662730634 Critic_Loss:0.0008574053645133972
# Episode:424 Score:500.0 Actor_Loss:-0.0004463225486688316 Critic_Loss:0.0007466874667443335
# Episode:425 Score:130.0 Actor_Loss:-26.58770751953125 Critic_Loss:55.038108825683594
# Episode:426 Score:500.0 Actor_Loss:0.2495565116405487 Critic_Loss:0.21214799582958221
# Episode:427 Score:500.0 Actor_Loss:0.2954643666744232 Critic_Loss:0.21702907979488373
# Episode:428 Score:500.0 Actor_Loss:0.2658499479293823 Critic_Loss:0.1687965989112854
# Episode:429 Score:500.0 Actor_Loss:0.07556059956550598 Critic_Loss:0.07762399315834045
# Episode:430 Score:500.0 Actor_Loss:-0.07983218133449554 Critic_Loss:0.03401108831167221
# Episode:431 Score:500.0 Actor_Loss:-0.2060675323009491 Critic_Loss:0.11414510756731033
# Episode:432 Score:500.0 Actor_Loss:-0.1771542727947235 Critic_Loss:0.15862824022769928
# Episode:433 Score:500.0 Actor_Loss:-0.1772853285074234 Critic_Loss:0.10186361521482468
# Episode:434 Score:500.0 Actor_Loss:-0.03084133192896843 Critic_Loss:0.0041746762581169605
# Episode:435 Score:500.0 Actor_Loss:0.07833220064640045 Critic_Loss:0.052004605531692505
# Episode:436 Score:500.0 Actor_Loss:0.1838986873626709 Critic_Loss:0.0939488634467125
# Episode:437 Score:500.0 Actor_Loss:0.16804619133472443 Critic_Loss:0.07222183793783188
# Episode:438 Score:500.0 Actor_Loss:0.0901566743850708 Critic_Loss:0.02363535948097706
# Episode:439 Score:500.0 Actor_Loss:-0.02179003693163395 Critic_Loss:0.00644129142165184
# Episode:440 Score:500.0 Actor_Loss:-0.12155396491289139 Critic_Loss:0.03823571652173996
# Episode:441 Score:500.0 Actor_Loss:-0.1483917236328125 Critic_Loss:0.05907275527715683
# Episode:442 Score:500.0 Actor_Loss:-0.12124986946582794 Critic_Loss:0.03569299727678299
# Episode:443 Score:500.0 Actor_Loss:-0.024662863463163376 Critic_Loss:0.0021389552857726812
# Episode:444 Score:500.0 Actor_Loss:0.06528270989656448 Critic_Loss:0.012990311719477177
# Episode:445 Score:500.0 Actor_Loss:0.12260730564594269 Critic_Loss:0.03902176022529602
# Episode:446 Score:500.0 Actor_Loss:0.10775211453437805 Critic_Loss:0.03385227173566818
# Episode:447 Score:500.0 Actor_Loss:0.0496959462761879 Critic_Loss:0.015611916780471802
# Episode:448 Score:500.0 Actor_Loss:-0.026323487982153893 Critic_Loss:0.003245539730414748
# Episode:449 Score:500.0 Actor_Loss:-0.057687610387802124 Critic_Loss:0.015044614672660828
# Episode:450 Score:500.0 Actor_Loss:-0.10353171825408936 Critic_Loss:0.036739204078912735
# Episode:451 Score:500.0 Actor_Loss:-0.0636405348777771 Critic_Loss:0.013301664032042027
# Episode:452 Score:500.0 Actor_Loss:-0.016585422679781914 Critic_Loss:0.002436572453007102
# Episode:453 Score:500.0 Actor_Loss:0.03487982973456383 Critic_Loss:0.011499473825097084
# Episode:454 Score:500.0 Actor_Loss:0.06892015039920807 Critic_Loss:0.0132376030087471
# Episode:455 Score:500.0 Actor_Loss:0.07202513515949249 Critic_Loss:0.01281229592859745
# Episode:456 Score:500.0 Actor_Loss:0.03316288813948631 Critic_Loss:0.003946963232010603
# Episode:457 Score:500.0 Actor_Loss:-0.02005915157496929 Critic_Loss:0.001514354720711708
# Episode:458 Score:500.0 Actor_Loss:-0.05322200059890747 Critic_Loss:0.007090983912348747
# Episode:459 Score:500.0 Actor_Loss:-0.05384373292326927 Critic_Loss:0.007970297709107399
# Episode:460 Score:500.0 Actor_Loss:-0.04547886177897453 Critic_Loss:0.00536549324169755
# Episode:461 Score:500.0 Actor_Loss:0.008901081047952175 Critic_Loss:0.0025415874551981688
# Episode:462 Score:500.0 Actor_Loss:0.03364592790603638 Critic_Loss:0.003790239803493023
# Episode:463 Score:500.0 Actor_Loss:0.035537607967853546 Critic_Loss:0.0045862323604524136
# Episode:464 Score:500.0 Actor_Loss:0.02791932225227356 Critic_Loss:0.005592299625277519
# Episode:465 Score:500.0 Actor_Loss:0.009129288606345654 Critic_Loss:0.001457930076867342
# Episode:466 Score:500.0 Actor_Loss:-0.006208839360624552 Critic_Loss:0.0006468250649049878
# Episode:467 Score:500.0 Actor_Loss:-0.022263359278440475 Critic_Loss:0.003057733876630664
# Episode:468 Score:500.0 Actor_Loss:-0.027754485607147217 Critic_Loss:0.003365684999153018
# Episode:469 Score:500.0 Actor_Loss:-0.0243722815066576 Critic_Loss:0.002025311579927802
# Episode:470 Score:500.0 Actor_Loss:-0.008286255411803722 Critic_Loss:0.0009062481694854796
# Episode:471 Score:500.0 Actor_Loss:0.006443667225539684 Critic_Loss:0.0011488054879009724
# Episode:472 Score:500.0 Actor_Loss:0.02032364159822464 Critic_Loss:0.00172999722417444
# Episode:473 Score:500.0 Actor_Loss:0.025647353380918503 Critic_Loss:0.0024320287629961967
# Episode:474 Score:500.0 Actor_Loss:0.009920877404510975 Critic_Loss:0.0011009610025212169
# Episode:475 Score:500.0 Actor_Loss:-0.0021279125940054655 Critic_Loss:0.0004620541294571012
# Episode:476 Score:500.0 Actor_Loss:0.0005530420457944274 Critic_Loss:0.0019633967895060778
# Episode:477 Score:500.0 Actor_Loss:-0.02811594307422638 Critic_Loss:0.00248383404687047
# Episode:478 Score:500.0 Actor_Loss:-0.026782358065247536 Critic_Loss:0.002538497094064951
# Episode:479 Score:500.0 Actor_Loss:-0.011074588634073734 Critic_Loss:0.0017888316651806235
# Episode:480 Score:500.0 Actor_Loss:0.0140769612044096 Critic_Loss:0.0010809698142111301
# Episode:481 Score:500.0 Actor_Loss:0.023545823991298676 Critic_Loss:0.002513232408091426
# Episode:482 Score:500.0 Actor_Loss:0.0206897109746933 Critic_Loss:0.0029378458857536316
# Episode:483 Score:500.0 Actor_Loss:0.0035952390171587467 Critic_Loss:0.001215708558447659
# Episode:484 Score:500.0 Actor_Loss:-0.0049272398464381695 Critic_Loss:0.0017776020104065537
# Episode:485 Score:500.0 Actor_Loss:-0.009674934670329094 Critic_Loss:0.002265256829559803
# Episode:486 Score:500.0 Actor_Loss:-0.02362102083861828 Critic_Loss:0.0018926538759842515
# Episode:487 Score:500.0 Actor_Loss:-0.027536606416106224 Critic_Loss:0.0023321430198848248
# Episode:488 Score:500.0 Actor_Loss:-0.003202660707756877 Critic_Loss:0.0009390002232976258
# Episode:489 Score:500.0 Actor_Loss:0.01805776171386242 Critic_Loss:0.0015202532522380352
# Episode:490 Score:500.0 Actor_Loss:0.02594791352748871 Critic_Loss:0.00256046699360013
# Episode:491 Score:500.0 Actor_Loss:0.023933129385113716 Critic_Loss:0.002108718501403928
# Episode:492 Score:500.0 Actor_Loss:-0.006348483730107546 Critic_Loss:0.0013177281944081187
# Episode:493 Score:500.0 Actor_Loss:-0.02090640179812908 Critic_Loss:0.0019363261526450515
# Episode:494 Score:500.0 Actor_Loss:-0.020793339237570763 Critic_Loss:0.0016610432649031281
# Episode:495 Score:500.0 Actor_Loss:-0.010625491850078106 Critic_Loss:0.002135896822437644
# Episode:496 Score:500.0 Actor_Loss:-0.0020326157100498676 Critic_Loss:0.0012348596937954426
# Episode:497 Score:500.0 Actor_Loss:0.002880057319998741 Critic_Loss:0.0004453301662579179
# Episode:498 Score:500.0 Actor_Loss:0.009063931182026863 Critic_Loss:0.001886026351712644
# Episode:499 Score:500.0 Actor_Loss:0.015410935506224632 Critic_Loss:0.0013626652071252465

# %%
plt.plot(np.array(list(range(0, len(score)))), score, label='Score')
plt.plot(np.array(list(range(0, len(score), constant_for_average))), average_score, label='Average Score')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(actor_loss)))), actor_loss, label='Actor Loss')
plt.plot(np.array(list(range(0, len(actor_loss), constant_for_average))), average_actor_loss, label='Average Actor Loss')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(critic_loss)))), critic_loss, label='Critic Loss')
plt.plot(np.array(list(range(0, len(critic_loss), constant_for_average))), average_critic_loss, label='Average Critic Loss')
plt.legend()
plt.show()

# %%
torch.save(Actor, 'Hybrid_Actor_Network_V7(500_Episodes_2_classical_layers).pkl')
torch.save(Critic, 'Hybrid_Critic_Network_V7(500_Episodes_2_classical_layers).pkl')

# %%
file = open("Quantum_Score_Loss_V7(500_Episodes_2_classical_layers).txt", "x")
data = np.column_stack([score, actor_loss, critic_loss])
np.savetxt("Quantum_Score_Loss_V7(500_Episodes_2_classical_layers).txt",data)

# %%
total_params = sum(p.numel() for p in Actor.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 8579

# %%
total_params = sum(p.numel() for p in Critic.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 8450

# %%
print("Hello")
