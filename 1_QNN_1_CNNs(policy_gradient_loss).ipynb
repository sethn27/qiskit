# %% [markdown]
# #### Importing Librarires

# %%
import gym
import sys
import sys
import random

import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn 
import torch.nn.functional as F 
from torch.distributions.categorical import Categorical
from sklearn.preprocessing import normalize

import math as mt
import numpy as np
import matplotlib.pyplot as plt
'''import qiskit
from qiskit import transpile, assemble
from qiskit.visualization import *
import qiskit_machine_learning
from qiskit_machine_learning.neural_networks import SamplerQNN, CircuitQNN
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector'''

import qb.core
from qb.core import String, VectorString 
from qb.core.optimization import ParamCirc
sys.path.append('/mnt/qb/qristal/core/examples/python/qml')
from qb_qml_torch_wrapper import QuantumLayer

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class HybridActorNetwork(nn.Module):
    def __init__(self, 
                 state_space, 
                 action_space,
                 number_of_qubits = 1,
                 number_of_shots = 1024):
        super(HybridActorNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.number_of_qubits = number_of_qubits
        self.number_of_shots = number_of_shots

        self.qubits = [i for i in range(0, self.number_of_qubits)]
        self.quantum_circuit = ParamCirc(1)

        '''self.quantum_circuit = qiskit.QuantumCircuit(self.number_of_qubits)
        self.theta = qiskit.circuit.Parameter('theta')
        self.beta = qiskit.circuit.ParameterVector('beta', self.state_space)'''

        self.input_layer()
        self.parameterized_quantum_circuit()
        self.quantum_circuit.measure(0)
        '''quantum_neural_network = EstimatorQNN(circuit = self.quantum_circuit, 
                                              input_params = self.beta.params, 
                                              weight_params = [self.theta], 
                                              input_gradients = True)
        self.quantum_layer = TorchConnector(quantum_neural_network)'''

        self.quantum_layer = QuantumLayer(self.quantum_circuit)

        self.classical_layer_1 = nn.Linear(64, self.action_space)

    def input_layer(self):
        self.quantum_circuit.h(0)
        #self.quantum_circuit.barrier()

        self.quantum_circuit.rz(0, "input")
        self.quantum_circuit.ry(0, "input")
        self.quantum_circuit.rz(0, "input")
        #self.quantum_circuit.barrier()

    def parameterized_quantum_circuit(self):
        self.quantum_circuit.rx(0, "variational")
        #self.quantum_circuit.barrier()

    def forward(self, current_state):
        output_layer_1 = self.quantum_layer(current_state)
        #output_layer_1 = QuantumLayer(self.quantum_circuit, input = current_state)
        output_layer_1 = output_layer_1.repeat(64)
        output_layer_2 = self.classical_layer_1(output_layer_1)
        
        policy = Categorical(F.softmax(output_layer_2, dim=-1))
        return policy

# %%
class HybridCriticNetwork(nn.Module):
    def __init__(self, 
                 state_space, 
                 action_space,
                 number_of_qubits = 1,
                 number_of_shots = 1024):
        super(HybridCriticNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.number_of_qubits = number_of_qubits
        self.number_of_shots = number_of_shots

        self.qubits = [i for i in range(0, self.number_of_qubits)]
        self.quantum_circuit = qiskit.QuantumCircuit(self.number_of_qubits)
        self.theta = qiskit.circuit.Parameter('theta')
        self.beta = qiskit.circuit.ParameterVector('beta', self.state_space)

        self.input_layer()
        self.parameterized_quantum_circuit()
        quantum_neural_network = EstimatorQNN(circuit = self.quantum_circuit, 
                                              input_params = self.beta.params, 
                                              weight_params = [self.theta], 
                                              input_gradients = True)
        self.quantum_layer = TorchConnector(quantum_neural_network)

        self.classical_layer_1 = nn.Linear(64, 1)

    def input_layer(self):
        self.quantum_circuit.h(self.qubits)
        self.quantum_circuit.barrier()

        self.quantum_circuit.rz(self.beta[0], self.qubits)
        self.quantum_circuit.ry(self.beta[1], self.qubits)
        self.quantum_circuit.rz(self.beta[2], self.qubits)
        self.quantum_circuit.barrier()

    def parameterized_quantum_circuit(self):
        self.quantum_circuit.rx(self.theta, self.qubits)
        self.quantum_circuit.barrier()

    def forward(self, current_state):
        output_layer_1 = self.quantum_layer(current_state)
        output_layer_1 = output_layer_1.repeat(64)
        state_value = self.classical_layer_1(output_layer_1)
    
        return state_value

# %%
class QERL_Agent():
    def __init__(self, 
                 Actor,
                 Critic,
                 max_time_steps,
                 actor_learning_rate,
                 critic_learning_rate,
                 discount_factor,
                 number_of_epochs):
        
        self.max_time_steps = max_time_steps
        self.actor_learning_rate = actor_learning_rate
        self.critic_learning_rate = critic_learning_rate
        self.discount_factor = discount_factor
        self.number_of_epochs = number_of_epochs

        self.Actor = Actor
        self.Critic = Critic

        self.actor_optimizer = optim.Adam(self.Actor.parameters(), self.actor_learning_rate)
        self.critic_optimizer = optim.Adam(self.Critic.parameters(), self.critic_learning_rate)

    def clear_memory(self):
        self.rewards = []
        self.state_values = []
        self.log_policies = []
        self.done = []

    def replay_memory(self, 
                      state_value,
                      reward,
                      policy,
                      done):
        
        self.log_policies.append(policy)
        self.state_values.append(state_value)
        self.rewards.append(torch.tensor([reward],
                                         dtype = torch.float,
                                         device = device))
        self.done.append(torch.tensor([1-done],
                                      dtype = torch.float,
                                      device = device))
        
    def action_selection(self, 
                         current_state):
        current_state = torch.FloatTensor(current_state).to(device)
        policy = self.Actor(current_state)
        action = policy.sample()
        policy = policy.log_prob(action).unsqueeze(0)

        return action.cpu().numpy(), policy
    
    def compute_discounted_rewards(self, 
                                   next_state_value):
        R = next_state_value
        discounted_rewards = []
        for step in reversed(range(len(self.rewards))):
            R = self.rewards[step] + self.discount_factor * R * self.done[step]
            discounted_rewards.insert(0, R)
        return discounted_rewards
    
    def loss_function(self,
                      discounted_rewards):
        
        self.log_policies = torch.cat(self.log_policies)
        discounted_rewards = torch.cat(discounted_rewards).detach()
        self.state_values = torch.cat(self.state_values)

        advantage = discounted_rewards - self.state_values
        actor_loss = -(self.log_policies * advantage.detach()).mean()
        critic_loss = F.huber_loss(discounted_rewards, self.state_values)

        return actor_loss, critic_loss
    
    def training(self, next_state_value):
        discounted_rewards = self.compute_discounted_rewards(next_state_value)
        actor_loss, critic_loss = self.loss_function(discounted_rewards)

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        return actor_loss.item(), critic_loss.item()

# %%
def data_transformation(state):
        return [mt.atan(i) for i in state]

# %%
enviroment = gym.make("CartPole-v0").unwrapped

state_space = enviroment.observation_space.shape[0]-1
action_space = enviroment.action_space.n

actor_learning_rate = 0.02
critic_learning_rate = 0.2

max_time_steps = 500
number_of_epochs = 1
number_of_episodes = 200
discount_factor = 0.99
constant_for_average = 10

Actor = HybridActorNetwork(state_space = state_space,
                     action_space = action_space).to(device)
Critic = HybridCriticNetwork(state_space = state_space,
                       action_space = action_space).to(device)
Agent = QERL_Agent(Actor = Actor,
                        Critic = Critic,
                        max_time_steps = max_time_steps,
                        discount_factor = discount_factor,
                        actor_learning_rate = actor_learning_rate,
                        critic_learning_rate = critic_learning_rate,
                        number_of_epochs = number_of_epochs)

score = []
actor_loss = []
critic_loss = []

average_score = []
average_actor_loss = []
average_critic_loss = []

for current_episode in range(0, number_of_episodes):
    Agent.clear_memory()
    (current_state, _ ) = enviroment.reset()
    episodic_score  = 0

    for time_step in range(0, max_time_steps):
        enviroment.render()
        current_state = data_transformation(state = current_state[1:4])
        action, policy = Agent.action_selection(current_state)
        current_state = torch.FloatTensor(current_state).to(device)
        state_value = Critic(current_state)

        next_state, reward, done, info, _ = enviroment.step(action)
        episodic_score += reward

        Agent.replay_memory(reward = reward,
                            policy = policy,
                            state_value = state_value,
                            done = done)
        
        current_state = next_state
        if done == True:
            break

    next_state = data_transformation(state = next_state[1:4])
    next_state = torch.FloatTensor(next_state).to(device)
    next_state_value = Critic(next_state)
    episodic_actor_loss, episodic_critic_loss = Agent.training(next_state_value = next_state_value)

    score.append(episodic_score)
    actor_loss.append(episodic_actor_loss)
    critic_loss.append(episodic_critic_loss)
    print('Episode:{} Score:{} Actor_Loss:{} Critic_Loss:{}'.format(current_episode, 
                                                                    episodic_score, 
                                                                    episodic_actor_loss, 
                                                                    episodic_critic_loss))
    
for i in range(0,int(len(score)/constant_for_average)):
    temp_score = sum(score[i * constant_for_average : (i+1) * constant_for_average])
    temp_actor_loss = sum(actor_loss[i * constant_for_average : (i+1) * constant_for_average])
    temp_critic_loss = sum(critic_loss[i * constant_for_average : (i+1) * constant_for_average])

    average_score.append(temp_score/10)
    average_actor_loss.append(temp_actor_loss/10)
    average_critic_loss.append(temp_critic_loss/10)
# Out:
# /mnt/qb/venv/lib/python3.10/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /mnt/qb/venv/lib/python3.10/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(
# Episode:0 Score:16.0 Actor_Loss:5.699670314788818 Critic_Loss:7.504210472106934
# Episode:1 Score:19.0 Actor_Loss:6.077487945556641 Critic_Loss:8.02158260345459
# Episode:2 Score:13.0 Actor_Loss:5.3281378746032715 Critic_Loss:7.444836139678955
# Episode:3 Score:22.0 Actor_Loss:7.644176006317139 Critic_Loss:10.542220115661621
# Episode:4 Score:10.0 Actor_Loss:3.1298611164093018 Critic_Loss:4.443078994750977
# Episode:5 Score:19.0 Actor_Loss:6.041924953460693 Critic_Loss:8.187326431274414
# Episode:6 Score:24.0 Actor_Loss:7.163247585296631 Critic_Loss:9.886574745178223
# Episode:7 Score:21.0 Actor_Loss:5.573089122772217 Critic_Loss:7.8485426902771
# Episode:8 Score:18.0 Actor_Loss:4.424320697784424 Critic_Loss:6.306303977966309
# Episode:9 Score:17.0 Actor_Loss:3.8430399894714355 Critic_Loss:5.661511421203613
# Episode:10 Score:17.0 Actor_Loss:5.264795780181885 Critic_Loss:6.9597859382629395
# Episode:11 Score:29.0 Actor_Loss:9.37232780456543 Critic_Loss:12.834328651428223
# Episode:12 Score:17.0 Actor_Loss:5.886655807495117 Critic_Loss:7.857450485229492
# Episode:13 Score:28.0 Actor_Loss:7.865408420562744 Critic_Loss:10.555776596069336
# Episode:14 Score:15.0 Actor_Loss:3.6390953063964844 Critic_Loss:5.092112064361572
# Episode:15 Score:18.0 Actor_Loss:4.681240558624268 Critic_Loss:6.442707061767578
# Episode:16 Score:22.0 Actor_Loss:4.776327133178711 Critic_Loss:7.1379923820495605
# Episode:17 Score:15.0 Actor_Loss:4.1623406410217285 Critic_Loss:5.635308742523193
# Episode:18 Score:14.0 Actor_Loss:3.237914562225342 Critic_Loss:4.403748512268066
# Episode:19 Score:32.0 Actor_Loss:7.673708438873291 Critic_Loss:10.975045204162598
# Episode:20 Score:12.0 Actor_Loss:1.6462597846984863 Critic_Loss:2.8007774353027344
# Episode:21 Score:25.0 Actor_Loss:4.845632076263428 Critic_Loss:7.739212512969971
# Episode:22 Score:29.0 Actor_Loss:5.476162433624268 Critic_Loss:9.21510124206543
# Episode:23 Score:21.0 Actor_Loss:2.3921959400177 Critic_Loss:5.923532962799072
# Episode:24 Score:24.0 Actor_Loss:3.6462104320526123 Critic_Loss:6.922091007232666
# Episode:25 Score:13.0 Actor_Loss:-0.028275324031710625 Critic_Loss:3.9316999912261963
# Episode:26 Score:27.0 Actor_Loss:5.539614677429199 Critic_Loss:8.719501495361328
# Episode:27 Score:49.0 Actor_Loss:8.029009819030762 Critic_Loss:14.006925582885742
# Episode:28 Score:82.0 Actor_Loss:18.535614013671875 Critic_Loss:27.947084426879883
# Episode:29 Score:36.0 Actor_Loss:5.427840709686279 Critic_Loss:10.146200180053711
# Episode:30 Score:18.0 Actor_Loss:-0.4411706030368805 Critic_Loss:4.577524185180664
# Episode:31 Score:33.0 Actor_Loss:5.3923234939575195 Critic_Loss:9.300674438476562
# Episode:32 Score:21.0 Actor_Loss:0.5446009039878845 Critic_Loss:6.316097259521484
# Episode:33 Score:52.0 Actor_Loss:9.757723808288574 Critic_Loss:16.863676071166992
# Episode:34 Score:48.0 Actor_Loss:7.395411014556885 Critic_Loss:13.467789649963379
# Episode:35 Score:45.0 Actor_Loss:10.563660621643066 Critic_Loss:14.838898658752441
# Episode:36 Score:70.0 Actor_Loss:11.187617301940918 Critic_Loss:21.557769775390625
# Episode:37 Score:37.0 Actor_Loss:5.270348072052002 Critic_Loss:10.328858375549316
# Episode:38 Score:20.0 Actor_Loss:0.8174508213996887 Critic_Loss:4.781981468200684
# Episode:39 Score:44.0 Actor_Loss:7.071776866912842 Critic_Loss:13.3214111328125
# Episode:40 Score:54.0 Actor_Loss:9.99655532836914 Critic_Loss:15.660945892333984
# Episode:41 Score:41.0 Actor_Loss:5.2214131355285645 Critic_Loss:11.9868745803833
# Episode:42 Score:41.0 Actor_Loss:6.087693214416504 Critic_Loss:12.315338134765625
# Episode:43 Score:42.0 Actor_Loss:6.667409896850586 Critic_Loss:11.387919425964355
# Episode:44 Score:48.0 Actor_Loss:7.048965930938721 Critic_Loss:13.517354011535645
# Episode:45 Score:40.0 Actor_Loss:4.434406280517578 Critic_Loss:11.068856239318848
# Episode:46 Score:41.0 Actor_Loss:5.092069149017334 Critic_Loss:10.993311882019043
# Episode:47 Score:86.0 Actor_Loss:11.117693901062012 Critic_Loss:25.182157516479492
# Episode:48 Score:57.0 Actor_Loss:7.677292346954346 Critic_Loss:16.296932220458984
# Episode:49 Score:59.0 Actor_Loss:8.076273918151855 Critic_Loss:16.679170608520508
# Episode:50 Score:53.0 Actor_Loss:6.564957618713379 Critic_Loss:14.74526309967041
# Episode:51 Score:54.0 Actor_Loss:6.49531364440918 Critic_Loss:14.741748809814453
# Episode:52 Score:55.0 Actor_Loss:6.696258544921875 Critic_Loss:15.228655815124512
# Episode:53 Score:37.0 Actor_Loss:3.7736213207244873 Critic_Loss:8.973942756652832
# Episode:54 Score:48.0 Actor_Loss:5.640106678009033 Critic_Loss:12.73836612701416
# Episode:55 Score:72.0 Actor_Loss:8.753985404968262 Critic_Loss:19.809328079223633
# Episode:56 Score:58.0 Actor_Loss:7.0580339431762695 Critic_Loss:15.344332695007324
# Episode:57 Score:115.0 Actor_Loss:15.729287147521973 Critic_Loss:31.105871200561523
# Episode:58 Score:73.0 Actor_Loss:9.51728343963623 Critic_Loss:20.144193649291992
# Episode:59 Score:36.0 Actor_Loss:2.199509859085083 Critic_Loss:7.8552117347717285
# Episode:60 Score:66.0 Actor_Loss:8.67955207824707 Critic_Loss:17.460895538330078
# Episode:61 Score:63.0 Actor_Loss:7.6944098472595215 Critic_Loss:16.639225006103516
# Episode:62 Score:65.0 Actor_Loss:6.361681938171387 Critic_Loss:17.217164993286133
# Episode:63 Score:35.0 Actor_Loss:3.0937740802764893 Critic_Loss:6.64015007019043
# Episode:64 Score:94.0 Actor_Loss:12.058075904846191 Critic_Loss:25.017314910888672
# Episode:65 Score:41.0 Actor_Loss:2.098440647125244 Critic_Loss:8.486428260803223
# Episode:66 Score:89.0 Actor_Loss:9.562216758728027 Critic_Loss:23.173646926879883
# Episode:67 Score:94.0 Actor_Loss:12.318489074707031 Critic_Loss:24.148435592651367
# Episode:68 Score:40.0 Actor_Loss:2.7786526679992676 Critic_Loss:7.49288272857666
# Episode:69 Score:62.0 Actor_Loss:4.527841091156006 Critic_Loss:14.815770149230957
# Episode:70 Score:66.0 Actor_Loss:6.061833381652832 Critic_Loss:16.729280471801758
# Episode:71 Score:83.0 Actor_Loss:8.405153274536133 Critic_Loss:21.522443771362305
# Episode:72 Score:51.0 Actor_Loss:5.081508159637451 Critic_Loss:9.183021545410156
# Episode:73 Score:54.0 Actor_Loss:5.4578728675842285 Critic_Loss:12.058344841003418
# Episode:74 Score:35.0 Actor_Loss:0.5645185112953186 Critic_Loss:4.7462077140808105
# Episode:75 Score:72.0 Actor_Loss:7.157958984375 Critic_Loss:16.649456024169922
# Episode:76 Score:51.0 Actor_Loss:1.8797167539596558 Critic_Loss:10.949736595153809
# Episode:77 Score:72.0 Actor_Loss:7.450541019439697 Critic_Loss:18.983182907104492
# Episode:78 Score:67.0 Actor_Loss:5.983823299407959 Critic_Loss:15.755701065063477
# Episode:79 Score:50.0 Actor_Loss:0.9992700219154358 Critic_Loss:9.550387382507324
# Episode:80 Score:42.0 Actor_Loss:0.44865328073501587 Critic_Loss:6.539910316467285
# Episode:81 Score:42.0 Actor_Loss:2.650106430053711 Critic_Loss:5.711475849151611
# Episode:82 Score:51.0 Actor_Loss:1.5802420377731323 Critic_Loss:11.20565128326416
# Episode:83 Score:38.0 Actor_Loss:-1.2528918981552124 Critic_Loss:6.614902496337891
# Episode:84 Score:43.0 Actor_Loss:-0.019908983260393143 Critic_Loss:7.415334224700928
# Episode:85 Score:84.0 Actor_Loss:6.666322231292725 Critic_Loss:20.15923500061035
# Episode:86 Score:62.0 Actor_Loss:3.871034622192383 Critic_Loss:11.882433891296387
# Episode:87 Score:62.0 Actor_Loss:4.6244401931762695 Critic_Loss:15.41493034362793
# Episode:88 Score:45.0 Actor_Loss:-0.19110068678855896 Critic_Loss:9.751056671142578
# Episode:89 Score:36.0 Actor_Loss:-0.26521414518356323 Critic_Loss:4.741514205932617
# Episode:90 Score:33.0 Actor_Loss:-1.8103408813476562 Critic_Loss:4.557030200958252
# Episode:91 Score:53.0 Actor_Loss:1.6643785238265991 Critic_Loss:10.092766761779785
# Episode:92 Score:38.0 Actor_Loss:0.13233277201652527 Critic_Loss:4.778204441070557
# Episode:93 Score:33.0 Actor_Loss:-1.3933398723602295 Critic_Loss:4.378109455108643
# Episode:94 Score:40.0 Actor_Loss:0.539086103439331 Critic_Loss:10.623052597045898
# Episode:95 Score:62.0 Actor_Loss:5.113703727722168 Critic_Loss:15.462174415588379
# Episode:96 Score:57.0 Actor_Loss:4.546478271484375 Critic_Loss:14.155682563781738
# Episode:97 Score:34.0 Actor_Loss:-0.3882167339324951 Critic_Loss:5.0639190673828125
# Episode:98 Score:42.0 Actor_Loss:1.247817039489746 Critic_Loss:6.426876068115234
# Episode:99 Score:40.0 Actor_Loss:1.2075293064117432 Critic_Loss:10.465689659118652
# Episode:100 Score:36.0 Actor_Loss:-0.32561004161834717 Critic_Loss:5.508610248565674
# Episode:101 Score:67.0 Actor_Loss:5.958319664001465 Critic_Loss:16.025283813476562
# Episode:102 Score:41.0 Actor_Loss:1.3219040632247925 Critic_Loss:9.593032836914062
# Episode:103 Score:52.0 Actor_Loss:2.851044178009033 Critic_Loss:9.875584602355957
# Episode:104 Score:112.0 Actor_Loss:11.562979698181152 Critic_Loss:26.395740509033203
# Episode:105 Score:62.0 Actor_Loss:4.240498065948486 Critic_Loss:14.500107765197754
# Episode:106 Score:67.0 Actor_Loss:5.130214691162109 Critic_Loss:15.658891677856445
# Episode:107 Score:64.0 Actor_Loss:5.61115837097168 Critic_Loss:14.340084075927734
# Episode:108 Score:70.0 Actor_Loss:6.70051383972168 Critic_Loss:15.309475898742676
# Episode:109 Score:64.0 Actor_Loss:4.395203590393066 Critic_Loss:14.635558128356934
# Episode:110 Score:57.0 Actor_Loss:2.030289649963379 Critic_Loss:11.995138168334961
# Episode:111 Score:70.0 Actor_Loss:5.53918981552124 Critic_Loss:15.580585479736328
# Episode:112 Score:48.0 Actor_Loss:2.4021060466766357 Critic_Loss:9.18277645111084
# Episode:113 Score:60.0 Actor_Loss:3.451585054397583 Critic_Loss:13.27519702911377
# Episode:114 Score:79.0 Actor_Loss:5.963339328765869 Critic_Loss:17.80298614501953
# Episode:115 Score:132.0 Actor_Loss:13.284317016601562 Critic_Loss:29.964269638061523
# Episode:116 Score:52.0 Actor_Loss:1.3236041069030762 Critic_Loss:9.583547592163086
# Episode:117 Score:78.0 Actor_Loss:4.822610855102539 Critic_Loss:17.97889518737793
# Episode:118 Score:43.0 Actor_Loss:0.21979378163814545 Critic_Loss:7.869043350219727
# Episode:119 Score:78.0 Actor_Loss:5.546772480010986 Critic_Loss:16.76785659790039
# Episode:120 Score:50.0 Actor_Loss:0.12773193418979645 Critic_Loss:9.893549919128418
# Episode:121 Score:129.0 Actor_Loss:11.134803771972656 Critic_Loss:28.604204177856445
# Episode:122 Score:66.0 Actor_Loss:4.53645658493042 Critic_Loss:14.554803848266602
# Episode:123 Score:64.0 Actor_Loss:3.617976427078247 Critic_Loss:13.650413513183594
# Episode:124 Score:61.0 Actor_Loss:2.4132676124572754 Critic_Loss:13.909955978393555
# Episode:125 Score:65.0 Actor_Loss:3.5099711418151855 Critic_Loss:14.309596061706543
# Episode:126 Score:64.0 Actor_Loss:3.40564227104187 Critic_Loss:14.293415069580078
# Episode:127 Score:49.0 Actor_Loss:0.44511741399765015 Critic_Loss:9.143668174743652
# Episode:128 Score:62.0 Actor_Loss:3.1001484394073486 Critic_Loss:12.663684844970703
# Episode:129 Score:93.0 Actor_Loss:6.007840156555176 Critic_Loss:20.471450805664062
# Episode:130 Score:77.0 Actor_Loss:3.4857871532440186 Critic_Loss:16.09100914001465
# Episode:131 Score:65.0 Actor_Loss:1.8657991886138916 Critic_Loss:12.872949600219727
# Episode:132 Score:66.0 Actor_Loss:3.0764482021331787 Critic_Loss:14.035017013549805
# Episode:133 Score:99.0 Actor_Loss:4.985148906707764 Critic_Loss:20.968252182006836
# Episode:134 Score:52.0 Actor_Loss:1.21096932888031 Critic_Loss:9.877141952514648
# Episode:135 Score:69.0 Actor_Loss:2.3490102291107178 Critic_Loss:14.197011947631836
# Episode:136 Score:73.0 Actor_Loss:2.875929832458496 Critic_Loss:14.842517852783203
# Episode:137 Score:69.0 Actor_Loss:1.8959283828735352 Critic_Loss:14.307976722717285
# Episode:138 Score:77.0 Actor_Loss:2.9338302612304688 Critic_Loss:16.186992645263672
# Episode:139 Score:80.0 Actor_Loss:6.332583427429199 Critic_Loss:16.866992950439453
# Episode:140 Score:55.0 Actor_Loss:0.14601589739322662 Critic_Loss:10.36123275756836
# Episode:141 Score:74.0 Actor_Loss:4.870179176330566 Critic_Loss:15.281880378723145
# Episode:142 Score:57.0 Actor_Loss:0.8956197500228882 Critic_Loss:11.080275535583496
# Episode:143 Score:62.0 Actor_Loss:2.1496493816375732 Critic_Loss:11.92647647857666
# Episode:144 Score:40.0 Actor_Loss:-2.634059429168701 Critic_Loss:7.593592643737793
# Episode:145 Score:60.0 Actor_Loss:1.8723273277282715 Critic_Loss:11.512503623962402
# Episode:146 Score:95.0 Actor_Loss:4.110545635223389 Critic_Loss:19.56517791748047
# Episode:147 Score:62.0 Actor_Loss:0.6115204691886902 Critic_Loss:11.850424766540527
# Episode:148 Score:86.0 Actor_Loss:2.7403500080108643 Critic_Loss:17.491086959838867
# Episode:149 Score:58.0 Actor_Loss:0.7688096761703491 Critic_Loss:10.73670482635498
# Episode:150 Score:82.0 Actor_Loss:3.3650007247924805 Critic_Loss:16.174091339111328
# Episode:151 Score:94.0 Actor_Loss:3.941401481628418 Critic_Loss:19.060924530029297
# Episode:152 Score:54.0 Actor_Loss:-0.9355488419532776 Critic_Loss:10.292852401733398
# Episode:153 Score:52.0 Actor_Loss:0.28519973158836365 Critic_Loss:9.166662216186523
# Episode:154 Score:78.0 Actor_Loss:3.2531940937042236 Critic_Loss:15.423583984375
# Episode:155 Score:97.0 Actor_Loss:5.554714679718018 Critic_Loss:19.307552337646484
# Episode:156 Score:103.0 Actor_Loss:5.6122660636901855 Critic_Loss:20.516199111938477
# Episode:157 Score:81.0 Actor_Loss:4.2645792961120605 Critic_Loss:16.02442169189453
# Episode:158 Score:77.0 Actor_Loss:2.4449901580810547 Critic_Loss:15.30695629119873
# Episode:159 Score:76.0 Actor_Loss:0.9851462841033936 Critic_Loss:14.206758499145508
# Episode:160 Score:88.0 Actor_Loss:4.566080570220947 Critic_Loss:17.64181900024414
# Episode:161 Score:107.0 Actor_Loss:7.736725330352783 Critic_Loss:21.191709518432617
# Episode:162 Score:121.0 Actor_Loss:4.715137004852295 Critic_Loss:23.559375762939453
# Episode:163 Score:127.0 Actor_Loss:9.012590408325195 Critic_Loss:25.06516456604004
# Episode:164 Score:83.0 Actor_Loss:3.511638879776001 Critic_Loss:16.262012481689453
# Episode:165 Score:216.0 Actor_Loss:11.293949127197266 Critic_Loss:38.73484420776367
# Episode:166 Score:85.0 Actor_Loss:2.463620901107788 Critic_Loss:16.382041931152344
# Episode:167 Score:76.0 Actor_Loss:1.0788456201553345 Critic_Loss:13.744091987609863
# Episode:168 Score:92.0 Actor_Loss:2.1496825218200684 Critic_Loss:17.256980895996094
# Episode:169 Score:136.0 Actor_Loss:5.783205986022949 Critic_Loss:25.988269805908203
# Episode:170 Score:157.0 Actor_Loss:6.885405540466309 Critic_Loss:29.532114028930664
# Episode:171 Score:172.0 Actor_Loss:7.834890842437744 Critic_Loss:31.667688369750977
# Episode:172 Score:115.0 Actor_Loss:6.717504501342773 Critic_Loss:22.11583709716797
# Episode:173 Score:82.0 Actor_Loss:1.7826783657073975 Critic_Loss:14.808038711547852
# Episode:174 Score:155.0 Actor_Loss:5.294906139373779 Critic_Loss:28.65921401977539
# Episode:175 Score:211.0 Actor_Loss:10.05333137512207 Critic_Loss:36.50788497924805
# Episode:176 Score:106.0 Actor_Loss:2.5385420322418213 Critic_Loss:19.733400344848633
# Episode:177 Score:78.0 Actor_Loss:1.000154733657837 Critic_Loss:13.458826065063477
# Episode:178 Score:132.0 Actor_Loss:8.704754829406738 Critic_Loss:24.245342254638672
# Episode:179 Score:88.0 Actor_Loss:1.5686652660369873 Critic_Loss:16.028196334838867
# Episode:180 Score:82.0 Actor_Loss:0.07030816376209259 Critic_Loss:14.881453514099121
# Episode:181 Score:119.0 Actor_Loss:3.3343544006347656 Critic_Loss:22.396652221679688
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
plt.plot(np.array(list(range(0, len(score)))), score, label='Score')
plt.plot(np.array(list(range(0, len(score), constant_for_average))), average_score, label='Average Score')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(actor_loss)))), actor_loss, label='Actor Loss')
plt.plot(np.array(list(range(0, len(actor_loss), constant_for_average))), average_actor_loss, label='Average Actor Loss')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(critic_loss)))), critic_loss, label='Critic Loss')
plt.plot(np.array(list(range(0, len(critic_loss), constant_for_average))), average_critic_loss, label='Average Critic Loss')
plt.legend()
plt.show()

# %%
torch.save(Actor, 'Hybrid_Actor_Network_V14(500_Episodes_1_classical_layers).pkl')
torch.save(Critic, 'Hybrid_Critic_Network_V14(500_Episodes_1_classical_layers).pkl')

# %%
file = open("Quantum_Score_Loss_V14(500_Episodes_1_classical_layers).txt", "x")
data = np.column_stack([score, actor_loss, critic_loss])
np.savetxt("Quantum_Score_Loss_V14(500_Episodes_1_classical_layers).txt",data)

# %%
total_params = sum(p.numel() for p in Actor.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 131

# %%
total_params = sum(p.numel() for p in Critic.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 66

# %%
A = HybridActorNetwork(3,2)

# %%
A.quantum_circuit.print()
# Out:
# H q0
# Rz(theta_i0) q0
# Ry(theta_i1) q0
# Rz(theta_i2) q0
# Rx(theta_v0) q0
# Measure q0
