# %% [markdown]
# #### Importing Librarires

# %%
import gym, os
from itertools import count
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical

import matplotlib.pyplot as plt
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class ActorNetwork(nn.Module):
    def __init__(self, state_space, action_space):
        super(ActorNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.layer_1 = nn.Linear(self.state_space, 128)
        self.layer_2 = nn.Linear(128, 256)
        self.layer_3 = nn.Linear(256, self.action_space)

    def forward(self, current_state):
        output_layer_1 = F.relu(self.layer_1(current_state))
        output_layer_2 = F.relu(self.layer_2(output_layer_1))
        output_layer_3 = self.layer_3(output_layer_2)
        policy = Categorical(F.softmax(output_layer_3, dim=-1))
        return policy

# %%
class CriticNetwork(nn.Module):
    def __init__(self, state_space, action_space):
        super(CriticNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.layer_1 = nn.Linear(self.state_space, 128)
        self.layer_2 = nn.Linear(128, 256)
        self.layer_3 = nn.Linear(256, 1)

    def forward(self, current_state):
        output_layer_1 = F.relu(self.layer_1(current_state))
        output_layer_2 = F.relu(self.layer_2(output_layer_1))
        state_value = self.layer_3(output_layer_2)
        return state_value

# %%
class Classical_Agent():
    def __init__(self, 
                 Actor,
                 Critic,
                 max_time_steps,
                 actor_learning_rate,
                 critic_learning_rate,
                 discount_factor,
                 number_of_epochs):
        
        self.max_time_steps = max_time_steps
        self.actor_learning_rate = actor_learning_rate
        self.critic_learning_rate = critic_learning_rate
        self.discount_factor = discount_factor
        self.number_of_epochs = number_of_epochs

        self.Actor = Actor
        self.Critic = Critic

        self.actor_optimizer = optim.Adam(self.Actor.parameters(), self.actor_learning_rate)
        self.critic_optimizer = optim.Adam(self.Critic.parameters(), self.critic_learning_rate)

    def clear_memory(self):
        self.rewards = []
        self.state_values = []
        self.log_policies = []
        self.done = []

    def replay_memory(self, 
                      state_value,
                      reward,
                      policy,
                      done):
        
        self.log_policies.append(policy)
        self.state_values.append(state_value)
        self.rewards.append(torch.tensor([reward],
                                         dtype = torch.float,
                                         device = device))
        self.done.append(torch.tensor([1-done],
                                      dtype = torch.float,
                                      device = device))
        
    def action_selection(self, 
                         current_state):
        current_state = torch.FloatTensor(current_state).to(device)
        policy = self.Actor(current_state)
        action = policy.sample()
        policy = policy.log_prob(action).unsqueeze(0)

        return action.cpu().numpy(), policy
    
    def compute_discounted_rewards(self, 
                                   next_state_value):
        R = next_state_value
        discounted_rewards = []
        for step in reversed(range(len(self.rewards))):
            R = self.rewards[step] + self.discount_factor * R * self.done[step]
            discounted_rewards.insert(0, R)
        return discounted_rewards
    
    def loss_function(self,
                      discounted_rewards):
        
        self.log_policies = torch.cat(self.log_policies)
        discounted_rewards = torch.cat(discounted_rewards).detach()
        self.state_values = torch.cat(self.state_values)

        advantage = discounted_rewards - self.state_values
        actor_loss = -(self.log_policies * advantage.detach()).mean()
        critic_loss = F.huber_loss(discounted_rewards, self.state_values)

        return actor_loss, critic_loss
    
    def training(self, next_state_value):
        discounted_rewards = self.compute_discounted_rewards(next_state_value)
        actor_loss, critic_loss = self.loss_function(discounted_rewards)

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        return actor_loss.item(), critic_loss.item()

# %%
enviroment = gym.make("CartPole-v1").unwrapped

state_space = enviroment.observation_space.shape[0]-1
action_space = enviroment.action_space.n

actor_learning_rate = 0.001
critic_learning_rate = 0.01

max_time_steps = 500
number_of_epochs = 1
number_of_episodes = 500
discount_factor = 0.99
constant_for_average = 10

Actor = ActorNetwork(state_space = state_space,
                     action_space = action_space).to(device)
Critic = CriticNetwork(state_space = state_space,
                       action_space = action_space).to(device)
Agent = Classical_Agent(Actor = Actor,
                        Critic = Critic,
                        max_time_steps = max_time_steps,
                        discount_factor = discount_factor,
                        actor_learning_rate = actor_learning_rate,
                        critic_learning_rate = critic_learning_rate,
                        number_of_epochs = number_of_epochs)

score = []
actor_loss = []
critic_loss = []

average_score = []
average_actor_loss = []
average_critic_loss = []

for current_episode in range(0, number_of_episodes):
    Agent.clear_memory()
    (current_state, _ ) = enviroment.reset()
    episodic_score  = 0

    for time_step in range(0, max_time_steps):
        enviroment.render()
        current_state = current_state[1:4]
        action, policy = Agent.action_selection(current_state)
        current_state = torch.FloatTensor(current_state).to(device)
        state_value = Critic(current_state)

        next_state, reward, done, info, _ = enviroment.step(action)
        episodic_score += reward

        Agent.replay_memory(reward = reward,
                            policy = policy,
                            state_value = state_value,
                            done = done)
        
        current_state = next_state
        if done == True:
            break

    next_state = torch.FloatTensor(next_state).to(device)
    next_state_value = Critic(next_state[1:4])
    episodic_actor_loss, episodic_critic_loss = Agent.training(next_state_value = next_state_value)

    score.append(episodic_score)
    actor_loss.append(episodic_actor_loss)
    critic_loss.append(episodic_critic_loss)
    print('Episode:{} Score:{} Actor_Loss:{} Critic_Loss:{}'.format(current_episode, 
                                                                    episodic_score, 
                                                                    episodic_actor_loss, 
                                                                    episodic_critic_loss))
    
for i in range(0,int(len(score)/constant_for_average)):
    temp_score = sum(score[i * constant_for_average : (i+1) * constant_for_average])
    temp_actor_loss = sum(actor_loss[i * constant_for_average : (i+1) * constant_for_average])
    temp_critic_loss = sum(critic_loss[i * constant_for_average : (i+1) * constant_for_average])

    average_score.append(temp_score/10)
    average_actor_loss.append(temp_actor_loss/10)
    average_critic_loss.append(temp_critic_loss/10)
# Out:
# /Users/zam026/Dropbox/CSIRO/Projects/QRL for CartPole/Python Codes/PyTorch/PyTorch/lib/python3.11/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Episode:0 Score:11.0 Actor_Loss:3.696333408355713 Critic_Loss:5.079178333282471
# Episode:1 Score:17.0 Actor_Loss:4.704235553741455 Critic_Loss:6.605495452880859
# Episode:2 Score:22.0 Actor_Loss:5.016862392425537 Critic_Loss:7.388770580291748
# Episode:3 Score:34.0 Actor_Loss:7.452051162719727 Critic_Loss:11.703993797302246
# Episode:4 Score:21.0 Actor_Loss:0.911013662815094 Critic_Loss:7.60732364654541
# Episode:5 Score:18.0 Actor_Loss:-1.4691230058670044 Critic_Loss:5.044748306274414
# Episode:6 Score:10.0 Actor_Loss:-3.988377094268799 Critic_Loss:6.4590630531311035
# Episode:7 Score:10.0 Actor_Loss:-3.108187198638916 Critic_Loss:5.787731170654297
# Episode:8 Score:46.0 Actor_Loss:7.9682698249816895 Critic_Loss:12.572759628295898
# Episode:9 Score:14.0 Actor_Loss:-0.4105207324028015 Critic_Loss:2.7533347606658936
# Episode:10 Score:34.0 Actor_Loss:5.0927629470825195 Critic_Loss:8.114971160888672
# Episode:11 Score:45.0 Actor_Loss:7.809001922607422 Critic_Loss:11.996177673339844
# Episode:12 Score:24.0 Actor_Loss:2.9806511402130127 Critic_Loss:5.211113929748535
# Episode:13 Score:35.0 Actor_Loss:-0.2900231182575226 Critic_Loss:12.760576248168945
# Episode:14 Score:57.0 Actor_Loss:7.493011951446533 Critic_Loss:15.866212844848633
# Episode:15 Score:20.0 Actor_Loss:0.7442904710769653 Critic_Loss:3.6080570220947266
# Episode:16 Score:89.0 Actor_Loss:14.037750244140625 Critic_Loss:23.044050216674805
# Episode:17 Score:13.0 Actor_Loss:-13.220389366149902 Critic_Loss:19.269145965576172
# Episode:18 Score:44.0 Actor_Loss:4.000703811645508 Critic_Loss:9.785354614257812
# Episode:19 Score:11.0 Actor_Loss:-1.986535668373108 Critic_Loss:1.9777941703796387
# Episode:20 Score:24.0 Actor_Loss:-4.346641540527344 Critic_Loss:6.80961275100708
# Episode:21 Score:69.0 Actor_Loss:10.164315223693848 Critic_Loss:17.038925170898438
# Episode:22 Score:39.0 Actor_Loss:2.297466278076172 Critic_Loss:10.15268325805664
# Episode:23 Score:80.0 Actor_Loss:12.935696601867676 Critic_Loss:20.464862823486328
# Episode:24 Score:51.0 Actor_Loss:6.376986503601074 Critic_Loss:12.564879417419434
# Episode:25 Score:58.0 Actor_Loss:7.453070640563965 Critic_Loss:13.97630500793457
# Episode:26 Score:58.0 Actor_Loss:6.5160722732543945 Critic_Loss:13.4747314453125
# Episode:27 Score:62.0 Actor_Loss:6.344611167907715 Critic_Loss:14.562007904052734
# Episode:28 Score:20.0 Actor_Loss:-2.9529166221618652 Critic_Loss:4.431519031524658
# Episode:29 Score:60.0 Actor_Loss:4.944681644439697 Critic_Loss:12.52230167388916
# Episode:30 Score:33.0 Actor_Loss:-1.2144465446472168 Critic_Loss:7.029679775238037
# Episode:31 Score:36.0 Actor_Loss:-1.3055448532104492 Critic_Loss:5.513554096221924
# Episode:32 Score:51.0 Actor_Loss:2.260571002960205 Critic_Loss:10.067870140075684
# Episode:33 Score:43.0 Actor_Loss:-0.6647568345069885 Critic_Loss:7.2282819747924805
# Episode:34 Score:52.0 Actor_Loss:1.7218682765960693 Critic_Loss:9.326510429382324
# Episode:35 Score:46.0 Actor_Loss:-0.23556804656982422 Critic_Loss:8.270846366882324
# Episode:36 Score:115.0 Actor_Loss:9.993597984313965 Critic_Loss:21.96720314025879
# Episode:37 Score:17.0 Actor_Loss:-9.202999114990234 Critic_Loss:11.542149543762207
# Episode:38 Score:17.0 Actor_Loss:-8.100394248962402 Critic_Loss:11.678407669067383
# Episode:39 Score:64.0 Actor_Loss:4.507401943206787 Critic_Loss:11.288191795349121
# Episode:40 Score:68.0 Actor_Loss:4.429489612579346 Critic_Loss:11.320106506347656
# Episode:41 Score:26.0 Actor_Loss:-7.801739692687988 Critic_Loss:12.62956428527832
# Episode:42 Score:39.0 Actor_Loss:-3.4568727016448975 Critic_Loss:8.81914234161377
# Episode:43 Score:41.0 Actor_Loss:1.8483690023422241 Critic_Loss:6.730274677276611
# Episode:44 Score:23.0 Actor_Loss:-6.736345291137695 Critic_Loss:9.697678565979004
# Episode:146 Score:211.0 Actor_Loss:-8.556206703186035 Critic_Loss:16.823604583740234
# Episode:147 Score:278.0 Actor_Loss:-4.853166103363037 Critic_Loss:13.718320846557617
# Episode:148 Score:171.0 Actor_Loss:-2.7240853309631348 Critic_Loss:7.436782360076904
# Episode:149 Score:434.0 Actor_Loss:-2.348015069961548 Critic_Loss:18.674903869628906
# Episode:150 Score:466.0 Actor_Loss:5.248749256134033 Critic_Loss:23.407176971435547
# Episode:151 Score:333.0 Actor_Loss:-0.942112922668457 Critic_Loss:17.445213317871094
# Episode:152 Score:430.0 Actor_Loss:1.6808747053146362 Critic_Loss:21.424591064453125
# Episode:153 Score:408.0 Actor_Loss:3.26391339302063 Critic_Loss:21.409168243408203
# Episode:154 Score:336.0 Actor_Loss:-0.5469757318496704 Critic_Loss:17.712343215942383
# Episode:155 Score:180.0 Actor_Loss:-8.19900894165039 Critic_Loss:17.696550369262695
# Episode:156 Score:475.0 Actor_Loss:9.327705383300781 Critic_Loss:25.868877410888672
# Episode:157 Score:442.0 Actor_Loss:3.8222484588623047 Critic_Loss:22.11534309387207
# Episode:158 Score:500.0 Actor_Loss:10.944437026977539 Critic_Loss:21.95840835571289
# Episode:159 Score:466.0 Actor_Loss:8.840465545654297 Critic_Loss:19.454898834228516
# Episode:160 Score:500.0 Actor_Loss:6.8404927253723145 Critic_Loss:14.310202598571777
# Episode:161 Score:460.0 Actor_Loss:1.094770073890686 Critic_Loss:9.625441551208496
# Episode:162 Score:462.0 Actor_Loss:-3.6269524097442627 Critic_Loss:7.004125118255615
# Episode:163 Score:436.0 Actor_Loss:-0.5067260265350342 Critic_Loss:7.310610771179199
# Episode:164 Score:500.0 Actor_Loss:-1.7165420055389404 Critic_Loss:4.364393711090088
# Episode:165 Score:346.0 Actor_Loss:-12.546178817749023 Critic_Loss:25.509183883666992
# Episode:166 Score:500.0 Actor_Loss:-2.2818763256073 Critic_Loss:4.623496055603027
# Episode:167 Score:500.0 Actor_Loss:1.1736276149749756 Critic_Loss:2.915989637374878
# Episode:168 Score:332.0 Actor_Loss:-11.321572303771973 Critic_Loss:20.472929000854492
# Episode:169 Score:500.0 Actor_Loss:2.034655809402466 Critic_Loss:5.1780595779418945
# Episode:170 Score:500.0 Actor_Loss:6.519087791442871 Critic_Loss:13.17265510559082
# Episode:171 Score:500.0 Actor_Loss:5.887923240661621 Critic_Loss:11.195701599121094
# Episode:172 Score:500.0 Actor_Loss:3.4586894512176514 Critic_Loss:6.601693153381348
# Episode:173 Score:500.0 Actor_Loss:1.0087785720825195 Critic_Loss:4.905144214630127
# Episode:174 Score:500.0 Actor_Loss:-1.5515310764312744 Critic_Loss:3.1484062671661377
# Episode:175 Score:500.0 Actor_Loss:-1.6748278141021729 Critic_Loss:4.544826984405518
# Episode:176 Score:500.0 Actor_Loss:-1.2857868671417236 Critic_Loss:4.199578762054443
# Episode:177 Score:500.0 Actor_Loss:-0.7647051811218262 Critic_Loss:2.387477159500122
# Episode:178 Score:500.0 Actor_Loss:0.4216657876968384 Critic_Loss:1.7014223337173462
# Episode:179 Score:343.0 Actor_Loss:-12.144537925720215 Critic_Loss:21.358003616333008
# Episode:247 Score:500.0 Actor_Loss:-1.2293413877487183 Critic_Loss:2.2774269580841064
# Episode:248 Score:500.0 Actor_Loss:0.7839876413345337 Critic_Loss:1.3875070810317993
# Episode:249 Score:500.0 Actor_Loss:1.1159472465515137 Critic_Loss:2.265380382537842
# Episode:250 Score:500.0 Actor_Loss:1.2137458324432373 Critic_Loss:2.488069772720337
# Episode:251 Score:500.0 Actor_Loss:0.8099722862243652 Critic_Loss:1.4646499156951904
# Episode:252 Score:500.0 Actor_Loss:-0.44827964901924133 Critic_Loss:0.7734436988830566
# Episode:253 Score:500.0 Actor_Loss:-1.221502423286438 Critic_Loss:2.1291184425354004
# Episode:254 Score:500.0 Actor_Loss:-1.009944200515747 Critic_Loss:1.5863269567489624
# Episode:255 Score:500.0 Actor_Loss:-0.1487259417772293 Critic_Loss:0.28544938564300537
# Episode:256 Score:500.0 Actor_Loss:0.8924408555030823 Critic_Loss:1.7490296363830566
# Episode:257 Score:500.0 Actor_Loss:1.2014158964157104 Critic_Loss:2.3496713638305664
# Episode:258 Score:500.0 Actor_Loss:1.0532530546188354 Critic_Loss:1.8498508930206299
# Episode:259 Score:500.0 Actor_Loss:-0.22874200344085693 Critic_Loss:0.2024717628955841
# Episode:260 Score:500.0 Actor_Loss:-1.3129287958145142 Critic_Loss:2.1821625232696533
# Episode:261 Score:500.0 Actor_Loss:-0.5355972051620483 Critic_Loss:0.7343156933784485
# Episode:262 Score:500.0 Actor_Loss:0.23420517146587372 Critic_Loss:0.43032363057136536
# Episode:263 Score:500.0 Actor_Loss:0.5858137011528015 Critic_Loss:1.006817102432251
# Episode:264 Score:500.0 Actor_Loss:0.3820401728153229 Critic_Loss:0.5342975854873657
# Episode:265 Score:500.0 Actor_Loss:-0.08771254867315292 Critic_Loss:0.659317672252655
# Episode:266 Score:500.0 Actor_Loss:-0.5480018258094788 Critic_Loss:1.2867575883865356
# Episode:267 Score:500.0 Actor_Loss:-0.5317218899726868 Critic_Loss:0.7429310083389282
# Episode:268 Score:500.0 Actor_Loss:0.24439679086208344 Critic_Loss:0.2572108507156372
# Episode:269 Score:500.0 Actor_Loss:0.6298217177391052 Critic_Loss:0.9269488453865051
# Episode:270 Score:500.0 Actor_Loss:0.21862339973449707 Critic_Loss:0.18980146944522858
# Episode:271 Score:500.0 Actor_Loss:-0.19008202850818634 Critic_Loss:0.7091099619865417
# Episode:272 Score:500.0 Actor_Loss:-0.7813355326652527 Critic_Loss:1.3444527387619019
# Episode:273 Score:500.0 Actor_Loss:-0.45048901438713074 Critic_Loss:0.5883511304855347
# Episode:274 Score:500.0 Actor_Loss:0.5287162065505981 Critic_Loss:0.7095550894737244
# Episode:275 Score:500.0 Actor_Loss:0.7390856742858887 Critic_Loss:1.1478248834609985
# Episode:276 Score:500.0 Actor_Loss:0.09343448281288147 Critic_Loss:0.1408611238002777
# Episode:277 Score:500.0 Actor_Loss:-0.48514437675476074 Critic_Loss:0.6326722502708435
# Episode:278 Score:500.0 Actor_Loss:0.09438975155353546 Critic_Loss:1.107114315032959
# Episode:279 Score:500.0 Actor_Loss:-0.1611977219581604 Critic_Loss:0.12695924937725067
# Episode:280 Score:500.0 Actor_Loss:0.332705020904541 Critic_Loss:0.5610417127609253
# Episode:281 Score:500.0 Actor_Loss:0.3783057630062103 Critic_Loss:0.4566846787929535
# Episode:282 Score:500.0 Actor_Loss:-0.15228688716888428 Critic_Loss:0.08533888310194016
# Episode:283 Score:500.0 Actor_Loss:-0.3103071451187134 Critic_Loss:0.27626368403434753
# Episode:284 Score:500.0 Actor_Loss:0.09247821569442749 Critic_Loss:0.10368438810110092
# Episode:285 Score:500.0 Actor_Loss:0.2566685080528259 Critic_Loss:0.20834596455097198
# Episode:286 Score:500.0 Actor_Loss:0.0029045208357274532 Critic_Loss:0.005490239709615707
# Episode:287 Score:500.0 Actor_Loss:-0.22625097632408142 Critic_Loss:0.17396856844425201
# Episode:288 Score:500.0 Actor_Loss:-0.13278231024742126 Critic_Loss:0.11361727863550186
# Episode:289 Score:500.0 Actor_Loss:0.2993045747280121 Critic_Loss:0.27117016911506653
# Episode:290 Score:500.0 Actor_Loss:0.17554667592048645 Critic_Loss:0.16267336905002594
# Episode:291 Score:500.0 Actor_Loss:-0.3298521041870117 Critic_Loss:0.3105675280094147
# Episode:292 Score:500.0 Actor_Loss:-0.1983453780412674 Critic_Loss:0.14536651968955994
# Episode:293 Score:500.0 Actor_Loss:0.2232121229171753 Critic_Loss:0.1423477977514267
# Episode:294 Score:500.0 Actor_Loss:0.23620492219924927 Critic_Loss:0.18986763060092926
# Episode:295 Score:500.0 Actor_Loss:-0.7030287981033325 Critic_Loss:1.0447026491165161
# Episode:296 Score:500.0 Actor_Loss:0.22647182643413544 Critic_Loss:0.2977338433265686
# Episode:297 Score:500.0 Actor_Loss:0.06053563579916954 Critic_Loss:0.010041101835668087
# Episode:298 Score:500.0 Actor_Loss:-0.14548185467720032 Critic_Loss:0.14285334944725037
# Episode:299 Score:500.0 Actor_Loss:0.07100912183523178 Critic_Loss:0.013523154892027378
# Episode:300 Score:500.0 Actor_Loss:0.011672803200781345 Critic_Loss:0.037473224103450775
# Episode:301 Score:500.0 Actor_Loss:0.0388769805431366 Critic_Loss:0.023886913433670998
# Episode:302 Score:500.0 Actor_Loss:-0.06050238013267517 Critic_Loss:0.013277684338390827
# Episode:303 Score:500.0 Actor_Loss:-0.018662504851818085 Critic_Loss:0.02337374910712242
# Episode:304 Score:500.0 Actor_Loss:0.03090088441967964 Critic_Loss:0.015600605867803097
# Episode:305 Score:500.0 Actor_Loss:3.961562924814643e-06 Critic_Loss:0.0021199004258960485
# Episode:306 Score:500.0 Actor_Loss:0.008980964310467243 Critic_Loss:0.0019293258665129542
# Episode:307 Score:500.0 Actor_Loss:0.005559177603572607 Critic_Loss:0.0015837583923712373
# Episode:308 Score:500.0 Actor_Loss:-0.0004783452022820711 Critic_Loss:0.0028437976725399494
# Episode:309 Score:500.0 Actor_Loss:0.0018981274915859103 Critic_Loss:0.01799614727497101
# Episode:310 Score:500.0 Actor_Loss:-0.012621143832802773 Critic_Loss:0.005611507222056389
# Episode:311 Score:500.0 Actor_Loss:0.013675582595169544 Critic_Loss:0.029032789170742035
# Episode:312 Score:500.0 Actor_Loss:0.006470886990427971 Critic_Loss:0.0019148237770423293
# Episode:313 Score:500.0 Actor_Loss:-0.03513416275382042 Critic_Loss:0.009696261025965214
# Episode:314 Score:500.0 Actor_Loss:0.0271848663687706 Critic_Loss:0.003498376114293933
# Episode:315 Score:500.0 Actor_Loss:0.03957868367433548 Critic_Loss:0.03733574226498604
# Episode:316 Score:500.0 Actor_Loss:-0.04557023569941521 Critic_Loss:0.008545652031898499
# Episode:317 Score:500.0 Actor_Loss:-0.03235751762986183 Critic_Loss:0.020465057343244553
# Episode:318 Score:500.0 Actor_Loss:0.05341875180602074 Critic_Loss:0.02348054014146328
# Episode:319 Score:500.0 Actor_Loss:0.06728652119636536 Critic_Loss:0.09735570102930069
# Episode:320 Score:500.0 Actor_Loss:-0.13486671447753906 Critic_Loss:0.053570374846458435
# Episode:321 Score:500.0 Actor_Loss:-0.0044824811629951 Critic_Loss:0.022839922457933426
# Episode:322 Score:500.0 Actor_Loss:0.09717246890068054 Critic_Loss:0.030347682535648346
# Episode:323 Score:500.0 Actor_Loss:0.04687891900539398 Critic_Loss:0.047388650476932526
# Episode:324 Score:500.0 Actor_Loss:-0.1393173187971115 Critic_Loss:0.06269164383411407
# Episode:325 Score:500.0 Actor_Loss:-0.01722266711294651 Critic_Loss:0.0029032512102276087
# Episode:326 Score:500.0 Actor_Loss:0.14928478002548218 Critic_Loss:0.05758874863386154
# Episode:327 Score:500.0 Actor_Loss:0.01499182265251875 Critic_Loss:0.001432744786143303
# Episode:328 Score:500.0 Actor_Loss:-0.10953425616025925 Critic_Loss:0.04178094118833542
# Episode:329 Score:500.0 Actor_Loss:-0.04407674819231033 Critic_Loss:0.00640439847484231
# Episode:330 Score:500.0 Actor_Loss:0.10913333296775818 Critic_Loss:0.028079895302653313
# Episode:331 Score:500.0 Actor_Loss:0.05156443268060684 Critic_Loss:0.009166271425783634
# Episode:332 Score:500.0 Actor_Loss:-0.08499225974082947 Critic_Loss:0.022727826610207558
# Episode:333 Score:500.0 Actor_Loss:-0.053340062499046326 Critic_Loss:0.009722555987536907
# Episode:334 Score:500.0 Actor_Loss:0.1285446584224701 Critic_Loss:0.05814791098237038
# Episode:335 Score:500.0 Actor_Loss:0.029957860708236694 Critic_Loss:0.002207872923463583
# Episode:336 Score:500.0 Actor_Loss:-0.06754498183727264 Critic_Loss:0.015645533800125122
# Episode:337 Score:500.0 Actor_Loss:-0.020353110507130623 Critic_Loss:0.003070334205403924
# Episode:338 Score:500.0 Actor_Loss:0.0748634934425354 Critic_Loss:0.032732438296079636
# Episode:339 Score:500.0 Actor_Loss:-0.001255116076208651 Critic_Loss:0.0006558157620020211
# Episode:340 Score:500.0 Actor_Loss:-0.06033046543598175 Critic_Loss:0.011657396331429482
# Episode:341 Score:500.0 Actor_Loss:0.015970705077052116 Critic_Loss:0.001068399753421545
# Episode:342 Score:500.0 Actor_Loss:0.062357548624277115 Critic_Loss:0.016092725098133087
# Episode:343 Score:500.0 Actor_Loss:-0.028452103957533836 Critic_Loss:0.006598080974072218
# Episode:344 Score:500.0 Actor_Loss:-0.012476875446736813 Critic_Loss:0.0012977527221664786
# Episode:345 Score:500.0 Actor_Loss:0.0205489881336689 Critic_Loss:0.007664619013667107
# Episode:346 Score:500.0 Actor_Loss:-0.004269564989954233 Critic_Loss:0.0011647198116406798
# Episode:347 Score:500.0 Actor_Loss:-0.0018074417021125555 Critic_Loss:0.0008777010370977223
# Episode:348 Score:500.0 Actor_Loss:0.0068777562119066715 Critic_Loss:0.006164564285427332
# Episode:349 Score:500.0 Actor_Loss:0.001330727944150567 Critic_Loss:0.0006733839400112629
# Episode:350 Score:500.0 Actor_Loss:0.003254873212426901 Critic_Loss:0.0007845956715755165
# Episode:351 Score:500.0 Actor_Loss:-0.0021516766864806414 Critic_Loss:0.009198518469929695
# Episode:352 Score:500.0 Actor_Loss:0.33872878551483154 Critic_Loss:0.65911865234375
# Episode:353 Score:500.0 Actor_Loss:-0.1878824681043625 Critic_Loss:0.108718641102314
# Episode:354 Score:500.0 Actor_Loss:-0.00020614761160686612 Critic_Loss:0.0075932457111775875
# Episode:355 Score:500.0 Actor_Loss:0.19583959877490997 Critic_Loss:0.11085858941078186
# Episode:356 Score:500.0 Actor_Loss:0.004190034698694944 Critic_Loss:0.033285729587078094
# Episode:357 Score:500.0 Actor_Loss:-0.18829552829265594 Critic_Loss:0.10101766884326935
# Episode:358 Score:500.0 Actor_Loss:0.013306221924722195 Critic_Loss:0.008201404474675655
# Episode:359 Score:500.0 Actor_Loss:0.14562441408634186 Critic_Loss:0.06235266104340553
# Episode:360 Score:500.0 Actor_Loss:0.0022858965676277876 Critic_Loss:0.010075836442410946
# Episode:361 Score:500.0 Actor_Loss:-0.15041381120681763 Critic_Loss:0.061279088258743286
# Episode:362 Score:500.0 Actor_Loss:0.035498637706041336 Critic_Loss:0.0118251396343112
# Episode:363 Score:500.0 Actor_Loss:0.2167414128780365 Critic_Loss:0.3386061489582062
# Episode:364 Score:500.0 Actor_Loss:-0.08683817833662033 Critic_Loss:0.030228180810809135
# Episode:365 Score:500.0 Actor_Loss:-0.0854339525103569 Critic_Loss:0.026374880224466324
# Episode:366 Score:500.0 Actor_Loss:0.12040755897760391 Critic_Loss:0.1957666426897049
# Episode:367 Score:500.0 Actor_Loss:0.11004484444856644 Critic_Loss:0.20331165194511414
# Episode:368 Score:500.0 Actor_Loss:-0.15047340095043182 Critic_Loss:0.06732220202684402
# Episode:369 Score:500.0 Actor_Loss:-0.04471847414970398 Critic_Loss:0.015839383006095886
# Episode:370 Score:500.0 Actor_Loss:0.1805102378129959 Critic_Loss:0.08162803947925568
# Episode:371 Score:500.0 Actor_Loss:-0.011524219065904617 Critic_Loss:0.010503961704671383
# Episode:372 Score:500.0 Actor_Loss:-0.10109691321849823 Critic_Loss:0.03680836781859398
# Episode:373 Score:500.0 Actor_Loss:-0.01916927471756935 Critic_Loss:0.00811999011784792
# Episode:374 Score:500.0 Actor_Loss:0.1241697371006012 Critic_Loss:0.052890922874212265
# Episode:375 Score:500.0 Actor_Loss:0.03934609144926071 Critic_Loss:0.10467065125703812
# Episode:376 Score:500.0 Actor_Loss:-0.18800944089889526 Critic_Loss:0.10758884996175766
# Episode:377 Score:500.0 Actor_Loss:0.032817501574754715 Critic_Loss:0.010080372914671898
# Episode:378 Score:500.0 Actor_Loss:0.16217876970767975 Critic_Loss:0.0720926970243454
# Episode:379 Score:500.0 Actor_Loss:-0.014314229600131512 Critic_Loss:0.010350292548537254
# Episode:380 Score:500.0 Actor_Loss:-0.14444346725940704 Critic_Loss:0.06735247373580933
# Episode:381 Score:500.0 Actor_Loss:0.028613537549972534 Critic_Loss:0.00336708826944232
# Episode:382 Score:500.0 Actor_Loss:0.13033543527126312 Critic_Loss:0.05662362277507782
# Episode:383 Score:500.0 Actor_Loss:-0.039474163204431534 Critic_Loss:0.009127359837293625
# Episode:384 Score:500.0 Actor_Loss:-0.08391601592302322 Critic_Loss:0.024950366467237473
# Episode:385 Score:500.0 Actor_Loss:0.015761954709887505 Critic_Loss:0.005497804377228022
# Episode:386 Score:500.0 Actor_Loss:0.095140241086483 Critic_Loss:0.026898927986621857
# Episode:387 Score:500.0 Actor_Loss:-0.014045197516679764 Critic_Loss:0.0018044889438897371
# Episode:388 Score:500.0 Actor_Loss:-0.08742142468690872 Critic_Loss:0.039747171103954315
# Episode:389 Score:500.0 Actor_Loss:0.015157726593315601 Critic_Loss:0.004210129380226135
# Episode:390 Score:500.0 Actor_Loss:0.05674846097826958 Critic_Loss:0.010216661728918552
# Episode:391 Score:500.0 Actor_Loss:-0.006294465158134699 Critic_Loss:0.003408161923289299
# Episode:392 Score:500.0 Actor_Loss:-0.04974576458334923 Critic_Loss:0.0089869424700737
# Episode:393 Score:500.0 Actor_Loss:0.015392320230603218 Critic_Loss:0.0034199259243905544
# Episode:394 Score:500.0 Actor_Loss:0.19818322360515594 Critic_Loss:0.35222381353378296
# Episode:395 Score:500.0 Actor_Loss:-0.13943135738372803 Critic_Loss:0.08272580057382584
# Episode:396 Score:500.0 Actor_Loss:-0.06133197620511055 Critic_Loss:0.017314590513706207
# Episode:397 Score:500.0 Actor_Loss:0.12149383872747421 Critic_Loss:0.04276423528790474
# Episode:398 Score:500.0 Actor_Loss:0.05841493979096413 Critic_Loss:0.01998724602162838
# Episode:399 Score:500.0 Actor_Loss:-0.1305750012397766 Critic_Loss:0.051579851657152176
# Episode:400 Score:500.0 Actor_Loss:-0.02125733159482479 Critic_Loss:0.002402649959549308
# Episode:401 Score:500.0 Actor_Loss:0.1285133808851242 Critic_Loss:0.04946649819612503
# Episode:402 Score:500.0 Actor_Loss:0.0015019905986264348 Critic_Loss:0.0006988177774474025
# Episode:403 Score:500.0 Actor_Loss:-0.11007221043109894 Critic_Loss:0.03360748291015625
# Episode:404 Score:500.0 Actor_Loss:0.010232033208012581 Critic_Loss:0.0069858902134001255
# Episode:405 Score:500.0 Actor_Loss:0.09046345949172974 Critic_Loss:0.022261803969740868
# Episode:406 Score:500.0 Actor_Loss:-0.011300569400191307 Critic_Loss:0.0014893951592966914
# Episode:407 Score:500.0 Actor_Loss:-0.08845575898885727 Critic_Loss:0.022596590220928192
# Episode:408 Score:500.0 Actor_Loss:0.03649042546749115 Critic_Loss:0.003695801831781864
# Episode:409 Score:500.0 Actor_Loss:0.07236270606517792 Critic_Loss:0.016276389360427856
# Episode:410 Score:500.0 Actor_Loss:-0.03402931988239288 Critic_Loss:0.009094600565731525
# Episode:411 Score:500.0 Actor_Loss:-0.059588685631752014 Critic_Loss:0.04946795478463173
# Episode:412 Score:500.0 Actor_Loss:0.02385600656270981 Critic_Loss:0.0014519572723656893
# Episode:413 Score:500.0 Actor_Loss:0.05613161623477936 Critic_Loss:0.01932121068239212
# Episode:414 Score:500.0 Actor_Loss:-0.011524098925292492 Critic_Loss:0.034222278743982315
# Episode:415 Score:500.0 Actor_Loss:-0.07127177715301514 Critic_Loss:0.019211340695619583
# Episode:416 Score:500.0 Actor_Loss:0.01632772758603096 Critic_Loss:0.002628421876579523
# Episode:417 Score:500.0 Actor_Loss:0.06936231255531311 Critic_Loss:0.013529813848435879
# Episode:418 Score:500.0 Actor_Loss:-0.02291138470172882 Critic_Loss:0.0022820832673460245
# Episode:419 Score:500.0 Actor_Loss:-0.053491536527872086 Critic_Loss:0.008952670730650425
# Episode:420 Score:500.0 Actor_Loss:0.03551477938890457 Critic_Loss:0.0031730113551020622
# Episode:421 Score:500.0 Actor_Loss:0.04404280334711075 Critic_Loss:0.005600472912192345
# Episode:422 Score:500.0 Actor_Loss:-0.033692244440317154 Critic_Loss:0.004625293891876936
# Episode:423 Score:500.0 Actor_Loss:-0.033266741782426834 Critic_Loss:0.003843167098239064
# Episode:424 Score:500.0 Actor_Loss:0.035696256905794144 Critic_Loss:0.005474688485264778
# Episode:425 Score:500.0 Actor_Loss:0.035610318183898926 Critic_Loss:0.017519531771540642
# Episode:426 Score:500.0 Actor_Loss:-0.0534227080643177 Critic_Loss:0.01487779337912798
# Episode:427 Score:500.0 Actor_Loss:0.0860527977347374 Critic_Loss:0.21630443632602692
# Episode:428 Score:500.0 Actor_Loss:-0.0719354897737503 Critic_Loss:0.015369947999715805
# Episode:429 Score:500.0 Actor_Loss:0.039014872163534164 Critic_Loss:0.004540564958006144
# Episode:430 Score:500.0 Actor_Loss:0.05805845931172371 Critic_Loss:0.02026602253317833
# Episode:431 Score:500.0 Actor_Loss:-0.05228874832391739 Critic_Loss:0.009242727421224117
# Episode:432 Score:500.0 Actor_Loss:-0.057747770100831985 Critic_Loss:0.07418479025363922
# Episode:433 Score:500.0 Actor_Loss:0.10869775712490082 Critic_Loss:0.032862234860658646
# Episode:434 Score:500.0 Actor_Loss:0.09002169221639633 Critic_Loss:0.20149564743041992
# Episode:435 Score:500.0 Actor_Loss:-0.19881568849086761 Critic_Loss:0.11142928153276443
# Episode:436 Score:500.0 Actor_Loss:0.04577392712235451 Critic_Loss:0.05223410576581955
# Episode:437 Score:500.0 Actor_Loss:0.1433883011341095 Critic_Loss:0.06867179274559021
# Episode:438 Score:500.0 Actor_Loss:-0.08963389694690704 Critic_Loss:0.02569773979485035
# Episode:439 Score:500.0 Actor_Loss:-0.10142991691827774 Critic_Loss:0.02863645926117897
# Episode:440 Score:500.0 Actor_Loss:0.10752656310796738 Critic_Loss:0.02997409924864769
# Episode:441 Score:500.0 Actor_Loss:0.0748613104224205 Critic_Loss:0.01575443521142006
# Episode:442 Score:500.0 Actor_Loss:-0.11254166811704636 Critic_Loss:0.037013325840234756
# Episode:443 Score:500.0 Actor_Loss:0.01741384156048298 Critic_Loss:0.11433228105306625
# Episode:444 Score:500.0 Actor_Loss:-0.008566807024180889 Critic_Loss:0.0015240531647577882
# Episode:445 Score:500.0 Actor_Loss:0.03835318237543106 Critic_Loss:0.005158432759344578
# Episode:446 Score:500.0 Actor_Loss:0.011253316886723042 Critic_Loss:0.0022689327597618103
# Episode:447 Score:500.0 Actor_Loss:-0.041098739951848984 Critic_Loss:0.005165509879589081
# Episode:448 Score:500.0 Actor_Loss:0.017022568732500076 Critic_Loss:0.001725303940474987
# Episode:449 Score:500.0 Actor_Loss:0.022491350769996643 Critic_Loss:0.001863754470832646
# Episode:450 Score:500.0 Actor_Loss:-0.015585565008223057 Critic_Loss:0.0012132690753787756
# Episode:451 Score:500.0 Actor_Loss:-0.005330686457455158 Critic_Loss:0.000303672015434131
# Episode:452 Score:500.0 Actor_Loss:0.018088307231664658 Critic_Loss:0.0009027133346535265
# Episode:453 Score:500.0 Actor_Loss:0.007388309109956026 Critic_Loss:0.00043051212560385466
# Episode:454 Score:500.0 Actor_Loss:0.0545048750936985 Critic_Loss:0.12786337733268738
# Episode:455 Score:500.0 Actor_Loss:-0.07628358900547028 Critic_Loss:0.018929844722151756
# Episode:456 Score:500.0 Actor_Loss:0.025625359266996384 Critic_Loss:0.0024910869542509317
# Episode:457 Score:500.0 Actor_Loss:0.0636383444070816 Critic_Loss:0.016289977356791496
# Episode:458 Score:500.0 Actor_Loss:-0.16889996826648712 Critic_Loss:0.19586198031902313
# Episode:459 Score:500.0 Actor_Loss:0.14575330913066864 Critic_Loss:0.08593343943357468
# Episode:460 Score:500.0 Actor_Loss:0.06783382594585419 Critic_Loss:0.019564315676689148
# Episode:461 Score:500.0 Actor_Loss:-0.18922564387321472 Critic_Loss:0.09574411809444427
# Episode:462 Score:500.0 Actor_Loss:-0.008660909719765186 Critic_Loss:0.027931638062000275
# Episode:463 Score:500.0 Actor_Loss:0.36440959572792053 Critic_Loss:0.4350068271160126
# Episode:464 Score:500.0 Actor_Loss:-0.1312483847141266 Critic_Loss:0.07764716446399689
# Episode:465 Score:500.0 Actor_Loss:-0.18115532398223877 Critic_Loss:0.0845523402094841
# Episode:466 Score:500.0 Actor_Loss:0.22700393199920654 Critic_Loss:0.16170550882816315
# Episode:467 Score:500.0 Actor_Loss:0.10247287154197693 Critic_Loss:0.028573688119649887
# Episode:468 Score:500.0 Actor_Loss:-0.2199302762746811 Critic_Loss:0.3097497224807739
# Episode:469 Score:500.0 Actor_Loss:-0.060359321534633636 Critic_Loss:0.027432246133685112
# Episode:470 Score:500.0 Actor_Loss:0.22943773865699768 Critic_Loss:0.1710120439529419
# Episode:471 Score:500.0 Actor_Loss:-0.012008506804704666 Critic_Loss:0.007638833019882441
# Episode:472 Score:500.0 Actor_Loss:-0.20596738159656525 Critic_Loss:0.10882366448640823
# Episode:473 Score:500.0 Actor_Loss:0.057518068701028824 Critic_Loss:0.01570151187479496
# Episode:474 Score:500.0 Actor_Loss:0.1635117381811142 Critic_Loss:0.08393914252519608
# Episode:475 Score:500.0 Actor_Loss:-0.07964051514863968 Critic_Loss:0.0336352214217186
# Episode:476 Score:500.0 Actor_Loss:-0.1444317102432251 Critic_Loss:0.061035867780447006
# Episode:477 Score:500.0 Actor_Loss:0.09288913756608963 Critic_Loss:0.024322522804141045
# Episode:478 Score:500.0 Actor_Loss:0.13110803067684174 Critic_Loss:0.053660184144973755
# Episode:479 Score:500.0 Actor_Loss:-0.17947937548160553 Critic_Loss:0.09478066861629486
# Episode:480 Score:500.0 Actor_Loss:-0.03318989649415016 Critic_Loss:0.010141399689018726
# Episode:481 Score:500.0 Actor_Loss:0.17645208537578583 Critic_Loss:0.07705157995223999
# Episode:482 Score:500.0 Actor_Loss:-0.03139873966574669 Critic_Loss:0.005807560868561268
# Episode:483 Score:500.0 Actor_Loss:-0.12519480288028717 Critic_Loss:0.04901622235774994
# Episode:484 Score:500.0 Actor_Loss:0.0726693794131279 Critic_Loss:0.018134957179427147
# Episode:485 Score:500.0 Actor_Loss:0.08583764731884003 Critic_Loss:0.018544074147939682
# Episode:486 Score:500.0 Actor_Loss:-0.08169341087341309 Critic_Loss:0.019836336374282837
# Episode:487 Score:500.0 Actor_Loss:-0.02916879765689373 Critic_Loss:0.005100216716527939
# Episode:488 Score:500.0 Actor_Loss:0.07888109982013702 Critic_Loss:0.02147679589688778
# Episode:489 Score:500.0 Actor_Loss:0.017917709425091743 Critic_Loss:0.0034653018228709698
# Episode:490 Score:500.0 Actor_Loss:-0.09591537714004517 Critic_Loss:0.029440177604556084
# Episode:491 Score:500.0 Actor_Loss:0.033021245151758194 Critic_Loss:0.01977424882352352
# Episode:492 Score:500.0 Actor_Loss:0.07656250149011612 Critic_Loss:0.01702963002026081
# Episode:493 Score:500.0 Actor_Loss:-0.06312209367752075 Critic_Loss:0.023072876036167145
# Episode:494 Score:500.0 Actor_Loss:-0.05224974453449249 Critic_Loss:0.008366196416318417
# Episode:495 Score:500.0 Actor_Loss:0.0901346281170845 Critic_Loss:0.04414578154683113
# Episode:496 Score:500.0 Actor_Loss:-0.0004386794753372669 Critic_Loss:0.013972271233797073
# Episode:497 Score:500.0 Actor_Loss:-0.06768414378166199 Critic_Loss:0.019219156354665756
# Episode:498 Score:500.0 Actor_Loss:0.012653842568397522 Critic_Loss:0.0013357169227674603
# Episode:499 Score:500.0 Actor_Loss:0.06222468614578247 Critic_Loss:0.010787093080580235

# %%
plt.plot(np.array(list(range(0, len(score)))), score, label='Score')
plt.plot(np.array(list(range(0, len(score), constant_for_average))), average_score, label='Average Score')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(actor_loss)))), actor_loss, label='Actor Loss')
plt.plot(np.array(list(range(0, len(actor_loss), constant_for_average))), average_actor_loss, label='Average Actor Loss')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(critic_loss)))), critic_loss, label='Critic Loss')
plt.plot(np.array(list(range(0, len(critic_loss), constant_for_average))), average_critic_loss, label='Average Critic Loss')
plt.legend()
plt.show()

# %%
file = open("Classical_Score_Loss_V8.txt", "x")
data = np.column_stack([score, actor_loss, critic_loss])
np.savetxt("Classical_Score_Loss_V8.txt",data)

# %%
total_params = sum(p.numel() for p in Critic.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 33793

# %%
total_params = sum(p.numel() for p in Actor.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 34050
