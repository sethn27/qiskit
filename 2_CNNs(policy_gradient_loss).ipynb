# %% [markdown]
# #### Importing Librarires

# %%
import gym, os
from itertools import count
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Categorical

import matplotlib.pyplot as plt
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class ActorNetwork(nn.Module):
    def __init__(self, state_space, action_space):
        super(ActorNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.layer_1 = nn.Linear(self.state_space, 128)
        self.layer_2 = nn.Linear(128, self.action_space)

    def forward(self, current_state):
        output_layer_1 = F.relu(self.layer_1(current_state))
        output_layer_2 = self.layer_2(output_layer_1)
        policy = Categorical(F.softmax(output_layer_2, dim=-1))
        return policy

# %%
class CriticNetwork(nn.Module):
    def __init__(self, state_space, action_space):
        super(CriticNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.layer_1 = nn.Linear(self.state_space, 128)
        self.layer_2 = nn.Linear(128, 1)

    def forward(self, current_state):
        output_layer_1 = F.relu(self.layer_1(current_state))
        state_value = self.layer_2(output_layer_1)
        return state_value

# %%
class Classical_Agent():
    def __init__(self, 
                 Actor,
                 Critic,
                 max_time_steps,
                 actor_learning_rate,
                 critic_learning_rate,
                 discount_factor,
                 number_of_epochs):
        
        self.max_time_steps = max_time_steps
        self.actor_learning_rate = actor_learning_rate
        self.critic_learning_rate = critic_learning_rate
        self.discount_factor = discount_factor
        self.number_of_epochs = number_of_epochs

        self.Actor = Actor
        self.Critic = Critic

        self.actor_optimizer = optim.Adam(self.Actor.parameters(), self.actor_learning_rate)
        self.critic_optimizer = optim.Adam(self.Critic.parameters(), self.critic_learning_rate)

    def clear_memory(self):
        self.rewards = []
        self.state_values = []
        self.log_policies = []
        self.done = []

    def replay_memory(self, 
                      state_value,
                      reward,
                      policy,
                      done):
        
        self.log_policies.append(policy)
        self.state_values.append(state_value)
        self.rewards.append(torch.tensor([reward],
                                         dtype = torch.float,
                                         device = device))
        self.done.append(torch.tensor([1-done],
                                      dtype = torch.float,
                                      device = device))
        
    def action_selection(self, 
                         current_state):
        current_state = torch.FloatTensor(current_state).to(device)
        policy = self.Actor(current_state)
        action = policy.sample()
        policy = policy.log_prob(action).unsqueeze(0)

        return action.cpu().numpy(), policy
    
    def compute_discounted_rewards(self, 
                                   next_state_value):
        R = next_state_value
        discounted_rewards = []
        for step in reversed(range(len(self.rewards))):
            R = self.rewards[step] + self.discount_factor * R * self.done[step]
            discounted_rewards.insert(0, R)
        return discounted_rewards
    
    def loss_function(self,
                      discounted_rewards):
        
        self.log_policies = torch.cat(self.log_policies)
        discounted_rewards = torch.cat(discounted_rewards).detach()
        self.state_values = torch.cat(self.state_values)

        advantage = discounted_rewards - self.state_values
        actor_loss = -(self.log_policies * advantage.detach()).mean()
        critic_loss = F.huber_loss(discounted_rewards, self.state_values)

        return actor_loss, critic_loss
    
    def training(self, next_state_value):
        discounted_rewards = self.compute_discounted_rewards(next_state_value)
        actor_loss, critic_loss = self.loss_function(discounted_rewards)

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()

        return actor_loss.item(), critic_loss.item()

# %%
enviroment = gym.make("CartPole-v1").unwrapped

state_space = enviroment.observation_space.shape[0]
action_space = enviroment.action_space.n

actor_learning_rate = 0.002
critic_learning_rate = 0.02

max_time_steps = 500
number_of_epochs = 1
number_of_episodes = 500
discount_factor = 0.99
constant_for_average = 10

Actor = ActorNetwork(state_space = state_space,
                     action_space = action_space).to(device)
Critic = CriticNetwork(state_space = state_space,
                       action_space = action_space).to(device)
Agent = Classical_Agent(Actor = Actor,
                        Critic = Critic,
                        max_time_steps = max_time_steps,
                        discount_factor = discount_factor,
                        actor_learning_rate = actor_learning_rate,
                        critic_learning_rate = critic_learning_rate,
                        number_of_epochs = number_of_epochs)

score = []
actor_loss = []
critic_loss = []

average_score = []
average_actor_loss = []
average_critic_loss = []

for current_episode in range(0, number_of_episodes):
    Agent.clear_memory()
    (current_state, _ ) = enviroment.reset()
    episodic_score  = 0

    for time_step in range(0, max_time_steps):
        enviroment.render()
        current_state = current_state
        action, policy = Agent.action_selection(current_state)
        current_state = torch.FloatTensor(current_state).to(device)
        state_value = Critic(current_state)

        next_state, reward, done, info, _ = enviroment.step(action)
        episodic_score += reward

        Agent.replay_memory(reward = reward,
                            policy = policy,
                            state_value = state_value,
                            done = done)
        
        current_state = next_state
        if done == True:
            break

    next_state = torch.FloatTensor(next_state).to(device)
    next_state_value = Critic(next_state)
    episodic_actor_loss, episodic_critic_loss = Agent.training(next_state_value = next_state_value)

    score.append(episodic_score)
    actor_loss.append(episodic_actor_loss)
    critic_loss.append(episodic_critic_loss)
    print('Episode:{} Score:{} Actor_Loss:{} Critic_Loss:{}'.format(current_episode, 
                                                                    episodic_score, 
                                                                    episodic_actor_loss, 
                                                                    episodic_critic_loss))
    
for i in range(0,int(len(score)/constant_for_average)):
    temp_score = sum(score[i * constant_for_average : (i+1) * constant_for_average])
    temp_actor_loss = sum(actor_loss[i * constant_for_average : (i+1) * constant_for_average])
    temp_critic_loss = sum(critic_loss[i * constant_for_average : (i+1) * constant_for_average])

    average_score.append(temp_score/10)
    average_actor_loss.append(temp_actor_loss/10)
    average_critic_loss.append(temp_critic_loss/10)
# Out:
# /Users/zam026/Dropbox/CSIRO/Projects/QRL for CartPole/Python Codes/PyTorch/PyTorch/lib/python3.11/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Episode:0 Score:22.0 Actor_Loss:7.459531784057617 Critic_Loss:10.401802062988281
# Episode:1 Score:26.0 Actor_Loss:8.421361923217773 Critic_Loss:11.581212997436523
# Episode:2 Score:12.0 Actor_Loss:3.326528310775757 Critic_Loss:4.8058342933654785
# Episode:3 Score:17.0 Actor_Loss:4.747233867645264 Critic_Loss:6.702975273132324
# Episode:4 Score:27.0 Actor_Loss:7.398641109466553 Critic_Loss:10.555822372436523
# Episode:5 Score:20.0 Actor_Loss:4.523462772369385 Critic_Loss:7.135579586029053
# Episode:6 Score:30.0 Actor_Loss:7.308070182800293 Critic_Loss:10.785528182983398
# Episode:7 Score:21.0 Actor_Loss:4.249541282653809 Critic_Loss:6.588728427886963
# Episode:8 Score:26.0 Actor_Loss:5.070573806762695 Critic_Loss:7.825345039367676
# Episode:9 Score:26.0 Actor_Loss:6.147140979766846 Critic_Loss:8.208700180053711
# Episode:10 Score:16.0 Actor_Loss:0.12929534912109375 Critic_Loss:4.253282070159912
# Episode:11 Score:10.0 Actor_Loss:-2.6448757648468018 Critic_Loss:4.420479774475098
# Episode:113 Score:209.0 Actor_Loss:13.008471488952637 Critic_Loss:29.00240135192871
# Episode:114 Score:40.0 Actor_Loss:-14.096713066101074 Critic_Loss:19.315885543823242
# Episode:115 Score:58.0 Actor_Loss:-9.473212242126465 Critic_Loss:14.774384498596191
# Episode:116 Score:129.0 Actor_Loss:4.387369632720947 Critic_Loss:17.005990982055664
# Episode:117 Score:125.0 Actor_Loss:2.808767080307007 Critic_Loss:15.60330867767334
# Episode:118 Score:255.0 Actor_Loss:16.62769889831543 Critic_Loss:30.682079315185547
# Episode:119 Score:132.0 Actor_Loss:5.899112224578857 Critic_Loss:14.338213920593262
# Episode:120 Score:143.0 Actor_Loss:2.056313991546631 Critic_Loss:18.689754486083984
# Episode:121 Score:101.0 Actor_Loss:3.178947925567627 Critic_Loss:8.7448091506958
# Episode:122 Score:41.0 Actor_Loss:-16.55867576599121 Critic_Loss:25.333410263061523
# Episode:123 Score:131.0 Actor_Loss:5.955423831939697 Critic_Loss:10.69459056854248
# Episode:124 Score:199.0 Actor_Loss:11.886460304260254 Critic_Loss:21.52215576171875
# Episode:125 Score:178.0 Actor_Loss:8.607629776000977 Critic_Loss:16.24152946472168
# Episode:126 Score:335.0 Actor_Loss:10.10245418548584 Critic_Loss:30.72736167907715
# Episode:127 Score:252.0 Actor_Loss:4.618738651275635 Critic_Loss:24.72480583190918
# Episode:128 Score:249.0 Actor_Loss:3.4228675365448 Critic_Loss:23.399433135986328
# Episode:129 Score:98.0 Actor_Loss:-11.6884765625 Critic_Loss:19.036483764648438
# Episode:130 Score:116.0 Actor_Loss:-9.377893447875977 Critic_Loss:18.177230834960938
# Episode:131 Score:281.0 Actor_Loss:4.735712051391602 Critic_Loss:23.7176570892334
# Episode:132 Score:268.0 Actor_Loss:2.685058116912842 Critic_Loss:21.84557342529297
# Episode:133 Score:300.0 Actor_Loss:5.667510986328125 Critic_Loss:25.99622917175293
# Episode:134 Score:144.0 Actor_Loss:-9.608123779296875 Critic_Loss:20.372224807739258
# Episode:135 Score:94.0 Actor_Loss:-11.282093048095703 Critic_Loss:18.308635711669922
# Episode:136 Score:108.0 Actor_Loss:-13.208599090576172 Critic_Loss:22.71860122680664
# Episode:137 Score:78.0 Actor_Loss:-25.71742820739746 Critic_Loss:29.702177047729492
# Episode:138 Score:162.0 Actor_Loss:-3.731001377105713 Critic_Loss:14.623649597167969
# Episode:139 Score:156.0 Actor_Loss:-3.36788272857666 Critic_Loss:15.00006103515625
# Episode:140 Score:115.0 Actor_Loss:-11.034059524536133 Critic_Loss:17.2624454498291
# Episode:141 Score:105.0 Actor_Loss:-8.85560131072998 Critic_Loss:16.323808670043945
# Episode:142 Score:143.0 Actor_Loss:1.7939602136611938 Critic_Loss:8.783926010131836
# Episode:143 Score:130.0 Actor_Loss:3.5179216861724854 Critic_Loss:7.943993091583252
# Episode:144 Score:143.0 Actor_Loss:7.819474220275879 Critic_Loss:14.0132474899292
# Episode:145 Score:374.0 Actor_Loss:22.137775421142578 Critic_Loss:38.30329895019531
# Episode:146 Score:281.0 Actor_Loss:9.072768211364746 Critic_Loss:25.149555206298828
# Episode:147 Score:390.0 Actor_Loss:13.302008628845215 Critic_Loss:30.30241584777832
# Episode:148 Score:144.0 Actor_Loss:7.92415714263916 Critic_Loss:13.381592750549316
# Episode:149 Score:367.0 Actor_Loss:12.409273147583008 Critic_Loss:27.28049659729004
# Episode:150 Score:269.0 Actor_Loss:11.567880630493164 Critic_Loss:21.721277236938477
# Episode:151 Score:114.0 Actor_Loss:-5.105140209197998 Critic_Loss:10.676162719726562
# Episode:152 Score:233.0 Actor_Loss:4.366727352142334 Critic_Loss:19.864704132080078
# Episode:153 Score:135.0 Actor_Loss:-4.620720386505127 Critic_Loss:11.793753623962402
# Episode:154 Score:269.0 Actor_Loss:7.372073173522949 Critic_Loss:17.108964920043945
# Episode:155 Score:286.0 Actor_Loss:10.13792610168457 Critic_Loss:24.533475875854492
# Episode:156 Score:402.0 Actor_Loss:8.962346076965332 Critic_Loss:21.335948944091797
# Episode:157 Score:160.0 Actor_Loss:-3.5076916217803955 Critic_Loss:14.527119636535645
# Episode:158 Score:157.0 Actor_Loss:1.1393189430236816 Critic_Loss:4.906569004058838
# Episode:159 Score:260.0 Actor_Loss:3.8440184593200684 Critic_Loss:7.217288494110107
# Episode:160 Score:408.0 Actor_Loss:1.0363292694091797 Critic_Loss:18.70270347595215
# Episode:161 Score:228.0 Actor_Loss:-7.043969631195068 Critic_Loss:18.261924743652344
# Episode:162 Score:272.0 Actor_Loss:2.5529589653015137 Critic_Loss:4.819015026092529
# Episode:163 Score:215.0 Actor_Loss:3.4389545917510986 Critic_Loss:8.274371147155762
# Episode:164 Score:174.0 Actor_Loss:-6.955541133880615 Critic_Loss:11.476601600646973
# Episode:165 Score:325.0 Actor_Loss:-6.955117225646973 Critic_Loss:17.38833999633789
# Episode:166 Score:185.0 Actor_Loss:-1.2701313495635986 Critic_Loss:2.328448534011841
# Episode:167 Score:134.0 Actor_Loss:-3.7948901653289795 Critic_Loss:10.03635025024414
# Episode:168 Score:61.0 Actor_Loss:-33.2209587097168 Critic_Loss:51.649070739746094
# Episode:169 Score:287.0 Actor_Loss:-10.36401653289795 Critic_Loss:20.615501403808594
# Episode:170 Score:226.0 Actor_Loss:4.457700729370117 Critic_Loss:7.79652214050293
# Episode:171 Score:288.0 Actor_Loss:-2.374483823776245 Critic_Loss:21.5946044921875
# Episode:172 Score:85.0 Actor_Loss:-26.50135040283203 Critic_Loss:47.48892593383789
# Episode:173 Score:301.0 Actor_Loss:3.196666955947876 Critic_Loss:9.775432586669922
# Episode:174 Score:174.0 Actor_Loss:-13.44648551940918 Critic_Loss:22.78709602355957
# Episode:175 Score:215.0 Actor_Loss:-10.194304466247559 Critic_Loss:19.353443145751953
# Episode:176 Score:128.0 Actor_Loss:-14.10410213470459 Critic_Loss:23.667980194091797
# Episode:177 Score:500.0 Actor_Loss:13.033646583557129 Critic_Loss:22.390949249267578
# Episode:178 Score:116.0 Actor_Loss:-15.536452293395996 Critic_Loss:26.34744644165039
# Episode:179 Score:500.0 Actor_Loss:13.702439308166504 Critic_Loss:23.19623374938965
# Episode:247 Score:500.0 Actor_Loss:3.508852481842041 Critic_Loss:6.681368827819824
# Episode:248 Score:500.0 Actor_Loss:1.0049198865890503 Critic_Loss:5.77028751373291
# Episode:249 Score:333.0 Actor_Loss:-8.632747650146484 Critic_Loss:19.661361694335938
# Episode:250 Score:500.0 Actor_Loss:-2.7674851417541504 Critic_Loss:5.563144683837891
# Episode:251 Score:500.0 Actor_Loss:-2.4826583862304688 Critic_Loss:5.012643814086914
# Episode:252 Score:500.0 Actor_Loss:-1.0373425483703613 Critic_Loss:5.62747859954834
# Episode:253 Score:500.0 Actor_Loss:-1.2155145406723022 Critic_Loss:3.7024924755096436
# Episode:254 Score:500.0 Actor_Loss:3.858910083770752 Critic_Loss:10.021453857421875
# Episode:255 Score:178.0 Actor_Loss:-27.159849166870117 Critic_Loss:43.32849884033203
# Episode:256 Score:500.0 Actor_Loss:0.9814043045043945 Critic_Loss:5.931641101837158
# Episode:257 Score:500.0 Actor_Loss:1.9567961692810059 Critic_Loss:4.198284149169922
# Episode:258 Score:500.0 Actor_Loss:-0.23474539816379547 Critic_Loss:1.6084827184677124
# Episode:259 Score:457.0 Actor_Loss:-0.5923125743865967 Critic_Loss:6.476415157318115
# Episode:260 Score:500.0 Actor_Loss:1.1952002048492432 Critic_Loss:2.8804516792297363
# Episode:261 Score:500.0 Actor_Loss:2.7250332832336426 Critic_Loss:4.900332450866699
# Episode:262 Score:413.0 Actor_Loss:-2.557910680770874 Critic_Loss:4.963099479675293
# Episode:263 Score:500.0 Actor_Loss:5.990249156951904 Critic_Loss:10.372893333435059
# Episode:264 Score:401.0 Actor_Loss:-1.9907881021499634 Critic_Loss:8.302955627441406
# Episode:265 Score:500.0 Actor_Loss:2.1355702877044678 Critic_Loss:4.4969706535339355
# Episode:266 Score:500.0 Actor_Loss:0.32635802030563354 Critic_Loss:1.5689924955368042
# Episode:267 Score:422.0 Actor_Loss:2.8875062465667725 Critic_Loss:9.456623077392578
# Episode:268 Score:500.0 Actor_Loss:0.24069498479366302 Critic_Loss:1.441443920135498
# Episode:269 Score:464.0 Actor_Loss:-5.484396934509277 Critic_Loss:9.400745391845703
# Episode:270 Score:500.0 Actor_Loss:-0.5447605848312378 Critic_Loss:1.845338225364685
# Episode:271 Score:500.0 Actor_Loss:-1.1611627340316772 Critic_Loss:1.7849280834197998
# Episode:272 Score:401.0 Actor_Loss:-12.11910629272461 Critic_Loss:20.703140258789062
# Episode:273 Score:500.0 Actor_Loss:0.09886957705020905 Critic_Loss:0.8310384750366211
# Episode:274 Score:500.0 Actor_Loss:2.3687312602996826 Critic_Loss:3.8873579502105713
# Episode:275 Score:500.0 Actor_Loss:0.6026955842971802 Critic_Loss:1.5717962980270386
# Episode:276 Score:500.0 Actor_Loss:1.2584706544876099 Critic_Loss:2.966541051864624
# Episode:277 Score:500.0 Actor_Loss:1.0538759231567383 Critic_Loss:1.582266092300415
# Episode:278 Score:500.0 Actor_Loss:4.694782733917236 Critic_Loss:8.893064498901367
# Episode:279 Score:500.0 Actor_Loss:0.39113694429397583 Critic_Loss:2.2675764560699463
# Episode:280 Score:500.0 Actor_Loss:-0.21628175675868988 Critic_Loss:1.3689963817596436
# Episode:281 Score:315.0 Actor_Loss:-17.4758358001709 Critic_Loss:30.682613372802734
# Episode:282 Score:307.0 Actor_Loss:-17.94818115234375 Critic_Loss:31.58809471130371
# Episode:283 Score:500.0 Actor_Loss:-0.4130837917327881 Critic_Loss:2.2931783199310303
# Episode:284 Score:413.0 Actor_Loss:-11.990677833557129 Critic_Loss:20.831371307373047
# Episode:285 Score:500.0 Actor_Loss:0.9563440084457397 Critic_Loss:1.7182228565216064
# Episode:286 Score:500.0 Actor_Loss:3.4197816848754883 Critic_Loss:5.9550862312316895
# Episode:287 Score:422.0 Actor_Loss:-9.905550003051758 Critic_Loss:17.423276901245117
# Episode:288 Score:500.0 Actor_Loss:2.2085163593292236 Critic_Loss:3.583030939102173
# Episode:289 Score:500.0 Actor_Loss:2.672490119934082 Critic_Loss:4.50461483001709
# Episode:290 Score:500.0 Actor_Loss:1.5466691255569458 Critic_Loss:2.502319574356079
# Episode:291 Score:500.0 Actor_Loss:2.7163209915161133 Critic_Loss:4.667219161987305
# Episode:292 Score:500.0 Actor_Loss:1.9094223976135254 Critic_Loss:3.291881799697876
# Episode:293 Score:500.0 Actor_Loss:0.1674782782793045 Critic_Loss:1.679179072380066
# Episode:294 Score:317.0 Actor_Loss:-19.40212631225586 Critic_Loss:31.248558044433594
# Episode:295 Score:500.0 Actor_Loss:-1.037197470664978 Critic_Loss:1.9453266859054565
# Episode:296 Score:500.0 Actor_Loss:-1.9247868061065674 Critic_Loss:3.277071475982666
# Episode:297 Score:500.0 Actor_Loss:-1.560528039932251 Critic_Loss:2.4625842571258545
# Episode:298 Score:500.0 Actor_Loss:-1.0789636373519897 Critic_Loss:1.7227903604507446
# Episode:299 Score:500.0 Actor_Loss:-1.7717546224594116 Critic_Loss:2.620351791381836
# Episode:300 Score:352.0 Actor_Loss:-13.98657512664795 Critic_Loss:23.25303840637207
# Episode:301 Score:457.0 Actor_Loss:-6.423583984375 Critic_Loss:15.190829277038574
# Episode:302 Score:294.0 Actor_Loss:-11.337467193603516 Critic_Loss:20.328346252441406
# Episode:303 Score:199.0 Actor_Loss:-18.53724479675293 Critic_Loss:31.183320999145508
# Episode:304 Score:412.0 Actor_Loss:-2.003127098083496 Critic_Loss:13.660775184631348
# Episode:305 Score:480.0 Actor_Loss:1.610827088356018 Critic_Loss:15.187677383422852
# Episode:306 Score:500.0 Actor_Loss:8.821676254272461 Critic_Loss:15.22722053527832
# Episode:307 Score:436.0 Actor_Loss:2.29784893989563 Critic_Loss:14.611551284790039
# Episode:308 Score:500.0 Actor_Loss:6.532312870025635 Critic_Loss:11.788217544555664
# Episode:309 Score:342.0 Actor_Loss:-2.2113075256347656 Critic_Loss:12.414970397949219
# Episode:310 Score:500.0 Actor_Loss:10.006675720214844 Critic_Loss:17.001976013183594
# Episode:311 Score:500.0 Actor_Loss:12.621642112731934 Critic_Loss:22.709779739379883
# Episode:312 Score:500.0 Actor_Loss:6.194892406463623 Critic_Loss:11.765913009643555
# Episode:313 Score:500.0 Actor_Loss:7.489468574523926 Critic_Loss:13.830065727233887
# Episode:314 Score:500.0 Actor_Loss:5.334825038909912 Critic_Loss:9.523497581481934
# Episode:315 Score:500.0 Actor_Loss:6.42597770690918 Critic_Loss:11.512247085571289
# Episode:316 Score:500.0 Actor_Loss:3.277466297149658 Critic_Loss:5.678785800933838
# Episode:317 Score:500.0 Actor_Loss:2.4262423515319824 Critic_Loss:3.878892421722412
# Episode:318 Score:500.0 Actor_Loss:-0.008424879983067513 Critic_Loss:0.43290814757347107
# Episode:319 Score:500.0 Actor_Loss:-1.1609033346176147 Critic_Loss:1.9206140041351318
# Episode:320 Score:500.0 Actor_Loss:-2.439901113510132 Critic_Loss:4.027002334594727
# Episode:321 Score:500.0 Actor_Loss:-2.0772478580474854 Critic_Loss:4.548097610473633
# Episode:322 Score:500.0 Actor_Loss:-3.374960422515869 Critic_Loss:6.077846527099609
# Episode:323 Score:500.0 Actor_Loss:-4.5354108810424805 Critic_Loss:8.166173934936523
# Episode:324 Score:500.0 Actor_Loss:-0.8891882300376892 Critic_Loss:5.792625904083252
# Episode:325 Score:500.0 Actor_Loss:-3.355445623397827 Critic_Loss:5.935628414154053
# Episode:326 Score:500.0 Actor_Loss:-2.791037082672119 Critic_Loss:4.762816429138184
# Episode:327 Score:500.0 Actor_Loss:-1.7748301029205322 Critic_Loss:3.070420503616333
# Episode:328 Score:500.0 Actor_Loss:-1.3421015739440918 Critic_Loss:2.0735247135162354
# Episode:329 Score:500.0 Actor_Loss:-0.29106011986732483 Critic_Loss:0.3182559311389923
# Episode:330 Score:168.0 Actor_Loss:-26.922176361083984 Critic_Loss:45.30500030517578
# Episode:331 Score:500.0 Actor_Loss:2.142806053161621 Critic_Loss:3.584547758102417
# Episode:332 Score:500.0 Actor_Loss:2.9100255966186523 Critic_Loss:4.990306854248047
# Episode:333 Score:500.0 Actor_Loss:3.6239750385284424 Critic_Loss:5.848736763000488
# Episode:334 Score:500.0 Actor_Loss:4.032814979553223 Critic_Loss:7.053491115570068
# Episode:335 Score:500.0 Actor_Loss:3.9862022399902344 Critic_Loss:7.071123123168945
# Episode:336 Score:500.0 Actor_Loss:3.243081569671631 Critic_Loss:5.635800838470459
# Episode:337 Score:500.0 Actor_Loss:3.7267489433288574 Critic_Loss:6.8757643699646
# Episode:338 Score:500.0 Actor_Loss:1.9315834045410156 Critic_Loss:3.244715690612793
# Episode:339 Score:500.0 Actor_Loss:0.5211446285247803 Critic_Loss:1.0290098190307617
# Episode:340 Score:500.0 Actor_Loss:-0.4913695752620697 Critic_Loss:0.9167077541351318
# Episode:341 Score:500.0 Actor_Loss:-1.3161879777908325 Critic_Loss:2.1170382499694824
# Episode:342 Score:500.0 Actor_Loss:-2.388622999191284 Critic_Loss:4.082505702972412
# Episode:343 Score:384.0 Actor_Loss:-16.70262336730957 Critic_Loss:29.97796058654785
# Episode:344 Score:500.0 Actor_Loss:-0.864677906036377 Critic_Loss:1.2147095203399658
# Episode:345 Score:243.0 Actor_Loss:-20.252017974853516 Critic_Loss:38.269046783447266
# Episode:346 Score:500.0 Actor_Loss:-0.1441926211118698 Critic_Loss:0.5799763202667236
# Episode:347 Score:500.0 Actor_Loss:0.7460386753082275 Critic_Loss:1.4456803798675537
# Episode:348 Score:500.0 Actor_Loss:0.961826741695404 Critic_Loss:2.0184717178344727
# Episode:349 Score:500.0 Actor_Loss:1.5779284238815308 Critic_Loss:2.605893135070801
# Episode:350 Score:500.0 Actor_Loss:1.714986801147461 Critic_Loss:2.6473538875579834
# Episode:351 Score:500.0 Actor_Loss:1.0720912218093872 Critic_Loss:1.5831807851791382
# Episode:352 Score:500.0 Actor_Loss:1.2331035137176514 Critic_Loss:1.9259033203125
# Episode:353 Score:500.0 Actor_Loss:0.17325353622436523 Critic_Loss:0.5311374068260193
# Episode:354 Score:500.0 Actor_Loss:-0.5621381998062134 Critic_Loss:1.138614296913147
# Episode:355 Score:500.0 Actor_Loss:-0.9599447846412659 Critic_Loss:1.6024832725524902
# Episode:356 Score:500.0 Actor_Loss:-1.1867417097091675 Critic_Loss:1.7977710962295532
# Episode:357 Score:500.0 Actor_Loss:-1.3278201818466187 Critic_Loss:2.065518856048584
# Episode:358 Score:500.0 Actor_Loss:-0.6303775906562805 Critic_Loss:1.0964659452438354
# Episode:359 Score:500.0 Actor_Loss:-0.3627116084098816 Critic_Loss:0.3742298483848572
# Episode:360 Score:500.0 Actor_Loss:0.31117352843284607 Critic_Loss:0.4795506000518799
# Episode:361 Score:500.0 Actor_Loss:1.4535549879074097 Critic_Loss:2.2829642295837402
# Episode:362 Score:500.0 Actor_Loss:0.9836475849151611 Critic_Loss:1.3274948596954346
# Episode:363 Score:500.0 Actor_Loss:1.3425531387329102 Critic_Loss:2.2003116607666016
# Episode:364 Score:500.0 Actor_Loss:0.5846877098083496 Critic_Loss:0.9012539386749268
# Episode:365 Score:500.0 Actor_Loss:-0.04114696756005287 Critic_Loss:0.12980996072292328
# Episode:366 Score:457.0 Actor_Loss:-5.415905475616455 Critic_Loss:9.737020492553711
# Episode:367 Score:500.0 Actor_Loss:-0.019181957468390465 Critic_Loss:0.2713596224784851
# Episode:368 Score:500.0 Actor_Loss:-0.562873363494873 Critic_Loss:0.8301290273666382
# Episode:369 Score:500.0 Actor_Loss:-0.5948465466499329 Critic_Loss:0.8930755257606506
# Episode:370 Score:500.0 Actor_Loss:-0.27609559893608093 Critic_Loss:0.21070726215839386
# Episode:371 Score:500.0 Actor_Loss:1.3959037065505981 Critic_Loss:2.2582201957702637
# Episode:372 Score:500.0 Actor_Loss:0.22731047868728638 Critic_Loss:0.33523163199424744
# Episode:373 Score:500.0 Actor_Loss:0.10522671788930893 Critic_Loss:0.23827922344207764
# Episode:374 Score:500.0 Actor_Loss:0.1863570213317871 Critic_Loss:0.3252853453159332
# Episode:375 Score:500.0 Actor_Loss:0.005034040659666061 Critic_Loss:0.07385053485631943
# Episode:376 Score:500.0 Actor_Loss:0.18988044559955597 Critic_Loss:0.36905571818351746
# Episode:377 Score:500.0 Actor_Loss:-0.03458590805530548 Critic_Loss:0.44984036684036255
# Episode:378 Score:500.0 Actor_Loss:-0.40320929884910583 Critic_Loss:0.3978273868560791
# Episode:379 Score:259.0 Actor_Loss:-20.00100326538086 Critic_Loss:34.4339485168457
# Episode:380 Score:500.0 Actor_Loss:0.45137014985084534 Critic_Loss:0.4606629014015198
# Episode:381 Score:500.0 Actor_Loss:0.07139682024717331 Critic_Loss:0.6228690147399902
# Episode:382 Score:500.0 Actor_Loss:0.2955329120159149 Critic_Loss:0.4659651517868042
# Episode:383 Score:500.0 Actor_Loss:0.32099151611328125 Critic_Loss:0.8360485434532166
# Episode:384 Score:500.0 Actor_Loss:0.16276788711547852 Critic_Loss:0.17105232179164886
# Episode:385 Score:500.0 Actor_Loss:0.1912362277507782 Critic_Loss:0.454730749130249
# Episode:386 Score:500.0 Actor_Loss:-0.0972084254026413 Critic_Loss:0.3565490245819092
# Episode:387 Score:457.0 Actor_Loss:-11.168782234191895 Critic_Loss:20.906946182250977
# Episode:388 Score:500.0 Actor_Loss:-0.14252294600009918 Critic_Loss:0.3655743896961212
# Episode:389 Score:500.0 Actor_Loss:0.2969348728656769 Critic_Loss:0.40390682220458984
# Episode:390 Score:500.0 Actor_Loss:0.4689987003803253 Critic_Loss:0.6518124938011169
# Episode:391 Score:500.0 Actor_Loss:0.3246690034866333 Critic_Loss:0.41328099370002747
# Episode:392 Score:500.0 Actor_Loss:0.058953072875738144 Critic_Loss:0.15198014676570892
# Episode:393 Score:500.0 Actor_Loss:-0.06542183458805084 Critic_Loss:0.43749281764030457
# Episode:394 Score:500.0 Actor_Loss:-0.8752760887145996 Critic_Loss:1.1941341161727905
# Episode:395 Score:500.0 Actor_Loss:-0.28392326831817627 Critic_Loss:0.32036200165748596
# Episode:396 Score:500.0 Actor_Loss:-0.05396244302392006 Critic_Loss:0.3430211842060089
# Episode:397 Score:489.0 Actor_Loss:-10.33637809753418 Critic_Loss:18.915340423583984
# Episode:398 Score:499.0 Actor_Loss:-8.91264533996582 Critic_Loss:17.081745147705078
# Episode:399 Score:500.0 Actor_Loss:0.8316489458084106 Critic_Loss:1.2974220514297485
# Episode:400 Score:453.0 Actor_Loss:-8.363234519958496 Critic_Loss:16.443042755126953
# Episode:401 Score:500.0 Actor_Loss:3.0486607551574707 Critic_Loss:5.166811466217041
# Episode:402 Score:500.0 Actor_Loss:1.7435681819915771 Critic_Loss:2.7815475463867188
# Episode:403 Score:500.0 Actor_Loss:1.4870065450668335 Critic_Loss:2.3799376487731934
# Episode:404 Score:500.0 Actor_Loss:1.4503047466278076 Critic_Loss:2.3376967906951904
# Episode:405 Score:500.0 Actor_Loss:1.8027571439743042 Critic_Loss:3.0732052326202393
# Episode:406 Score:500.0 Actor_Loss:0.04570242017507553 Critic_Loss:0.30256330966949463
# Episode:407 Score:500.0 Actor_Loss:-0.3405396640300751 Critic_Loss:0.6300936341285706
# Episode:408 Score:500.0 Actor_Loss:-1.2246710062026978 Critic_Loss:1.9371029138565063
# Episode:409 Score:355.0 Actor_Loss:-16.989330291748047 Critic_Loss:29.48587417602539
# Episode:410 Score:500.0 Actor_Loss:-1.2258108854293823 Critic_Loss:2.055459499359131
# Episode:411 Score:500.0 Actor_Loss:-1.5887858867645264 Critic_Loss:2.53861403465271
# Episode:412 Score:500.0 Actor_Loss:-0.7176545262336731 Critic_Loss:1.0852277278900146
# Episode:413 Score:500.0 Actor_Loss:-0.40643176436424255 Critic_Loss:0.4625008702278137
# Episode:414 Score:500.0 Actor_Loss:0.13953763246536255 Critic_Loss:0.1665400117635727
# Episode:415 Score:500.0 Actor_Loss:0.9917188286781311 Critic_Loss:1.430808663368225
# Episode:416 Score:500.0 Actor_Loss:1.314921498298645 Critic_Loss:2.0973565578460693
# Episode:417 Score:500.0 Actor_Loss:0.698233962059021 Critic_Loss:1.0555702447891235
# Episode:418 Score:500.0 Actor_Loss:0.6546762585639954 Critic_Loss:0.8828696608543396
# Episode:419 Score:500.0 Actor_Loss:0.1949859857559204 Critic_Loss:0.15706130862236023
# Episode:420 Score:500.0 Actor_Loss:-0.06716228276491165 Critic_Loss:0.08253882080316544
# Episode:421 Score:500.0 Actor_Loss:-0.10305412858724594 Critic_Loss:0.446709007024765
# Episode:422 Score:500.0 Actor_Loss:-0.7340046763420105 Critic_Loss:1.0403075218200684
# Episode:423 Score:500.0 Actor_Loss:0.46805840730667114 Critic_Loss:3.4923202991485596
# Episode:424 Score:500.0 Actor_Loss:-0.8450403809547424 Critic_Loss:1.097770094871521
# Episode:425 Score:500.0 Actor_Loss:0.21291480958461761 Critic_Loss:1.6900218725204468
# Episode:426 Score:500.0 Actor_Loss:-0.05504244565963745 Critic_Loss:0.5347672700881958
# Episode:427 Score:500.0 Actor_Loss:-0.16232579946517944 Critic_Loss:0.5192976593971252
# Episode:428 Score:500.0 Actor_Loss:0.5852109789848328 Critic_Loss:0.7255659699440002
# Episode:429 Score:500.0 Actor_Loss:0.6483256220817566 Critic_Loss:0.9467370510101318
# Episode:430 Score:500.0 Actor_Loss:1.6435832977294922 Critic_Loss:2.7170746326446533
# Episode:431 Score:489.0 Actor_Loss:-10.94546127319336 Critic_Loss:18.609363555908203
# Episode:432 Score:317.0 Actor_Loss:-15.337615013122559 Critic_Loss:26.964738845825195
# Episode:433 Score:500.0 Actor_Loss:0.3593319356441498 Critic_Loss:0.3028562366962433
# Episode:434 Score:500.0 Actor_Loss:0.40866008400917053 Critic_Loss:0.4141094982624054
# Episode:435 Score:500.0 Actor_Loss:0.25013893842697144 Critic_Loss:0.1799086481332779
# Episode:436 Score:500.0 Actor_Loss:0.1356697380542755 Critic_Loss:0.09636921435594559
# Episode:437 Score:500.0 Actor_Loss:-0.6328995823860168 Critic_Loss:0.7439857125282288
# Episode:438 Score:500.0 Actor_Loss:-0.36505070328712463 Critic_Loss:0.33790984749794006
# Episode:439 Score:500.0 Actor_Loss:-0.17277435958385468 Critic_Loss:0.18962669372558594
# Episode:440 Score:500.0 Actor_Loss:0.22827181220054626 Critic_Loss:0.25717484951019287
# Episode:441 Score:500.0 Actor_Loss:0.22713078558444977 Critic_Loss:0.22687813639640808
# Episode:442 Score:500.0 Actor_Loss:-0.08363065868616104 Critic_Loss:0.07801903784275055
# Episode:443 Score:500.0 Actor_Loss:-0.022593647241592407 Critic_Loss:0.0246351920068264
# Episode:444 Score:500.0 Actor_Loss:0.46184128522872925 Critic_Loss:0.44241711497306824
# Episode:445 Score:500.0 Actor_Loss:0.03904157504439354 Critic_Loss:0.009544655680656433
# Episode:446 Score:500.0 Actor_Loss:-0.0970296859741211 Critic_Loss:0.12602125108242035
# Episode:447 Score:500.0 Actor_Loss:-0.030137300491333008 Critic_Loss:0.33753660321235657
# Episode:448 Score:500.0 Actor_Loss:-0.23603913187980652 Critic_Loss:0.1846117526292801
# Episode:449 Score:500.0 Actor_Loss:-0.10658639669418335 Critic_Loss:0.20727573335170746
# Episode:450 Score:500.0 Actor_Loss:-0.03542234003543854 Critic_Loss:0.09016667306423187
# Episode:451 Score:500.0 Actor_Loss:-0.05620008334517479 Critic_Loss:0.032262109220027924
# Episode:452 Score:500.0 Actor_Loss:-0.021839093416929245 Critic_Loss:0.06884277611970901
# Episode:453 Score:500.0 Actor_Loss:0.18196988105773926 Critic_Loss:0.08141440898180008
# Episode:454 Score:500.0 Actor_Loss:0.20980502665042877 Critic_Loss:0.10812821239233017
# Episode:455 Score:500.0 Actor_Loss:0.16361087560653687 Critic_Loss:0.06034005060791969
# Episode:456 Score:500.0 Actor_Loss:0.18007640540599823 Critic_Loss:0.09961918741464615
# Episode:457 Score:500.0 Actor_Loss:-0.04912663623690605 Critic_Loss:0.0965765118598938
# Episode:458 Score:500.0 Actor_Loss:-0.32215064764022827 Critic_Loss:0.21142570674419403
# Episode:459 Score:500.0 Actor_Loss:-0.15517807006835938 Critic_Loss:0.12757019698619843
# Episode:460 Score:500.0 Actor_Loss:-0.11668984591960907 Critic_Loss:0.3561893403530121
# Episode:461 Score:500.0 Actor_Loss:-0.21903789043426514 Critic_Loss:0.10287526249885559
# Episode:462 Score:500.0 Actor_Loss:0.39591822028160095 Critic_Loss:0.4929032623767853
# Episode:463 Score:500.0 Actor_Loss:0.22044675052165985 Critic_Loss:0.09297985583543777
# Episode:464 Score:500.0 Actor_Loss:0.20190322399139404 Critic_Loss:0.08329983800649643
# Episode:465 Score:320.0 Actor_Loss:-17.178678512573242 Critic_Loss:28.63932228088379
# Episode:466 Score:500.0 Actor_Loss:0.1981913149356842 Critic_Loss:0.1032879501581192
# Episode:467 Score:500.0 Actor_Loss:0.25317129492759705 Critic_Loss:0.16879452764987946
# Episode:468 Score:500.0 Actor_Loss:0.07071001082658768 Critic_Loss:0.03869957476854324
# Episode:469 Score:500.0 Actor_Loss:0.2239314317703247 Critic_Loss:0.11973634362220764
# Episode:470 Score:500.0 Actor_Loss:-0.06967217475175858 Critic_Loss:0.017288770526647568
# Episode:471 Score:500.0 Actor_Loss:-0.32783591747283936 Critic_Loss:0.2812204658985138
# Episode:472 Score:500.0 Actor_Loss:-0.3753543794155121 Critic_Loss:0.32120421528816223
# Episode:473 Score:500.0 Actor_Loss:-0.20958195626735687 Critic_Loss:0.11702117323875427
# Episode:474 Score:500.0 Actor_Loss:0.5030741095542908 Critic_Loss:0.5295709371566772
# Episode:475 Score:500.0 Actor_Loss:0.13020585477352142 Critic_Loss:0.09277716279029846
# Episode:476 Score:500.0 Actor_Loss:0.3147113025188446 Critic_Loss:0.21557235717773438
# Episode:477 Score:500.0 Actor_Loss:0.16265742480754852 Critic_Loss:0.058489564806222916
# Episode:478 Score:500.0 Actor_Loss:-0.1486610621213913 Critic_Loss:0.05580919235944748
# Episode:479 Score:500.0 Actor_Loss:-0.24372164905071259 Critic_Loss:0.14102976024150848
# Episode:480 Score:500.0 Actor_Loss:-0.20018689334392548 Critic_Loss:0.10847802460193634
# Episode:481 Score:500.0 Actor_Loss:-0.16406966745853424 Critic_Loss:0.07779524475336075
# Episode:482 Score:500.0 Actor_Loss:-0.017468806356191635 Critic_Loss:0.02978629618883133
# Episode:483 Score:500.0 Actor_Loss:0.07749343663454056 Critic_Loss:0.07327260822057724
# Episode:484 Score:500.0 Actor_Loss:0.31247618794441223 Critic_Loss:0.2625409662723541
# Episode:485 Score:500.0 Actor_Loss:0.16241443157196045 Critic_Loss:0.0922677144408226
# Episode:486 Score:500.0 Actor_Loss:0.3778514266014099 Critic_Loss:0.38515394926071167
# Episode:487 Score:500.0 Actor_Loss:-0.31187960505485535 Critic_Loss:0.21179859340190887
# Episode:488 Score:500.0 Actor_Loss:-0.4061066508293152 Critic_Loss:0.34728291630744934
# Episode:489 Score:500.0 Actor_Loss:-0.13713717460632324 Critic_Loss:0.07429111003875732
# Episode:490 Score:500.0 Actor_Loss:-0.03953811153769493 Critic_Loss:0.009027235209941864
# Episode:491 Score:500.0 Actor_Loss:-0.24238266050815582 Critic_Loss:0.37550073862075806
# Episode:492 Score:500.0 Actor_Loss:0.3998265862464905 Critic_Loss:0.3028598725795746
# Episode:493 Score:500.0 Actor_Loss:0.3846152126789093 Critic_Loss:0.28529664874076843
# Episode:494 Score:500.0 Actor_Loss:0.20094750821590424 Critic_Loss:0.09406818449497223
# Episode:495 Score:500.0 Actor_Loss:0.7257589101791382 Critic_Loss:1.7008134126663208
# Episode:496 Score:500.0 Actor_Loss:-0.3718312084674835 Critic_Loss:0.29229485988616943
# Episode:497 Score:500.0 Actor_Loss:-0.5041966438293457 Critic_Loss:0.4875059425830841
# Episode:498 Score:500.0 Actor_Loss:1.5262227058410645 Critic_Loss:2.7694671154022217
# Episode:499 Score:500.0 Actor_Loss:-0.46315792202949524 Critic_Loss:0.894627034664154

# %%
plt.plot(np.array(list(range(0, len(score)))), score, label='Score')
plt.plot(np.array(list(range(0, len(score), constant_for_average))), average_score, label='Average Score')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(actor_loss)))), actor_loss, label='Actor Loss')
plt.plot(np.array(list(range(0, len(actor_loss), constant_for_average))), average_actor_loss, label='Average Actor Loss')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(critic_loss)))), critic_loss, label='Critic Loss')
plt.plot(np.array(list(range(0, len(critic_loss), constant_for_average))), average_critic_loss, label='Average Critic Loss')
plt.legend()
plt.show()

# %%
file = open("Classical_Score_Loss_V30(1_hidden_layer_4_input_fetures).txt", "x")
data = np.column_stack([score, actor_loss, critic_loss])
np.savetxt("Classical_Score_Loss_V30(1_hidden_layer_4_input_fetures).txt",data)

# %%
total_params = sum(p.numel() for p in Critic.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 769

# %%
total_params = sum(p.numel() for p in Actor.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 898
