# %% [markdown]
# #### Importing Librarires

# %%
import gym
import sys
import sys
import random

import torch
from torch.autograd import Function
from torchvision import datasets, transforms
import torch.optim as optim
import torch.nn as nn 
import torch.nn.functional as F 
from torch.distributions.categorical import Categorical
from sklearn.preprocessing import normalize

import math as mt
import numpy as np
import matplotlib.pyplot as plt
import qiskit
from qiskit import *
from qiskit import transpile, assemble
from qiskit.utils import QuantumInstance
from qiskit.visualization import *
import qiskit_machine_learning
from qiskit_machine_learning.neural_networks import SamplerQNN, CircuitQNN
from qiskit_machine_learning.neural_networks import EstimatorQNN
from qiskit_machine_learning.connectors import TorchConnector
from qiskit_ibm_runtime import Options

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

'''seed = 0
np.random.seed(seed)
torch.manual_seed(seed)
options = Options()
options.simulator.seed_simulator = seed'''

enviroment = gym.make("CartPole-v1").unwrapped
backend = qiskit.Aer.get_backend('qasm_simulator')

# %%
class HybridActorNetwork(nn.Module):
    def __init__(self, 
                 state_space, 
                 action_space,
                 number_of_qubits = 1,
                 number_of_shots = 1024):
        super(HybridActorNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.number_of_qubits = number_of_qubits
        self.number_of_shots = number_of_shots

        self.qubits = [i for i in range(0, self.number_of_qubits)]
        self.theta = qiskit.circuit.Parameter('theta')
        self.beta = qiskit.circuit.ParameterVector('beta', self.state_space)

        QuantumBits=qiskit.QuantumRegister(self.number_of_qubits)
        ClassicalBits=qiskit.ClassicalRegister(self.number_of_qubits)
        self.quantum_circuit = qiskit.QuantumCircuit(QuantumBits,
                                                     ClassicalBits)

        self.input_layer()
        self.parameterized_quantum_circuit()
        self.quantum_circuit.measure(QuantumBits,
                                     ClassicalBits)
        quantum_instance = QuantumInstance(backend = backend,
                                           shots = self.number_of_shots)
        quantum_neural_network = CircuitQNN(circuit = self.quantum_circuit,
                                            input_params = self.beta.params,
                                            weight_params = [self.theta],
                                            input_gradients = False,
                                            quantum_instance = quantum_instance)
        
        self.quantum_layer = TorchConnector(quantum_neural_network)

        self.classical_layer_1 = nn.Linear(64, self.action_space)

    def input_layer(self):
        self.quantum_circuit.h(self.qubits)
        self.quantum_circuit.barrier()

        self.quantum_circuit.rz(self.beta[0], self.qubits)
        self.quantum_circuit.ry(self.beta[1], self.qubits)
        self.quantum_circuit.rz(self.beta[2], self.qubits)
        self.quantum_circuit.barrier()

    def parameterized_quantum_circuit(self):
        self.quantum_circuit.rx(self.theta, self.qubits)
        self.quantum_circuit.barrier()

    def forward(self, current_state):

        output_layer_1 = self.quantum_layer(current_state)
        output_layer_1 = (output_layer_1[0]-output_layer_1[1]).repeat(64)
        output_layer_2 = F.relu(self.classical_layer_1(output_layer_1))
        
        policy = Categorical(F.softmax(output_layer_2, dim=-1))
        return policy

# %%
class HybridCriticNetwork(nn.Module):
    def __init__(self, 
                 state_space, 
                 action_space,
                 number_of_qubits = 1,
                 number_of_shots = 1024):
        super(HybridCriticNetwork, self).__init__()
        self.state_space = state_space
        self.action_space = action_space
        self.number_of_qubits = number_of_qubits
        self.number_of_shots = number_of_shots
        self.qubits = [i for i in range(0, self.number_of_qubits)]
        self.theta = qiskit.circuit.Parameter('theta')
        self.beta = qiskit.circuit.ParameterVector('beta', self.state_space)

        QuantumBits=qiskit.QuantumRegister(self.number_of_qubits)
        ClassicalBits=qiskit.ClassicalRegister(self.number_of_qubits)
        self.quantum_circuit = qiskit.QuantumCircuit(QuantumBits,
                                                     ClassicalBits)

        self.input_layer()
        self.parameterized_quantum_circuit()
        self.quantum_circuit.measure(QuantumBits,
                                     ClassicalBits)
        
        quantum_instance = QuantumInstance(backend = backend,
                                           shots = self.number_of_shots)
        quantum_neural_network = CircuitQNN(circuit = self.quantum_circuit,
                                            input_params = self.beta.params,
                                            weight_params = [self.theta],
                                            input_gradients = True,
                                            quantum_instance = quantum_instance)
        
        self.quantum_layer = TorchConnector(quantum_neural_network)

        self.classical_layer_1 = nn.Linear(64, 1)

    def input_layer(self):
        self.quantum_circuit.h(self.qubits)
        self.quantum_circuit.barrier()

        self.quantum_circuit.rz(self.beta[0], self.qubits)
        self.quantum_circuit.ry(self.beta[1], self.qubits)
        self.quantum_circuit.rz(self.beta[2], self.qubits)
        self.quantum_circuit.barrier()

    def parameterized_quantum_circuit(self):
        self.quantum_circuit.rx(self.theta, self.qubits)
        self.quantum_circuit.barrier()

    def forward(self, current_state):

        output_layer_1 = self.quantum_layer(current_state)
        output_layer_1 = (output_layer_1[0]-output_layer_1[1]).repeat(64)
        state_value = self.classical_layer_1(output_layer_1)
    
        return state_value

# %%
class QERL_Agent():
    def __init__(self, 
                 Actor,
                 Critic,
                 max_time_steps,
                 actor_learning_rate,
                 critic_learning_rate,
                 discount_factor,
                 number_of_epochs):
        
        self.max_time_steps = max_time_steps
        self.actor_learning_rate = actor_learning_rate
        self.critic_learning_rate = critic_learning_rate
        self.discount_factor = discount_factor
        self.number_of_epochs = number_of_epochs

        self.Actor = Actor
        self.Critic = Critic

        self.actor_optimizer = optim.Adam(self.Actor.parameters(), self.actor_learning_rate)
        self.critic_optimizer = optim.Adam(self.Critic.parameters(), self.critic_learning_rate)

    def clear_memory(self):
        self.rewards = []
        self.state_values = []
        self.log_policies = []
        self.done = []

    def replay_memory(self, 
                      state_value,
                      reward,
                      policy,
                      done):
        
        self.log_policies.append(policy)
        self.state_values.append(state_value)
        self.rewards.append(torch.tensor([reward],
                                         dtype = torch.float,
                                         device = device))
        self.done.append(torch.tensor([1-done],
                                      dtype = torch.float,
                                      device = device))
        
    def action_selection(self, 
                         current_state):
        current_state = torch.FloatTensor(current_state).to(device)
        policy = self.Actor(current_state)
        action = policy.sample()
        policy = policy.log_prob(action).unsqueeze(0)

        return action.cpu().numpy(), policy
    
    def compute_discounted_rewards(self, 
                                   next_state_value):
        R = next_state_value
        discounted_rewards = []
        for step in reversed(range(len(self.rewards))):
            R = self.rewards[step] + self.discount_factor * R * self.done[step]
            discounted_rewards.insert(0, R)
        return discounted_rewards
    
    def loss_function(self,
                      discounted_rewards):
        
        self.log_policies = torch.cat(self.log_policies)
        discounted_rewards = torch.cat(discounted_rewards).detach()
        self.state_values = torch.cat(self.state_values)

        advantage = discounted_rewards - self.state_values
        actor_loss = -(self.log_policies * advantage.detach()).mean()
        critic_loss = F.huber_loss(discounted_rewards, self.state_values)

        return actor_loss, critic_loss
    
    def training(self, next_state_value):
        discounted_rewards = self.compute_discounted_rewards(next_state_value)
        actor_loss, critic_loss = self.loss_function(discounted_rewards)

        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()

        self.critic_optimizer.zero_grad()
        critic_loss.backward()
        self.critic_optimizer.step()


        return actor_loss.item(), critic_loss.item()

# %%
def data_transformation(state):
        return [mt.atan(i) for i in state]

# %%
state_space = enviroment.observation_space.shape[0]-1
action_space = enviroment.action_space.n

actor_learning_rate = 0.02
critic_learning_rate = 0.2

max_time_steps = 500
number_of_epochs = 1
number_of_episodes = 500
discount_factor = 0.99
constant_for_average = 10

Actor = HybridActorNetwork(state_space = state_space,
                     action_space = action_space).to(device)
Critic = HybridCriticNetwork(state_space = state_space,
                       action_space = action_space).to(device)
Agent = QERL_Agent(Actor = Actor,
                        Critic = Critic,
                        max_time_steps = max_time_steps,
                        discount_factor = discount_factor,
                        actor_learning_rate = actor_learning_rate,
                        critic_learning_rate = critic_learning_rate,
                        number_of_epochs = number_of_epochs)

score = []
actor_loss = []
critic_loss = []

average_score = []
average_actor_loss = []
average_critic_loss = []

for current_episode in range(0, number_of_episodes):
    Agent.clear_memory()
    (current_state, _ ) = enviroment.reset()
    episodic_score  = 0

    for time_step in range(0, max_time_steps):
        enviroment.render()
        current_state = data_transformation(state = current_state[1:4])
        action, policy = Agent.action_selection(current_state)
        current_state = torch.FloatTensor(current_state).to(device)
        state_value = Critic(current_state)

        next_state, reward, done, info, _ = enviroment.step(action)
        episodic_score += reward

        Agent.replay_memory(reward = reward,
                            policy = policy,
                            state_value = state_value,
                            done = done)
        
        current_state = next_state
        if done == True:
            break

    next_state = data_transformation(state = next_state[1:4])
    next_state = torch.FloatTensor(next_state).to(device)
    next_state_value = Critic(next_state)
    episodic_actor_loss, episodic_critic_loss = Agent.training(next_state_value = next_state_value)

    score.append(episodic_score)
    actor_loss.append(episodic_actor_loss)
    critic_loss.append(episodic_critic_loss)
    print('Episode:{} Score:{} Actor_Loss:{} Critic_Loss:{}'.format(current_episode, 
                                                                    episodic_score, 
                                                                    episodic_actor_loss, 
                                                                    episodic_critic_loss))
    
for i in range(0,int(len(score)/constant_for_average)):
    temp_score = sum(score[i * constant_for_average : (i+1) * constant_for_average])
    temp_actor_loss = sum(actor_loss[i * constant_for_average : (i+1) * constant_for_average])
    temp_critic_loss = sum(critic_loss[i * constant_for_average : (i+1) * constant_for_average])

    average_score.append(temp_score/10)
    average_actor_loss.append(temp_actor_loss/10)
    average_critic_loss.append(temp_critic_loss/10)
# Out:
# /var/folders/5d/v7pmycsx3ld6mf_2fksw9vzc0000gn/T/ipykernel_71069/1355134908.py:26: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   quantum_instance = QuantumInstance(backend = backend,
# /Users/zam026/Dropbox/CSIRO/Projects/QRL for CartPole/Python Codes/PyTorch and Qiskit/.venv/lib/python3.11/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Episode:0 Score:14.0 Actor_Loss:5.139144420623779 Critic_Loss:6.6523003578186035
# Episode:1 Score:9.0 Actor_Loss:3.131927967071533 Critic_Loss:3.507538318634033
# /Users/zam026/Dropbox/CSIRO/Projects/QRL for CartPole/Python Codes/PyTorch and Qiskit/.venv/lib/python3.11/site-packages/gym/envs/classic_control/cartpole.py:211: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym("CartPole-v1", render_mode="rgb_array")
#   gym.logger.warn(
# Episode:2 Score:48.0 Actor_Loss:14.410446166992188 Critic_Loss:20.414386749267578
# Episode:3 Score:17.0 Actor_Loss:7.999631881713867 Critic_Loss:11.05884075164795
# Episode:4 Score:14.0 Actor_Loss:3.5956614017486572 Critic_Loss:4.953354835510254
# Episode:5 Score:37.0 Actor_Loss:11.33658504486084 Critic_Loss:15.981364250183105
# Episode:6 Score:29.0 Actor_Loss:8.087885856628418 Critic_Loss:11.222709655761719
# Episode:7 Score:58.0 Actor_Loss:14.200017929077148 Critic_Loss:21.69138526916504
# Episode:8 Score:21.0 Actor_Loss:6.0217156410217285 Critic_Loss:8.163647651672363
# Episode:9 Score:18.0 Actor_Loss:5.167199611663818 Critic_Loss:7.381771564483643
# Episode:10 Score:52.0 Actor_Loss:13.065876007080078 Critic_Loss:19.27348518371582
# Episode:11 Score:48.0 Actor_Loss:12.264313697814941 Critic_Loss:18.590778350830078
# Episode:12 Score:20.0 Actor_Loss:5.190560340881348 Critic_Loss:7.3473711013793945
# Episode:13 Score:37.0 Actor_Loss:9.3223237991333 Critic_Loss:13.586788177490234
# Episode:14 Score:15.0 Actor_Loss:3.990536689758301 Critic_Loss:5.652232646942139
# Episode:15 Score:62.0 Actor_Loss:15.258642196655273 Critic_Loss:23.757658004760742
# Episode:16 Score:41.0 Actor_Loss:10.29781436920166 Critic_Loss:16.39320945739746
# Episode:17 Score:33.0 Actor_Loss:7.471157073974609 Critic_Loss:12.039913177490234
# Episode:18 Score:85.0 Actor_Loss:18.289823532104492 Critic_Loss:29.25044822692871
# Episode:19 Score:51.0 Actor_Loss:12.142966270446777 Critic_Loss:18.09514808654785
# Episode:20 Score:38.0 Actor_Loss:8.528274536132812 Critic_Loss:13.13670539855957
# Episode:21 Score:43.0 Actor_Loss:9.884018898010254 Critic_Loss:15.481188774108887
# Episode:22 Score:31.0 Actor_Loss:6.261376857757568 Critic_Loss:10.258872985839844
# Episode:23 Score:37.0 Actor_Loss:6.194113254547119 Critic_Loss:11.881099700927734
# Episode:24 Score:34.0 Actor_Loss:6.589437961578369 Critic_Loss:11.378763198852539
# Episode:25 Score:45.0 Actor_Loss:8.535646438598633 Critic_Loss:15.365411758422852
# Episode:26 Score:40.0 Actor_Loss:8.007132530212402 Critic_Loss:12.986030578613281
# Episode:27 Score:34.0 Actor_Loss:6.633254528045654 Critic_Loss:10.418516159057617
# Episode:28 Score:25.0 Actor_Loss:3.421344041824341 Critic_Loss:7.374549388885498
# Episode:29 Score:43.0 Actor_Loss:8.779004096984863 Critic_Loss:13.98770809173584
# Episode:30 Score:37.0 Actor_Loss:7.2891154289245605 Critic_Loss:10.676119804382324
# Episode:31 Score:34.0 Actor_Loss:5.112911701202393 Critic_Loss:10.801875114440918
# Episode:32 Score:36.0 Actor_Loss:6.272825241088867 Critic_Loss:11.178030014038086
# Episode:33 Score:84.0 Actor_Loss:15.766819953918457 Critic_Loss:27.072614669799805
# Episode:34 Score:53.0 Actor_Loss:9.263179779052734 Critic_Loss:16.897775650024414
# Episode:35 Score:49.0 Actor_Loss:9.502849578857422 Critic_Loss:15.046220779418945
# Episode:36 Score:39.0 Actor_Loss:5.686188697814941 Critic_Loss:11.409730911254883
# Episode:37 Score:46.0 Actor_Loss:7.588597297668457 Critic_Loss:13.87375259399414
# Episode:38 Score:17.0 Actor_Loss:0.45894965529441833 Critic_Loss:3.7463459968566895
# Episode:39 Score:68.0 Actor_Loss:10.951247215270996 Critic_Loss:20.862871170043945
# Episode:40 Score:42.0 Actor_Loss:8.048215866088867 Critic_Loss:11.910130500793457
# Episode:41 Score:56.0 Actor_Loss:9.941271781921387 Critic_Loss:16.573678970336914
# Episode:42 Score:65.0 Actor_Loss:9.858064651489258 Critic_Loss:19.41025733947754
# Episode:43 Score:35.0 Actor_Loss:3.6878035068511963 Critic_Loss:9.046391487121582
# Episode:44 Score:64.0 Actor_Loss:9.767091751098633 Critic_Loss:18.54836082458496
# Episode:45 Score:34.0 Actor_Loss:3.486872673034668 Critic_Loss:8.453143119812012
# Episode:46 Score:49.0 Actor_Loss:6.817450523376465 Critic_Loss:13.629871368408203
# Episode:47 Score:74.0 Actor_Loss:10.400731086730957 Critic_Loss:21.251564025878906
# Episode:48 Score:28.0 Actor_Loss:1.6245700120925903 Critic_Loss:6.38387393951416
# Episode:49 Score:44.0 Actor_Loss:5.744291305541992 Critic_Loss:11.802698135375977
# Episode:50 Score:76.0 Actor_Loss:11.725844383239746 Critic_Loss:20.707088470458984
# Episode:51 Score:44.0 Actor_Loss:4.954167366027832 Critic_Loss:12.434183120727539
# Episode:52 Score:28.0 Actor_Loss:1.6226800680160522 Critic_Loss:5.359778881072998
# Episode:53 Score:91.0 Actor_Loss:13.420246124267578 Critic_Loss:25.669132232666016
# Episode:54 Score:70.0 Actor_Loss:10.614862442016602 Critic_Loss:20.26222801208496
# Episode:55 Score:51.0 Actor_Loss:6.702028274536133 Critic_Loss:12.45728588104248
# Episode:56 Score:51.0 Actor_Loss:6.698256492614746 Critic_Loss:12.887262344360352
# Episode:57 Score:54.0 Actor_Loss:5.994503974914551 Critic_Loss:15.295745849609375
# Episode:58 Score:68.0 Actor_Loss:8.48850154876709 Critic_Loss:18.94101905822754
# Episode:59 Score:31.0 Actor_Loss:1.7499587535858154 Critic_Loss:5.399166107177734
# Episode:60 Score:43.0 Actor_Loss:4.395926475524902 Critic_Loss:11.43916130065918
# Episode:61 Score:67.0 Actor_Loss:7.8876543045043945 Critic_Loss:17.072370529174805
# Episode:62 Score:40.0 Actor_Loss:2.160687208175659 Critic_Loss:8.24732780456543
# Episode:63 Score:65.0 Actor_Loss:6.549679756164551 Critic_Loss:18.020204544067383
# Episode:64 Score:39.0 Actor_Loss:3.5312867164611816 Critic_Loss:8.205635070800781
# Episode:65 Score:113.0 Actor_Loss:13.2522554397583 Critic_Loss:28.820423126220703
# Episode:66 Score:71.0 Actor_Loss:9.21705436706543 Critic_Loss:17.38047218322754
# Episode:67 Score:66.0 Actor_Loss:9.219250679016113 Critic_Loss:17.55143165588379
# Episode:68 Score:69.0 Actor_Loss:7.369641304016113 Critic_Loss:16.460126876831055
# Episode:69 Score:71.0 Actor_Loss:8.219502449035645 Critic_Loss:16.769676208496094
# Episode:70 Score:61.0 Actor_Loss:6.286959171295166 Critic_Loss:16.335887908935547
# Episode:71 Score:55.0 Actor_Loss:5.99283504486084 Critic_Loss:14.066828727722168
# Episode:72 Score:55.0 Actor_Loss:4.752468109130859 Critic_Loss:14.040081977844238
# Episode:73 Score:44.0 Actor_Loss:4.043846130371094 Critic_Loss:11.163556098937988
# Episode:74 Score:37.0 Actor_Loss:1.7904502153396606 Critic_Loss:5.9255595207214355
# Episode:75 Score:63.0 Actor_Loss:5.801721572875977 Critic_Loss:16.324357986450195
# Episode:76 Score:54.0 Actor_Loss:4.459577560424805 Critic_Loss:13.486082077026367
# Episode:77 Score:61.0 Actor_Loss:5.616291522979736 Critic_Loss:13.92982292175293
# Episode:78 Score:65.0 Actor_Loss:5.175808429718018 Critic_Loss:14.802689552307129
# Episode:79 Score:63.0 Actor_Loss:5.318763256072998 Critic_Loss:15.680074691772461
# Episode:80 Score:97.0 Actor_Loss:12.636730194091797 Critic_Loss:23.619661331176758
# Episode:81 Score:43.0 Actor_Loss:1.7237497568130493 Critic_Loss:8.501666069030762
# Episode:82 Score:92.0 Actor_Loss:9.683938980102539 Critic_Loss:22.6097354888916
# Episode:83 Score:114.0 Actor_Loss:11.686219215393066 Critic_Loss:27.30069923400879
# Episode:84 Score:62.0 Actor_Loss:4.502983570098877 Critic_Loss:14.430988311767578
# Episode:85 Score:58.0 Actor_Loss:4.096572399139404 Critic_Loss:12.634140968322754
# Episode:86 Score:84.0 Actor_Loss:7.774895668029785 Critic_Loss:19.539766311645508
# Episode:87 Score:36.0 Actor_Loss:0.3016120195388794 Critic_Loss:7.20567512512207
# Episode:88 Score:100.0 Actor_Loss:11.910395622253418 Critic_Loss:23.457902908325195
# Episode:89 Score:41.0 Actor_Loss:2.12754225730896 Critic_Loss:8.260074615478516
# Episode:90 Score:64.0 Actor_Loss:4.164422988891602 Critic_Loss:14.076868057250977
# Episode:91 Score:106.0 Actor_Loss:10.301718711853027 Critic_Loss:24.34602928161621
# Episode:92 Score:83.0 Actor_Loss:7.406332492828369 Critic_Loss:18.874298095703125
# Episode:93 Score:40.0 Actor_Loss:1.3950622081756592 Critic_Loss:7.9238739013671875
# Episode:94 Score:93.0 Actor_Loss:9.308753967285156 Critic_Loss:21.04816436767578
# Episode:95 Score:54.0 Actor_Loss:1.9584556818008423 Critic_Loss:10.932944297790527
# Episode:96 Score:78.0 Actor_Loss:6.343421936035156 Critic_Loss:17.138729095458984
# Episode:97 Score:70.0 Actor_Loss:5.467193126678467 Critic_Loss:14.706884384155273
# Episode:98 Score:109.0 Actor_Loss:9.7195405960083 Critic_Loss:24.51401710510254
# Episode:99 Score:110.0 Actor_Loss:9.747447967529297 Critic_Loss:24.68552017211914
# Episode:100 Score:96.0 Actor_Loss:6.9238715171813965 Critic_Loss:21.295564651489258
# Episode:101 Score:69.0 Actor_Loss:4.422417163848877 Critic_Loss:14.114298820495605
# Episode:102 Score:94.0 Actor_Loss:8.509854316711426 Critic_Loss:20.12254524230957
# Episode:103 Score:72.0 Actor_Loss:4.089536190032959 Critic_Loss:15.864949226379395
# Episode:104 Score:41.0 Actor_Loss:1.8135827779769897 Critic_Loss:8.325282096862793
# Episode:105 Score:42.0 Actor_Loss:0.4499853253364563 Critic_Loss:8.102660179138184
# Episode:106 Score:143.0 Actor_Loss:13.10566234588623 Critic_Loss:30.432353973388672
# Episode:107 Score:67.0 Actor_Loss:2.600024461746216 Critic_Loss:13.321773529052734
# Episode:108 Score:61.0 Actor_Loss:4.622143268585205 Critic_Loss:10.7941255569458
# Episode:109 Score:103.0 Actor_Loss:8.48066234588623 Critic_Loss:22.48162841796875
# Episode:110 Score:69.0 Actor_Loss:4.417166233062744 Critic_Loss:13.503318786621094
# Episode:111 Score:164.0 Actor_Loss:15.88218879699707 Critic_Loss:34.09000015258789
# Episode:112 Score:65.0 Actor_Loss:2.73933482170105 Critic_Loss:13.083622932434082
# Episode:113 Score:126.0 Actor_Loss:12.105719566345215 Critic_Loss:26.000822067260742
# Episode:114 Score:74.0 Actor_Loss:3.6742746829986572 Critic_Loss:14.180990219116211
# Episode:115 Score:65.0 Actor_Loss:1.9545761346817017 Critic_Loss:12.727635383605957
# Episode:116 Score:80.0 Actor_Loss:3.9204604625701904 Critic_Loss:16.809125900268555
# Episode:117 Score:83.0 Actor_Loss:6.189145088195801 Critic_Loss:16.656898498535156
# Episode:118 Score:55.0 Actor_Loss:0.02729984186589718 Critic_Loss:10.929348945617676
# Episode:119 Score:84.0 Actor_Loss:4.752321720123291 Critic_Loss:15.459946632385254
# Episode:120 Score:43.0 Actor_Loss:-1.2824594974517822 Critic_Loss:8.23551082611084
# Episode:121 Score:80.0 Actor_Loss:4.364579200744629 Critic_Loss:15.035481452941895
# Episode:122 Score:97.0 Actor_Loss:6.210507869720459 Critic_Loss:18.66497802734375
# Episode:123 Score:76.0 Actor_Loss:4.389737606048584 Critic_Loss:14.101395606994629
# Episode:124 Score:57.0 Actor_Loss:-0.0914338082075119 Critic_Loss:11.323057174682617
# Episode:125 Score:76.0 Actor_Loss:2.586230754852295 Critic_Loss:14.224140167236328
# Episode:126 Score:53.0 Actor_Loss:0.6268896460533142 Critic_Loss:9.717601776123047
# Episode:127 Score:60.0 Actor_Loss:0.59716796875 Critic_Loss:13.515595436096191
# Episode:128 Score:123.0 Actor_Loss:10.319700241088867 Critic_Loss:22.036758422851562
# Episode:129 Score:62.0 Actor_Loss:1.418412685394287 Critic_Loss:12.219124794006348
# Episode:130 Score:64.0 Actor_Loss:1.8732999563217163 Critic_Loss:12.263117790222168
# Episode:131 Score:53.0 Actor_Loss:0.10899409651756287 Critic_Loss:10.534394264221191
# Episode:132 Score:66.0 Actor_Loss:1.3855575323104858 Critic_Loss:11.749950408935547
# Episode:133 Score:70.0 Actor_Loss:3.528033971786499 Critic_Loss:11.253417015075684
# Episode:134 Score:56.0 Actor_Loss:0.9542595148086548 Critic_Loss:11.39286994934082
# Episode:135 Score:94.0 Actor_Loss:5.994247913360596 Critic_Loss:18.33854866027832
# Episode:136 Score:43.0 Actor_Loss:-3.6515560150146484 Critic_Loss:10.079824447631836
# Episode:137 Score:62.0 Actor_Loss:0.7574076056480408 Critic_Loss:12.564576148986816
# Episode:138 Score:135.0 Actor_Loss:10.07575511932373 Critic_Loss:26.238466262817383
# Episode:139 Score:122.0 Actor_Loss:8.071503639221191 Critic_Loss:24.930076599121094
# Episode:140 Score:80.0 Actor_Loss:3.41955304145813 Critic_Loss:15.185223579406738
# Episode:141 Score:52.0 Actor_Loss:1.8416495323181152 Critic_Loss:9.604120254516602
# Episode:142 Score:61.0 Actor_Loss:0.1857772320508957 Critic_Loss:11.528525352478027
# Episode:143 Score:198.0 Actor_Loss:15.091464042663574 Critic_Loss:35.78215026855469
# Episode:144 Score:112.0 Actor_Loss:8.562304496765137 Critic_Loss:21.953433990478516
# Episode:145 Score:53.0 Actor_Loss:-0.6954370141029358 Critic_Loss:9.354364395141602
# Episode:146 Score:108.0 Actor_Loss:6.145730495452881 Critic_Loss:21.256250381469727
# Episode:147 Score:157.0 Actor_Loss:13.272761344909668 Critic_Loss:29.51555633544922
# Episode:148 Score:36.0 Actor_Loss:-3.7419252395629883 Critic_Loss:9.180379867553711
# Episode:149 Score:79.0 Actor_Loss:3.270094871520996 Critic_Loss:14.61172103881836
# Episode:150 Score:132.0 Actor_Loss:8.501416206359863 Critic_Loss:25.38861656188965
# Episode:151 Score:81.0 Actor_Loss:3.213569164276123 Critic_Loss:15.111982345581055
# Episode:152 Score:164.0 Actor_Loss:11.189692497253418 Critic_Loss:30.67719268798828
# Episode:153 Score:57.0 Actor_Loss:1.5880706310272217 Critic_Loss:10.449426651000977
# Episode:154 Score:77.0 Actor_Loss:3.346301555633545 Critic_Loss:13.722691535949707
# Episode:155 Score:66.0 Actor_Loss:0.9295285940170288 Critic_Loss:12.258991241455078
# Episode:156 Score:99.0 Actor_Loss:5.705148220062256 Critic_Loss:18.279834747314453
# Episode:157 Score:137.0 Actor_Loss:9.305501937866211 Critic_Loss:25.86794662475586
# Episode:158 Score:221.0 Actor_Loss:14.05528450012207 Critic_Loss:37.87462615966797
# Episode:159 Score:83.0 Actor_Loss:2.4153354167938232 Critic_Loss:14.9111328125
# Episode:160 Score:96.0 Actor_Loss:4.663898944854736 Critic_Loss:17.25469207763672
# Episode:161 Score:142.0 Actor_Loss:9.309758186340332 Critic_Loss:25.8575382232666
# Episode:162 Score:82.0 Actor_Loss:1.9428837299346924 Critic_Loss:14.195660591125488
# Episode:163 Score:221.0 Actor_Loss:15.776300430297852 Critic_Loss:36.96099090576172
# Episode:164 Score:191.0 Actor_Loss:13.148857116699219 Critic_Loss:33.39845275878906
# Episode:165 Score:125.0 Actor_Loss:6.116358280181885 Critic_Loss:23.474170684814453
# Episode:166 Score:90.0 Actor_Loss:2.7814104557037354 Critic_Loss:15.069193840026855
# Episode:167 Score:105.0 Actor_Loss:4.389956951141357 Critic_Loss:19.44854736328125
# Episode:168 Score:324.0 Actor_Loss:18.674175262451172 Critic_Loss:45.483909606933594
# Episode:169 Score:90.0 Actor_Loss:3.066204071044922 Critic_Loss:16.421022415161133
# Episode:170 Score:130.0 Actor_Loss:7.472757339477539 Critic_Loss:22.505258560180664
# Episode:171 Score:161.0 Actor_Loss:9.533308029174805 Critic_Loss:27.83306884765625
# Episode:172 Score:74.0 Actor_Loss:-0.7482141256332397 Critic_Loss:14.298075675964355
# Episode:173 Score:86.0 Actor_Loss:2.43269944190979 Critic_Loss:16.04519271850586
# Episode:174 Score:181.0 Actor_Loss:9.797476768493652 Critic_Loss:31.208087921142578
# Episode:175 Score:134.0 Actor_Loss:9.169941902160645 Critic_Loss:22.885364532470703
# Episode:176 Score:149.0 Actor_Loss:7.208724021911621 Critic_Loss:25.212360382080078
# Episode:177 Score:83.0 Actor_Loss:2.2072434425354004 Critic_Loss:14.763442039489746
# Episode:178 Score:202.0 Actor_Loss:10.08739948272705 Critic_Loss:33.05352020263672
# Episode:179 Score:205.0 Actor_Loss:10.313398361206055 Critic_Loss:33.64686584472656
# Episode:180 Score:176.0 Actor_Loss:9.018040657043457 Critic_Loss:29.673795700073242
# Episode:181 Score:207.0 Actor_Loss:11.980758666992188 Critic_Loss:33.41927719116211
# Episode:182 Score:93.0 Actor_Loss:2.827171802520752 Critic_Loss:16.258056640625
# Episode:183 Score:130.0 Actor_Loss:5.865204811096191 Critic_Loss:22.215972900390625
# Episode:184 Score:167.0 Actor_Loss:7.681304454803467 Critic_Loss:28.197999954223633
# Episode:185 Score:73.0 Actor_Loss:0.20299817621707916 Critic_Loss:12.745007514953613
# Episode:186 Score:229.0 Actor_Loss:14.282191276550293 Critic_Loss:34.066680908203125
# Episode:187 Score:110.0 Actor_Loss:3.2871415615081787 Critic_Loss:19.471811294555664
# Episode:188 Score:181.0 Actor_Loss:10.02362060546875 Critic_Loss:29.022018432617188
# Episode:189 Score:108.0 Actor_Loss:2.600301742553711 Critic_Loss:17.740629196166992
# Episode:190 Score:343.0 Actor_Loss:17.602737426757812 Critic_Loss:44.00546646118164
# Episode:191 Score:75.0 Actor_Loss:-1.1056874990463257 Critic_Loss:12.223701477050781
# Episode:192 Score:230.0 Actor_Loss:11.325668334960938 Critic_Loss:35.641517639160156
# Episode:193 Score:175.0 Actor_Loss:9.554387092590332 Critic_Loss:27.144676208496094
# Episode:194 Score:290.0 Actor_Loss:13.215996742248535 Critic_Loss:39.455142974853516
# Episode:195 Score:264.0 Actor_Loss:13.626642227172852 Critic_Loss:38.26222610473633
# Episode:196 Score:208.0 Actor_Loss:11.104599952697754 Critic_Loss:30.842670440673828
# Episode:197 Score:207.0 Actor_Loss:8.473431587219238 Critic_Loss:32.68995666503906
# Episode:198 Score:298.0 Actor_Loss:15.045205116271973 Critic_Loss:40.00926971435547
# Episode:199 Score:500.0 Actor_Loss:20.275663375854492 Critic_Loss:54.123809814453125
# Episode:200 Score:461.0 Actor_Loss:17.43168830871582 Critic_Loss:48.4279899597168
# Episode:201 Score:157.0 Actor_Loss:5.099878787994385 Critic_Loss:24.27603530883789
# Episode:202 Score:123.0 Actor_Loss:3.505139112472534 Critic_Loss:20.0026912689209
# Episode:203 Score:117.0 Actor_Loss:3.3529155254364014 Critic_Loss:18.55333709716797
# Episode:204 Score:181.0 Actor_Loss:7.153652191162109 Critic_Loss:26.841445922851562
# Episode:205 Score:352.0 Actor_Loss:12.987483978271484 Critic_Loss:42.30222702026367
# Episode:206 Score:500.0 Actor_Loss:20.043458938598633 Critic_Loss:51.55825424194336
# Episode:207 Score:393.0 Actor_Loss:18.63235092163086 Critic_Loss:44.617034912109375
# Episode:208 Score:500.0 Actor_Loss:20.05052947998047 Critic_Loss:54.368892669677734
# Episode:209 Score:500.0 Actor_Loss:20.925079345703125 Critic_Loss:53.986568450927734
# Episode:210 Score:258.0 Actor_Loss:11.120543479919434 Critic_Loss:33.52186965942383
# Episode:211 Score:433.0 Actor_Loss:13.70156192779541 Critic_Loss:44.362159729003906
# Episode:212 Score:500.0 Actor_Loss:19.439546585083008 Critic_Loss:52.278072357177734
# Episode:213 Score:337.0 Actor_Loss:13.412031173706055 Critic_Loss:40.27779769897461
# Episode:214 Score:346.0 Actor_Loss:12.618683815002441 Critic_Loss:40.96698760986328
# Episode:215 Score:500.0 Actor_Loss:20.049299240112305 Critic_Loss:49.95334243774414
# Episode:216 Score:500.0 Actor_Loss:17.610246658325195 Critic_Loss:50.20228576660156
# Episode:217 Score:500.0 Actor_Loss:17.33124351501465 Critic_Loss:49.95711898803711
# Episode:218 Score:500.0 Actor_Loss:17.698427200317383 Critic_Loss:48.38629150390625
# Episode:219 Score:500.0 Actor_Loss:18.19013786315918 Critic_Loss:51.221519470214844
# Episode:220 Score:500.0 Actor_Loss:17.7071475982666 Critic_Loss:46.0948600769043
# Episode:221 Score:278.0 Actor_Loss:9.528924942016602 Critic_Loss:34.9071044921875
# Episode:222 Score:408.0 Actor_Loss:13.68974494934082 Critic_Loss:43.93269348144531
# Episode:223 Score:500.0 Actor_Loss:15.92533016204834 Critic_Loss:45.94363784790039
# Episode:224 Score:500.0 Actor_Loss:21.313095092773438 Critic_Loss:49.89680862426758
# Episode:225 Score:500.0 Actor_Loss:15.955650329589844 Critic_Loss:49.61515808105469
# Episode:226 Score:500.0 Actor_Loss:16.627620697021484 Critic_Loss:51.184471130371094
# Episode:227 Score:227.0 Actor_Loss:6.484066009521484 Critic_Loss:30.972721099853516
# Episode:228 Score:383.0 Actor_Loss:11.756150245666504 Critic_Loss:40.38088607788086
# Episode:229 Score:500.0 Actor_Loss:14.00411605834961 Critic_Loss:45.2379035949707
# Episode:230 Score:177.0 Actor_Loss:1.9680180549621582 Critic_Loss:28.446590423583984
# Episode:231 Score:500.0 Actor_Loss:17.08354949951172 Critic_Loss:49.464027404785156
# Episode:232 Score:500.0 Actor_Loss:15.949153900146484 Critic_Loss:47.240177154541016
# Episode:233 Score:500.0 Actor_Loss:16.589244842529297 Critic_Loss:50.225181579589844
# Episode:234 Score:334.0 Actor_Loss:9.698684692382812 Critic_Loss:38.192626953125
# Episode:235 Score:500.0 Actor_Loss:17.45722198486328 Critic_Loss:48.97072219848633
# Episode:236 Score:500.0 Actor_Loss:11.9584321975708 Critic_Loss:43.265663146972656
# Episode:237 Score:383.0 Actor_Loss:10.083418846130371 Critic_Loss:38.26996612548828
# Episode:238 Score:500.0 Actor_Loss:15.271468162536621 Critic_Loss:42.297637939453125
# Episode:239 Score:500.0 Actor_Loss:15.033825874328613 Critic_Loss:47.072418212890625
# Episode:240 Score:500.0 Actor_Loss:14.358271598815918 Critic_Loss:43.07135772705078
# Episode:241 Score:500.0 Actor_Loss:13.21865177154541 Critic_Loss:42.755367279052734
# Episode:242 Score:500.0 Actor_Loss:16.365886688232422 Critic_Loss:50.551963806152344
# Episode:243 Score:500.0 Actor_Loss:14.878872871398926 Critic_Loss:45.8935432434082
# Episode:244 Score:500.0 Actor_Loss:15.826530456542969 Critic_Loss:49.32404327392578
# Episode:245 Score:500.0 Actor_Loss:12.936294555664062 Critic_Loss:43.465396881103516
# Episode:246 Score:500.0 Actor_Loss:13.738553047180176 Critic_Loss:45.8345832824707
# Episode:247 Score:500.0 Actor_Loss:13.94728946685791 Critic_Loss:44.728755950927734
# Episode:248 Score:500.0 Actor_Loss:14.906257629394531 Critic_Loss:46.60715103149414
# Episode:249 Score:500.0 Actor_Loss:15.179250717163086 Critic_Loss:41.61039352416992
# Episode:250 Score:500.0 Actor_Loss:11.3734769821167 Critic_Loss:42.52787399291992
# Episode:251 Score:500.0 Actor_Loss:11.671639442443848 Critic_Loss:40.900150299072266
# Episode:252 Score:500.0 Actor_Loss:15.187702178955078 Critic_Loss:49.002952575683594
# Episode:253 Score:500.0 Actor_Loss:13.311371803283691 Critic_Loss:44.155494689941406
# Episode:254 Score:500.0 Actor_Loss:10.933899879455566 Critic_Loss:40.749549865722656
# Episode:255 Score:500.0 Actor_Loss:13.165387153625488 Critic_Loss:39.4626579284668
# Episode:256 Score:500.0 Actor_Loss:9.29643440246582 Critic_Loss:39.046451568603516
# Episode:257 Score:500.0 Actor_Loss:15.112884521484375 Critic_Loss:47.65614700317383
# Episode:258 Score:500.0 Actor_Loss:14.142613410949707 Critic_Loss:44.71044158935547
# Episode:259 Score:500.0 Actor_Loss:10.238743782043457 Critic_Loss:38.35208511352539
# Episode:260 Score:500.0 Actor_Loss:12.337481498718262 Critic_Loss:39.69189453125
# Episode:261 Score:500.0 Actor_Loss:13.435738563537598 Critic_Loss:44.07481384277344
# Episode:262 Score:500.0 Actor_Loss:12.349809646606445 Critic_Loss:43.76573944091797
# Episode:263 Score:500.0 Actor_Loss:11.455150604248047 Critic_Loss:38.1131706237793
# Episode:264 Score:500.0 Actor_Loss:15.679952621459961 Critic_Loss:44.37149429321289
# Episode:265 Score:500.0 Actor_Loss:11.485194206237793 Critic_Loss:38.61406707763672
# Episode:266 Score:500.0 Actor_Loss:13.668371200561523 Critic_Loss:45.12663269042969
# Episode:267 Score:500.0 Actor_Loss:9.776830673217773 Critic_Loss:38.664913177490234
# Episode:268 Score:500.0 Actor_Loss:13.642496109008789 Critic_Loss:42.53477478027344
# Episode:269 Score:500.0 Actor_Loss:11.53740406036377 Critic_Loss:41.191062927246094
# Episode:270 Score:500.0 Actor_Loss:11.591358184814453 Critic_Loss:38.86212158203125
# Episode:271 Score:500.0 Actor_Loss:11.518952369689941 Critic_Loss:36.62329864501953
# Episode:272 Score:500.0 Actor_Loss:13.156214714050293 Critic_Loss:41.52225112915039
# Episode:273 Score:500.0 Actor_Loss:10.385162353515625 Critic_Loss:37.185672760009766
# Episode:274 Score:500.0 Actor_Loss:7.123047828674316 Critic_Loss:35.966129302978516
# Episode:275 Score:500.0 Actor_Loss:11.524046897888184 Critic_Loss:39.71615982055664
# Episode:276 Score:500.0 Actor_Loss:6.542491436004639 Critic_Loss:36.57731246948242
# Episode:277 Score:500.0 Actor_Loss:11.052845001220703 Critic_Loss:39.78662872314453
# Episode:278 Score:500.0 Actor_Loss:11.087631225585938 Critic_Loss:38.24042892456055
# Episode:279 Score:500.0 Actor_Loss:11.855149269104004 Critic_Loss:38.27730178833008
# Episode:280 Score:500.0 Actor_Loss:11.068455696105957 Critic_Loss:38.882606506347656
# Episode:281 Score:500.0 Actor_Loss:12.503915786743164 Critic_Loss:37.70176315307617
# Episode:282 Score:500.0 Actor_Loss:10.262751579284668 Critic_Loss:38.367122650146484
# Episode:283 Score:500.0 Actor_Loss:10.792539596557617 Critic_Loss:37.23875045776367
# Episode:284 Score:500.0 Actor_Loss:12.305042266845703 Critic_Loss:41.50117111206055
# Episode:285 Score:500.0 Actor_Loss:7.777806282043457 Critic_Loss:33.91529083251953
# Episode:286 Score:371.0 Actor_Loss:5.646648406982422 Critic_Loss:32.39727783203125
# Episode:287 Score:269.0 Actor_Loss:3.4269461631774902 Critic_Loss:29.21933364868164
# Episode:288 Score:500.0 Actor_Loss:8.710243225097656 Critic_Loss:34.15773391723633
# Episode:289 Score:500.0 Actor_Loss:8.631156921386719 Critic_Loss:35.058345794677734
# Episode:290 Score:500.0 Actor_Loss:8.68214225769043 Critic_Loss:33.20410919189453
# Episode:291 Score:500.0 Actor_Loss:6.733891010284424 Critic_Loss:32.2425422668457
# Episode:292 Score:500.0 Actor_Loss:12.237955093383789 Critic_Loss:39.941646575927734
# Episode:293 Score:500.0 Actor_Loss:11.118025779724121 Critic_Loss:35.813968658447266
# Episode:294 Score:500.0 Actor_Loss:10.853541374206543 Critic_Loss:33.94756317138672
# Episode:295 Score:500.0 Actor_Loss:10.978872299194336 Critic_Loss:36.137550354003906
# Episode:296 Score:500.0 Actor_Loss:10.006887435913086 Critic_Loss:33.36165237426758
# Episode:297 Score:500.0 Actor_Loss:9.126275062561035 Critic_Loss:32.80341720581055
# Episode:298 Score:500.0 Actor_Loss:9.011218070983887 Critic_Loss:33.904911041259766
# Episode:299 Score:500.0 Actor_Loss:10.237195014953613 Critic_Loss:36.21236801147461
# Episode:300 Score:500.0 Actor_Loss:9.504610061645508 Critic_Loss:32.760231018066406
# Episode:301 Score:500.0 Actor_Loss:12.101953506469727 Critic_Loss:37.382652282714844
# Episode:302 Score:500.0 Actor_Loss:13.275446891784668 Critic_Loss:39.773250579833984
# Episode:303 Score:500.0 Actor_Loss:10.987810134887695 Critic_Loss:33.791603088378906
# Episode:304 Score:500.0 Actor_Loss:11.163267135620117 Critic_Loss:35.62392044067383
# Episode:305 Score:500.0 Actor_Loss:8.214590072631836 Critic_Loss:31.54485511779785
# Episode:306 Score:500.0 Actor_Loss:9.894777297973633 Critic_Loss:36.60915756225586
# Episode:307 Score:500.0 Actor_Loss:8.690949440002441 Critic_Loss:32.8094367980957
# Episode:308 Score:500.0 Actor_Loss:8.944580078125 Critic_Loss:34.09397888183594
# Episode:309 Score:500.0 Actor_Loss:8.69141674041748 Critic_Loss:30.069549560546875
# Episode:310 Score:500.0 Actor_Loss:11.192914962768555 Critic_Loss:37.39909362792969
# Episode:311 Score:500.0 Actor_Loss:7.34596586227417 Critic_Loss:29.79725456237793
# Episode:312 Score:500.0 Actor_Loss:10.184962272644043 Critic_Loss:33.66434860229492
# Episode:313 Score:500.0 Actor_Loss:8.849152565002441 Critic_Loss:32.176883697509766
# Episode:314 Score:500.0 Actor_Loss:8.447731018066406 Critic_Loss:29.880666732788086
# Episode:315 Score:500.0 Actor_Loss:12.513809204101562 Critic_Loss:36.30477523803711
# Episode:316 Score:500.0 Actor_Loss:9.138254165649414 Critic_Loss:29.56687355041504
# Episode:317 Score:500.0 Actor_Loss:9.418530464172363 Critic_Loss:34.993072509765625
# Episode:318 Score:500.0 Actor_Loss:9.096851348876953 Critic_Loss:30.37926483154297
# Episode:319 Score:500.0 Actor_Loss:8.363364219665527 Critic_Loss:32.92301559448242
# Episode:320 Score:479.0 Actor_Loss:3.947735071182251 Critic_Loss:28.610944747924805
# Episode:321 Score:500.0 Actor_Loss:7.632430076599121 Critic_Loss:26.89209747314453
# Episode:322 Score:500.0 Actor_Loss:6.905417442321777 Critic_Loss:27.089391708374023
# Episode:323 Score:500.0 Actor_Loss:8.319756507873535 Critic_Loss:31.324777603149414
# Episode:324 Score:500.0 Actor_Loss:8.354626655578613 Critic_Loss:28.26343536376953
# Episode:325 Score:313.0 Actor_Loss:1.7682945728302002 Critic_Loss:25.507028579711914
# Episode:326 Score:160.0 Actor_Loss:-5.359954833984375 Critic_Loss:23.71639633178711
# Episode:327 Score:500.0 Actor_Loss:9.277194023132324 Critic_Loss:32.00605773925781
# Episode:328 Score:500.0 Actor_Loss:6.9655890464782715 Critic_Loss:28.596675872802734
# Episode:329 Score:500.0 Actor_Loss:7.713421821594238 Critic_Loss:28.059345245361328
# Episode:330 Score:500.0 Actor_Loss:9.418972969055176 Critic_Loss:26.80013656616211
# Episode:331 Score:500.0 Actor_Loss:8.657523155212402 Critic_Loss:30.470619201660156
# Episode:332 Score:500.0 Actor_Loss:9.472307205200195 Critic_Loss:30.75658416748047
# Episode:333 Score:500.0 Actor_Loss:7.224001884460449 Critic_Loss:26.98113441467285
# Episode:334 Score:500.0 Actor_Loss:8.1884183883667 Critic_Loss:29.063812255859375
# Episode:335 Score:500.0 Actor_Loss:8.106861114501953 Critic_Loss:27.538623809814453
# Episode:336 Score:500.0 Actor_Loss:7.3083343505859375 Critic_Loss:25.899660110473633
# Episode:337 Score:500.0 Actor_Loss:8.837898254394531 Critic_Loss:30.256820678710938
# Episode:338 Score:500.0 Actor_Loss:9.472228050231934 Critic_Loss:27.927988052368164
# Episode:339 Score:500.0 Actor_Loss:6.95258903503418 Critic_Loss:26.099468231201172
# Episode:340 Score:500.0 Actor_Loss:6.869348526000977 Critic_Loss:24.627105712890625
# Episode:341 Score:500.0 Actor_Loss:7.446284294128418 Critic_Loss:24.68471908569336
# Episode:342 Score:500.0 Actor_Loss:6.7711944580078125 Critic_Loss:26.758102416992188
# Episode:343 Score:500.0 Actor_Loss:6.629336833953857 Critic_Loss:26.574478149414062
# Episode:344 Score:500.0 Actor_Loss:7.1296706199646 Critic_Loss:24.48757553100586
# Episode:345 Score:500.0 Actor_Loss:6.683262825012207 Critic_Loss:26.743896484375
# Episode:346 Score:500.0 Actor_Loss:7.161768436431885 Critic_Loss:27.209550857543945
# Episode:347 Score:500.0 Actor_Loss:7.700560092926025 Critic_Loss:25.36703872680664
# Episode:348 Score:500.0 Actor_Loss:9.822930335998535 Critic_Loss:27.39781951904297
# Episode:349 Score:500.0 Actor_Loss:6.9530534744262695 Critic_Loss:25.254362106323242
# Episode:350 Score:500.0 Actor_Loss:7.881417751312256 Critic_Loss:25.051218032836914
# Episode:351 Score:500.0 Actor_Loss:6.307805061340332 Critic_Loss:23.54599380493164
# Episode:352 Score:500.0 Actor_Loss:8.09192180633545 Critic_Loss:26.319442749023438
# Episode:353 Score:500.0 Actor_Loss:7.5979533195495605 Critic_Loss:25.747121810913086
# Episode:354 Score:500.0 Actor_Loss:7.486319541931152 Critic_Loss:26.152273178100586
# Episode:355 Score:500.0 Actor_Loss:8.205123901367188 Critic_Loss:26.13321876525879
# Episode:356 Score:500.0 Actor_Loss:7.00712251663208 Critic_Loss:23.930421829223633
# Episode:357 Score:500.0 Actor_Loss:7.995009422302246 Critic_Loss:24.321121215820312
# Episode:358 Score:500.0 Actor_Loss:6.9002461433410645 Critic_Loss:24.11640167236328
# Episode:359 Score:500.0 Actor_Loss:7.927345275878906 Critic_Loss:24.043474197387695
# Episode:360 Score:500.0 Actor_Loss:7.114030361175537 Critic_Loss:25.57647132873535
# Episode:361 Score:500.0 Actor_Loss:6.062558650970459 Critic_Loss:21.537778854370117
# Episode:362 Score:500.0 Actor_Loss:7.953390598297119 Critic_Loss:25.38712501525879
# Episode:363 Score:500.0 Actor_Loss:6.486357688903809 Critic_Loss:21.531940460205078
# Episode:364 Score:500.0 Actor_Loss:6.9267497062683105 Critic_Loss:23.171621322631836
# Episode:365 Score:500.0 Actor_Loss:7.522231578826904 Critic_Loss:25.24921989440918
# Episode:366 Score:500.0 Actor_Loss:5.831915378570557 Critic_Loss:21.249910354614258
# Episode:367 Score:500.0 Actor_Loss:5.809876918792725 Critic_Loss:23.268178939819336
# Episode:368 Score:500.0 Actor_Loss:5.234813213348389 Critic_Loss:20.355382919311523
# Episode:369 Score:500.0 Actor_Loss:8.29061222076416 Critic_Loss:24.77014923095703
# Episode:370 Score:500.0 Actor_Loss:5.103564262390137 Critic_Loss:19.939422607421875
# Episode:371 Score:500.0 Actor_Loss:5.919165134429932 Critic_Loss:21.664138793945312
# Episode:372 Score:500.0 Actor_Loss:7.739546775817871 Critic_Loss:22.086746215820312
# Episode:373 Score:500.0 Actor_Loss:7.34186315536499 Critic_Loss:20.40819549560547
# Episode:374 Score:500.0 Actor_Loss:5.977898120880127 Critic_Loss:19.706172943115234
# Episode:375 Score:500.0 Actor_Loss:6.724370002746582 Critic_Loss:18.901920318603516
# Episode:376 Score:500.0 Actor_Loss:7.3160600662231445 Critic_Loss:23.413848876953125
# Episode:377 Score:500.0 Actor_Loss:6.58715295791626 Critic_Loss:23.821735382080078
# Episode:378 Score:500.0 Actor_Loss:5.356464862823486 Critic_Loss:20.21617317199707
# Episode:379 Score:500.0 Actor_Loss:6.549715042114258 Critic_Loss:20.252273559570312
# Episode:380 Score:500.0 Actor_Loss:6.025503158569336 Critic_Loss:18.67113494873047
# Episode:381 Score:500.0 Actor_Loss:6.656086444854736 Critic_Loss:20.00722312927246
# Episode:382 Score:500.0 Actor_Loss:5.4015045166015625 Critic_Loss:18.046009063720703
# Episode:383 Score:500.0 Actor_Loss:6.9016523361206055 Critic_Loss:21.697311401367188
# Episode:384 Score:500.0 Actor_Loss:5.25104284286499 Critic_Loss:18.546274185180664
# Episode:385 Score:500.0 Actor_Loss:6.164316177368164 Critic_Loss:18.0123233795166
# Episode:386 Score:500.0 Actor_Loss:4.947600364685059 Critic_Loss:17.390968322753906
# Episode:387 Score:500.0 Actor_Loss:6.970764636993408 Critic_Loss:22.089855194091797
# Episode:388 Score:500.0 Actor_Loss:4.788905620574951 Critic_Loss:16.553762435913086
# Episode:389 Score:500.0 Actor_Loss:6.313529014587402 Critic_Loss:18.52715301513672
# Episode:390 Score:500.0 Actor_Loss:4.733828544616699 Critic_Loss:17.629581451416016
# Episode:391 Score:500.0 Actor_Loss:4.59226655960083 Critic_Loss:18.05729866027832
# Episode:392 Score:500.0 Actor_Loss:4.742177963256836 Critic_Loss:16.332929611206055
# Episode:393 Score:500.0 Actor_Loss:5.442055702209473 Critic_Loss:15.642526626586914
# Episode:394 Score:500.0 Actor_Loss:5.124391078948975 Critic_Loss:18.185537338256836
# Episode:395 Score:500.0 Actor_Loss:6.639166355133057 Critic_Loss:19.512367248535156
# Episode:396 Score:500.0 Actor_Loss:5.346879482269287 Critic_Loss:16.357999801635742
# Episode:397 Score:500.0 Actor_Loss:6.097863674163818 Critic_Loss:18.108795166015625
# Episode:398 Score:500.0 Actor_Loss:5.653102874755859 Critic_Loss:18.3973331451416
# Episode:399 Score:500.0 Actor_Loss:5.036688327789307 Critic_Loss:16.596145629882812
# Episode:400 Score:500.0 Actor_Loss:5.758320331573486 Critic_Loss:16.550058364868164
# Episode:401 Score:500.0 Actor_Loss:4.298181533813477 Critic_Loss:14.770990371704102
# Episode:402 Score:500.0 Actor_Loss:4.360875129699707 Critic_Loss:15.013752937316895
# Episode:403 Score:500.0 Actor_Loss:4.548471450805664 Critic_Loss:15.221152305603027
# Episode:404 Score:500.0 Actor_Loss:5.470487117767334 Critic_Loss:16.415300369262695
# Episode:405 Score:500.0 Actor_Loss:5.76999044418335 Critic_Loss:16.962032318115234
# Episode:406 Score:500.0 Actor_Loss:4.534540176391602 Critic_Loss:16.50983238220215
# Episode:407 Score:500.0 Actor_Loss:3.5707685947418213 Critic_Loss:13.590319633483887
# Episode:408 Score:500.0 Actor_Loss:4.806521415710449 Critic_Loss:14.18137264251709
# Episode:409 Score:500.0 Actor_Loss:3.5203256607055664 Critic_Loss:13.31104850769043
# Episode:410 Score:500.0 Actor_Loss:3.756448984146118 Critic_Loss:13.10285472869873
# Episode:411 Score:500.0 Actor_Loss:5.451331615447998 Critic_Loss:15.570493698120117
# Episode:412 Score:500.0 Actor_Loss:4.884798526763916 Critic_Loss:14.746393203735352
# Episode:413 Score:500.0 Actor_Loss:4.298288345336914 Critic_Loss:14.900663375854492
# Episode:414 Score:500.0 Actor_Loss:3.7902309894561768 Critic_Loss:13.248620986938477
# Episode:415 Score:500.0 Actor_Loss:4.027546405792236 Critic_Loss:13.89420223236084
# Episode:416 Score:500.0 Actor_Loss:3.8350563049316406 Critic_Loss:12.18057632446289
# Episode:417 Score:500.0 Actor_Loss:3.323554515838623 Critic_Loss:12.472986221313477
# Episode:418 Score:500.0 Actor_Loss:4.086036205291748 Critic_Loss:13.617987632751465
# Episode:419 Score:500.0 Actor_Loss:4.979875564575195 Critic_Loss:14.39891529083252
# Episode:420 Score:500.0 Actor_Loss:3.730940341949463 Critic_Loss:12.390348434448242
# Episode:421 Score:500.0 Actor_Loss:4.423733711242676 Critic_Loss:14.015382766723633
# Episode:422 Score:500.0 Actor_Loss:4.670913219451904 Critic_Loss:13.574162483215332
# Episode:423 Score:500.0 Actor_Loss:3.4562325477600098 Critic_Loss:12.143630027770996
# Episode:424 Score:500.0 Actor_Loss:3.6112303733825684 Critic_Loss:12.024720191955566
# Episode:425 Score:500.0 Actor_Loss:4.779384613037109 Critic_Loss:12.443607330322266
# Episode:426 Score:500.0 Actor_Loss:2.6769697666168213 Critic_Loss:10.963812828063965
# Episode:427 Score:500.0 Actor_Loss:3.6288998126983643 Critic_Loss:11.306814193725586
# Episode:428 Score:500.0 Actor_Loss:3.0163536071777344 Critic_Loss:10.648755073547363
# Episode:429 Score:500.0 Actor_Loss:4.595104694366455 Critic_Loss:14.137494087219238
# Episode:430 Score:500.0 Actor_Loss:3.6612794399261475 Critic_Loss:10.734163284301758
# Episode:431 Score:500.0 Actor_Loss:3.027186632156372 Critic_Loss:10.275507926940918
# Episode:432 Score:500.0 Actor_Loss:3.379453420639038 Critic_Loss:10.203125
# Episode:433 Score:500.0 Actor_Loss:3.6438281536102295 Critic_Loss:11.114233016967773
# Episode:434 Score:500.0 Actor_Loss:2.640577793121338 Critic_Loss:9.959403991699219
# Episode:435 Score:500.0 Actor_Loss:2.944852113723755 Critic_Loss:10.738272666931152
# Episode:436 Score:500.0 Actor_Loss:3.1629130840301514 Critic_Loss:10.136672019958496
# Episode:437 Score:500.0 Actor_Loss:3.8040478229522705 Critic_Loss:11.564801216125488
# Episode:438 Score:500.0 Actor_Loss:2.3937625885009766 Critic_Loss:8.789143562316895
# Episode:439 Score:500.0 Actor_Loss:3.0158634185791016 Critic_Loss:9.407455444335938
# Episode:440 Score:500.0 Actor_Loss:3.4763009548187256 Critic_Loss:9.810487747192383
# Episode:441 Score:500.0 Actor_Loss:2.251690149307251 Critic_Loss:7.832001686096191
# Episode:442 Score:500.0 Actor_Loss:2.667602777481079 Critic_Loss:8.783998489379883
# Episode:443 Score:500.0 Actor_Loss:3.6541712284088135 Critic_Loss:10.336763381958008
# Episode:444 Score:500.0 Actor_Loss:2.3907177448272705 Critic_Loss:7.943572521209717
# Episode:445 Score:500.0 Actor_Loss:2.8643484115600586 Critic_Loss:9.29079532623291
# Episode:446 Score:500.0 Actor_Loss:2.358151435852051 Critic_Loss:8.331533432006836
# Episode:447 Score:500.0 Actor_Loss:2.0722732543945312 Critic_Loss:7.46156120300293
# Episode:448 Score:500.0 Actor_Loss:1.9929020404815674 Critic_Loss:7.681506633758545
# Episode:449 Score:500.0 Actor_Loss:2.3753116130828857 Critic_Loss:7.581353664398193
# Episode:450 Score:500.0 Actor_Loss:2.7772512435913086 Critic_Loss:7.699825763702393
# Episode:451 Score:500.0 Actor_Loss:2.638521909713745 Critic_Loss:7.837356090545654
# Episode:452 Score:500.0 Actor_Loss:2.0214624404907227 Critic_Loss:6.764895439147949
# Episode:453 Score:500.0 Actor_Loss:2.0899157524108887 Critic_Loss:7.374781131744385
# Episode:454 Score:500.0 Actor_Loss:2.062736749649048 Critic_Loss:6.629441738128662
# Episode:455 Score:500.0 Actor_Loss:2.265446424484253 Critic_Loss:7.250216484069824
# Episode:456 Score:500.0 Actor_Loss:2.2981481552124023 Critic_Loss:6.630885601043701
# Episode:457 Score:500.0 Actor_Loss:2.1280124187469482 Critic_Loss:6.2433881759643555
# Episode:458 Score:500.0 Actor_Loss:1.9045839309692383 Critic_Loss:6.36378812789917
# Episode:459 Score:500.0 Actor_Loss:2.001403570175171 Critic_Loss:6.421806335449219
# Episode:460 Score:500.0 Actor_Loss:2.2678422927856445 Critic_Loss:6.47650146484375
# Episode:461 Score:500.0 Actor_Loss:2.156773328781128 Critic_Loss:6.293858051300049
# Episode:462 Score:500.0 Actor_Loss:1.6465837955474854 Critic_Loss:5.298007965087891
# Episode:463 Score:500.0 Actor_Loss:1.5587395429611206 Critic_Loss:5.280190467834473
# Episode:464 Score:500.0 Actor_Loss:1.461439847946167 Critic_Loss:5.150880813598633
# Episode:465 Score:500.0 Actor_Loss:1.5041403770446777 Critic_Loss:4.671645164489746
# Episode:466 Score:500.0 Actor_Loss:1.268815279006958 Critic_Loss:4.6918206214904785
# Episode:467 Score:500.0 Actor_Loss:1.8531585931777954 Critic_Loss:5.3087358474731445
# Episode:468 Score:500.0 Actor_Loss:1.9249802827835083 Critic_Loss:5.086284160614014
# Episode:469 Score:500.0 Actor_Loss:1.4159822463989258 Critic_Loss:4.38887357711792
# Episode:470 Score:500.0 Actor_Loss:1.3571420907974243 Critic_Loss:4.442941188812256
# Episode:471 Score:500.0 Actor_Loss:1.2535685300827026 Critic_Loss:4.289798736572266
# Episode:472 Score:500.0 Actor_Loss:1.4792357683181763 Critic_Loss:4.431353569030762
# Episode:473 Score:500.0 Actor_Loss:1.2298380136489868 Critic_Loss:3.716928243637085
# Episode:474 Score:500.0 Actor_Loss:1.3283627033233643 Critic_Loss:3.9256505966186523
# Episode:475 Score:500.0 Actor_Loss:0.9597553610801697 Critic_Loss:3.4477226734161377
# Episode:476 Score:500.0 Actor_Loss:1.5126891136169434 Critic_Loss:4.116509914398193
# Episode:477 Score:500.0 Actor_Loss:0.884095311164856 Critic_Loss:2.882373809814453
# Episode:478 Score:500.0 Actor_Loss:1.0110470056533813 Critic_Loss:2.792794942855835
# Episode:479 Score:500.0 Actor_Loss:1.0162849426269531 Critic_Loss:2.823413848876953
# Episode:480 Score:500.0 Actor_Loss:1.0239075422286987 Critic_Loss:2.737199306488037
# Episode:481 Score:500.0 Actor_Loss:0.9809500575065613 Critic_Loss:2.6239540576934814
# Episode:482 Score:500.0 Actor_Loss:0.7845205664634705 Critic_Loss:2.5020039081573486
# Episode:483 Score:500.0 Actor_Loss:0.9483184814453125 Critic_Loss:2.3156068325042725
# Episode:484 Score:500.0 Actor_Loss:0.6807385087013245 Critic_Loss:2.132133960723877
# Episode:485 Score:500.0 Actor_Loss:0.5633684396743774 Critic_Loss:1.7331032752990723
# Episode:486 Score:500.0 Actor_Loss:0.8036331534385681 Critic_Loss:1.993947982788086
# Episode:487 Score:500.0 Actor_Loss:0.6393658518791199 Critic_Loss:1.6585705280303955
# Episode:488 Score:500.0 Actor_Loss:0.47738149762153625 Critic_Loss:1.3896692991256714
# Episode:489 Score:500.0 Actor_Loss:0.482082337141037 Critic_Loss:1.165778398513794
# Episode:490 Score:500.0 Actor_Loss:0.47680115699768066 Critic_Loss:1.0320700407028198
# Episode:491 Score:500.0 Actor_Loss:0.44423168897628784 Critic_Loss:0.985165536403656
# Episode:492 Score:500.0 Actor_Loss:0.4242514669895172 Critic_Loss:0.8629111051559448
# Episode:493 Score:500.0 Actor_Loss:0.3559781014919281 Critic_Loss:0.6248252987861633
# Episode:494 Score:500.0 Actor_Loss:0.2490081936120987 Critic_Loss:0.4588812291622162
# Episode:495 Score:500.0 Actor_Loss:0.20229992270469666 Critic_Loss:0.36025241017341614
# Episode:496 Score:500.0 Actor_Loss:0.1640111654996872 Critic_Loss:0.21679134666919708
# Episode:497 Score:500.0 Actor_Loss:0.10627605020999908 Critic_Loss:0.09822577238082886
# Episode:498 Score:500.0 Actor_Loss:0.09027963131666183 Critic_Loss:0.04068915173411369
# Episode:499 Score:500.0 Actor_Loss:0.04709663242101669 Critic_Loss:0.012948301620781422

# %%
plt.plot(np.array(list(range(0, len(score)))), score, label='Score')
plt.plot(np.array(list(range(0, len(score), constant_for_average))), average_score, label='Average Score')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(actor_loss)))), actor_loss, label='Actor Loss')
plt.plot(np.array(list(range(0, len(actor_loss), constant_for_average))), average_actor_loss, label='Average Actor Loss')
plt.legend()
plt.show()

# %%
plt.plot(np.array(list(range(0, len(critic_loss)))), critic_loss, label='Critic Loss')
plt.plot(np.array(list(range(0, len(critic_loss), constant_for_average))), average_critic_loss, label='Average Critic Loss')
plt.legend()
plt.show()

# %%
'''file = open("Quantum_Score_Loss_V15(1_CNN_qasm).txt", "x")
data = np.column_stack([score, actor_loss, critic_loss])
np.savetxt("Quantum_Score_Loss_V15(1_CNN_qasm).txt",data)'''

# %%
'''file = open("Quantum_Score_Loss_V1(1_CNN_qasm_1500_epsiodes).txt", "x")
data = np.column_stack([score, actor_loss, critic_loss])
np.savetxt("Quantum_Score_Loss_V1(1_CNN_qasm_1500_episodes).txt",data)'''

# %%
total_params = sum(p.numel() for p in Actor.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 131

# %%
total_params = sum(p.numel() for p in Critic.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 66

# %%
torch.save(Actor.state_dict(), 'Actor_weights_V1.pth')

# %%
torch.save(Actor.state_dict(), 'Critic_weights_V1.pth')

# %%
Actor1 = HybridActorNetwork(state_space = state_space,
                            action_space = action_space).to(device)
# Out:
# /var/folders/5d/v7pmycsx3ld6mf_2fksw9vzc0000gn/T/ipykernel_71069/1355134908.py:26: DeprecationWarning: The class ``qiskit.utils.quantum_instance.QuantumInstance`` is deprecated as of qiskit-terra 0.24.0. It will be removed no earlier than 3 months after the release date. For code migration guidelines, visit https://qisk.it/qi_migration.
#   quantum_instance = QuantumInstance(backend = backend,

# %%
Actor1.load_state_dict(torch.load("Actor_weights_V1.pth"))
# Out:
# <All keys matched successfully>

# %%
Actor1.state_dict()
# Out:
# OrderedDict([('quantum_layer.weight', tensor([2.3464])),
#              ('quantum_layer._weights', tensor([2.3464])),
#              ('classical_layer_1.weight',
#               tensor([[-0.4933, -0.4795, -0.6510, -0.6290, -0.4794, -0.6119, -0.4686, -0.5171,
#                        -0.4220, -0.5964, -0.5980, -0.5146, -0.4314, -0.5529, -0.4661, -0.5879,
#                        -0.4363, -0.5477, -0.4487, -0.5589, -0.5851, -0.6124, -0.4818, -0.6329,
#                        -0.5833, -0.4243, -0.4337, -0.5083, -0.6088, -0.4724, -0.6054, -0.5366,
#                        -0.6555, -0.4840, -0.4691, -0.4761, -0.5635, -0.5897, -0.4877, -0.6473,
#                        -0.5567, -0.5021, -0.5275, -0.6440, -0.5212, -0.6313, -0.6382, -0.4833,
#                        -0.5122, -0.5283, -0.4386, -0.5911, -0.5132, -0.5505, -0.5363, -0.5703,
#                        -0.4219, -0.5479, -0.5124, -0.4358, -0.4662, -0.4832, -0.5439, -0.5187],
#                       [ 0.8627,  0.8364,  0.9438,  0.9418,  0.7903,  0.7609,  0.7973,  0.8772,
#                         0.9245,  0.7512,  0.8846,  0.8097,  0.8802,  0.9231,  0.8671,  0.7795,
#                         0.8578,  0.9109,  0.9066,  0.8003,  0.9114,  0.8849,  0.8752,  0.8219,
#                         0.8877,  0.9319,  0.9649,  0.8894,  0.7871,  0.9554,  0.8540,  0.7790,
#                         0.7731,  0.9190,  0.8335,  0.7932,  0.8821,  0.8070,  0.8791,  0.7663,
#                         0.9135,  0.8007,  0.8290,  0.7542,  0.9764,  0.9461,  0.8636,  0.9851,
#                         0.9013,  0.7414,  0.8131,  0.7466,  0.8257,  0.8550,  0.9275,  0.9507,
#                         0.7409,  0.8214,  0.8919,  0.9586,  0.8342,  0.8577,  0.9873,  0.8567]])),
#              ('classical_layer_1.bias', tensor([0.1243, 0.9238]))])

# %%
Actor.state_dict()
# Out:
# OrderedDict([('quantum_layer.weight', tensor([2.3464])),
#              ('quantum_layer._weights', tensor([2.3464])),
#              ('classical_layer_1.weight',
#               tensor([[-0.4933, -0.4795, -0.6510, -0.6290, -0.4794, -0.6119, -0.4686, -0.5171,
#                        -0.4220, -0.5964, -0.5980, -0.5146, -0.4314, -0.5529, -0.4661, -0.5879,
#                        -0.4363, -0.5477, -0.4487, -0.5589, -0.5851, -0.6124, -0.4818, -0.6329,
#                        -0.5833, -0.4243, -0.4337, -0.5083, -0.6088, -0.4724, -0.6054, -0.5366,
#                        -0.6555, -0.4840, -0.4691, -0.4761, -0.5635, -0.5897, -0.4877, -0.6473,
#                        -0.5567, -0.5021, -0.5275, -0.6440, -0.5212, -0.6313, -0.6382, -0.4833,
#                        -0.5122, -0.5283, -0.4386, -0.5911, -0.5132, -0.5505, -0.5363, -0.5703,
#                        -0.4219, -0.5479, -0.5124, -0.4358, -0.4662, -0.4832, -0.5439, -0.5187],
#                       [ 0.8627,  0.8364,  0.9438,  0.9418,  0.7903,  0.7609,  0.7973,  0.8772,
#                         0.9245,  0.7512,  0.8846,  0.8097,  0.8802,  0.9231,  0.8671,  0.7795,
#                         0.8578,  0.9109,  0.9066,  0.8003,  0.9114,  0.8849,  0.8752,  0.8219,
#                         0.8877,  0.9319,  0.9649,  0.8894,  0.7871,  0.9554,  0.8540,  0.7790,
#                         0.7731,  0.9190,  0.8335,  0.7932,  0.8821,  0.8070,  0.8791,  0.7663,
#                         0.9135,  0.8007,  0.8290,  0.7542,  0.9764,  0.9461,  0.8636,  0.9851,
#                         0.9013,  0.7414,  0.8131,  0.7466,  0.8257,  0.8550,  0.9275,  0.9507,
#                         0.7409,  0.8214,  0.8919,  0.9586,  0.8342,  0.8577,  0.9873,  0.8567]])),
#              ('classical_layer_1.bias', tensor([0.1243, 0.9238]))])
